# %%
# %pip install keras-tuner
# %pip install keras_self_attention

# %%
import tensorflow as tf
import site
import pandas as pd
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import  Dense, Flatten, Activation, Dropout, Embedding, Conv1D, Conv2D, MaxPooling2D, MaxPooling1D, Concatenate, BatchNormalization, GaussianNoise
from tensorflow.keras.layers import LSTM, TimeDistributed, Permute, Reshape, Lambda, RepeatVector, Input, Multiply, SimpleRNN, GRU, LeakyReLU
import os
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
pd.set_option('display.width', 400)
pd.set_option('display.max_columns', 40)

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import h5py as h5
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
import errno
import os
from collections import defaultdict
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.summary import create_file_writer
from sklearn.model_selection import train_test_split
import numpy as np
import itertools
import multiprocessing

# %%
def coShuffled_vectors(X, Y):
    if tf.shape(X)[0] == tf.shape(Y)[0]:
        test_idxs = tf.range(start=0, limit=tf.shape(X)[0], dtype=tf.int32)
        shuffled_test_idxs = tf.random.shuffle(test_idxs)
        return (tf.gather(X, shuffled_test_idxs), tf.gather(Y, shuffled_test_idxs))
    else:
        raise ValueError(f"0-dimension has to be the same {tf.shape(X)[0]} != {tf.shape(Y)[0]}")


def getNpArrayFromH5(hf_Data):
    X_train = hf_Data['Train_Data']  # Get train set
    X_train = np.array(X_train)
    Y_train = hf_Data['Label']  # Get train label
    Y_train = np.array(Y_train)
    return X_train, Y_train

# data extraction
def getData(is500=True, shuffle=False, ise2e=False, include_secondary=False, validation_split=None, isColab=False):
    if not include_secondary:
        hf_Train = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/{"e2e_Train_Data" if ise2e else "Fold_10_Train_Data"}_{str(500) if is500 else str(1000)}.h5', 'r')
        hf_Test = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/{"e2e_Test_Data" if ise2e else "Fold_10_Test_Data"}_{str(500) if is500 else str(1000)}.h5', 'r')
    else:
        hf_Train = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_Secondary_Data_1136.h5', 'r')
        hf_Test = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_Secondary_Data_1136.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    X_validation = Y_validation = None
    if validation_split is not None:
        # sklearn split shuffles anyway
        X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=validation_split)

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation


def getE2eData(is500=True, shuffle=False, include_secondary=False, isColab=False):
    if not include_secondary:
        hf_Train = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_Data_{str(500) if is500 else str(1000)}.h5', 'r')
        hf_Test = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_Data_{str(500) if is500 else str(1000)}.h5', 'r')
    else:
        hf_Train = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_Secondary_Data_1136.h5', 'r')
        hf_Test = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_Secondary_Data_1136.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    hf_Val = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Val_Secondary_Data_1136.h5', 'r') if include_secondary else h5.File(
        f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Val_Data_{str(500) if is500 else str(1000)}.h5', 'r')
    X_validation, Y_validation = getNpArrayFromH5(hf_Val)
    Y_validation = to_categorical(Y_validation, 13)  # Process the label of tain

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation


def getE2eDataJustSecondary(shuffle=False,isColab=False):
    hf_Train = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_just_Secondary_Data_1000.h5', 'r')
    hf_Test = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_just_Secondary_Data_1000.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    hf_Val = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Val_just_Secondary_Data_1000.h5', 'r')
    
    X_validation, Y_validation = getNpArrayFromH5(hf_Val)
    Y_validation = to_categorical(Y_validation, 13)  # Process the label of tain

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation

# %%
def plot_history(history):
    acc_keys = [k for k in history.history.keys() if k in ('accuracy', 'val_accuracy')]
    loss_keys = [k for k in history.history.keys() if not k in acc_keys]
    for k, v in history.history.items():
        if k in acc_keys:
            plt.figure(1)
            plt.plot(v)
        else:
            plt.figure(2)
            plt.plot(v)
    plt.figure(1)
    plt.title('Accuracy vs. epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(acc_keys, loc='lower right')
    plt.figure(2)
    plt.title('Loss vs. epochs')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loss_keys, loc='upper right')
    plt.show()


def get_layer_by_name(layers, name, return_first=True):
    matching_named_layers = [l for l in layers if l.name == name]
    if not matching_named_layers:
        return None
    return matching_named_layers[0] if return_first else matching_named_layers


def get_combined_features_from_models(
        to_combine,
        X_train, Y_train,
        X_test, Y_test,
        reverse_one_hot=False,
        normalize_X_func=None):
    models = []
    models_dict = {}
    X_trains_out = []
    X_test_out = []
    XY_dict = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: None))))

    if reverse_one_hot:
        Y_train_new = np.apply_along_axis(np.argmax, 1, Y_train) + 1
        Y_test_new = np.apply_along_axis(np.argmax, 1, Y_test) + 1
    else:
        Y_train_new = Y_train.copy()
        Y_test_new = Y_test.copy()

    for model_file_name, layer_name, kwargs in to_combine:
        model_here = None
        if isinstance(model_file_name, tf.keras.models.Model):
            model_here = model_file_name
            model_file_name = model_here.name
        else:
            if model_file_name in models_dict.keys():
                model_here = models_dict[model_file_name]
            else:
                model_here = tf.keras.models.load_model(model_file_name,
                                                        **kwargs) if kwargs is not None else tf.keras.models.load_model \
                    (model_file_name)

        features_model = Model(model_here.input,
                               get_layer_by_name(model_here.layers, layer_name).output)
        if normalize_X_func is None:
            X_trains_out.append(np.array(features_model.predict(X_train), dtype='float64'))
            X_test_out.append(np.array(features_model.predict(X_test), dtype='float64'))
        else:
            X_trains_out.append(np.array(normalize_X_func(features_model.predict(X_train)), dtype='float64'))
            X_test_out.append(np.array(normalize_X_func(features_model.predict(X_test)), dtype='float64'))
        XY_dict[model_file_name][layer_name]['Train']['X'] = X_trains_out[-1]
        XY_dict[model_file_name][layer_name]['Test']['X'] = X_test_out[-1]
        XY_dict[model_file_name][layer_name]['Train']['Y'] = Y_train_new
        XY_dict[model_file_name][layer_name]['Test']['Y'] = Y_test_new
        models.append(((model_file_name, layer_name), (model_here, features_model)))
        models_dict[model_file_name] = model_here

    X_train_new = np.concatenate(tuple(X_trains_out), axis=1)
    X_test_new = np.concatenate(tuple(X_test_out), axis=1)

    data_train = (X_train_new, Y_train_new)
    data_test = (X_test_new, Y_test_new)

    return models, data_train, data_test, XY_dict


def make_dir_if_not_exist(used_path):
    if not os.path.isdir(used_path):
        try:
            os.mkdir(used_path)
        except OSError as exc:
            if exc.errno != errno.EEXIST:
                raise exc
            else:
                raise ValueError(f'{used_path} directoy cannot be created because its parent directory does not exist.')


def source_model(model_func, model_name, input_shape):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)
    return m


def compile_and_fit_model_with_tb(model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_every_epoch=True,
                                  save_final=False,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)
    tb_callback = TensorBoard(log_dir=f'{m.name}_logs', histogram_freq=kwargs.pop("histogram_freq", 1))
    if save_every_epoch:
        tb_callback.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.2f}'))
    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=[tb_callback], verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)
    # m.save(f"{m.name}_Tenth_Fold_New_Model_500_8") #Save the model


def compile_and_fit_model(model_func,
                          model_name,
                          input_shape,
                          X_train,
                          Y_train,
                          save_every_epoch=True,
                          save_final=False,
                          **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_every_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.2f}'))
    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)


def compile_model_and_fit_with_custom_loop(model_func,
                                           model_name,
                                           input_shape,
                                           X_train,
                                           Y_train,
                                           **kwargs):
    make_dir_if_not_exist(model_name)
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    train_writer = create_file_writer(f'{m.name}_logs/train/')
    test_writer = create_file_writer(f'{m.name}_logs/test/')
    train_step = test_step = 0

    acc_metric = tf.keras.metrics.CategoricalAccuracy()
    optimizer = tf.keras.optimizers.Adam()
    num_epochs = kwargs.get("epochs", 10)

    AUTOTUNE = tf.data.experimental.AUTOTUNE
    BATCH_SIZE = kwargs.get("batch_size", 32)
    X_test, Y_test = kwargs.get("validation_data", (None, None))
    if X_test is None:
        raise ValueError("Missing X validation data")
    if Y_test is None:
        raise ValueError("Missing Y validation data")

    train_dataset_tf = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
    train_dataset_tf = train_dataset_tf.batch(BATCH_SIZE)
    train_dataset_tf = train_dataset_tf.prefetch(AUTOTUNE)

    test_dataset_tf = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    test_dataset_tf = train_dataset_tf.batch(BATCH_SIZE)
    test_dataset_tf = train_dataset_tf.prefetch(AUTOTUNE)

    loss_fn = tf.keras.losses.CategoricalCrossentropy()

    for epoch in range(num_epochs):
        # Iterate through training set
        for batch_idx, (x, y) in enumerate(train_dataset_tf):
            with tf.GradientTape() as tape:
                y_pred = m(x, training=True)
                loss = loss_fn(y, y_pred)

            gradients = tape.gradient(loss, m.trainable_weights)
            optimizer.apply_gradients(zip(gradients, m.trainable_weights))
            acc_metric.update_state(y, y_pred)

            with train_writer.as_default():
                tf.summary.scalar("Loss", loss, step=train_step)
                tf.summary.scalar(
                    "Accuracy", acc_metric.result(), step=train_step,
                )
                train_step += 1
        # Reset accuracy in between epochs (and for testing and test)
        acc_metric.reset_states()
        # Iterate through test set
        for batch_idx, (x, y) in enumerate(test_dataset_tf):
            y_pred = m(x, training=False)
            loss = loss_fn(y, y_pred)
            acc_metric.update_state(y, y_pred)
            with test_writer.as_default():
                tf.summary.scalar("Loss", loss, step=test_step)
                tf.summary.scalar(
                    "Accuracy", acc_metric.result(), step=test_step,
                )
                test_step += 1

        acc_metric.reset_states()  # Reset accuracy in between epochs (and for testing and test)

    return m


def reinitialize_weights(model):
    for ix, layer in enumerate(model.layers):
        if hasattr(model.layers[ix], 'kernel_initializer') and hasattr(model.layers[ix], 'bias_initializer'):
            weight_initializer = model.layers[ix].kernel_initializer
            bias_initializer = model.layers[ix].bias_initializer

            old_weights, old_biases = model.layers[ix].get_weights()

            model.layers[ix].set_weights([
                weight_initializer(shape=old_weights.shape),
                bias_initializer(shape=len(old_biases))])
    return model


def reverse_tensor(X):
    return tf.gather(X, tf.reverse(tf.range(start=0, limit=tf.shape(X)[0], dtype=tf.int32), (0,)))


def run_mirrored_strategy(model_func, base_batch_size, nepochs, x_train, y_train, x_test, y_test, **kwargs):
    strategy = tf.distribute.MirroredStrategy()
    with strategy.scope():
        model = model_func()
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=tf.keras.metrics.SparseCategoricalAccuracy()
        )
    batch_size_mirr_strat = base_batch_size * strategy.num_replicas_in_sync
    history = model.fit(x_train, y_train, epochs=nepochs, batch_size=batch_size_mirr_strat,
                        validation_data=(x_test, y_test),
                        **kwargs)
    return model, history


def sparse_setdiff(a1, a2):
    a1a = a1.reshape(a1.shape[0], -1)
    a2a = a2.reshape(a2.shape[0], -1)
    spa2a = [np.where(x)[0].tolist() for x in a2a]
    spa1a = [np.where(x)[0].tolist() for x in a1a]
    idxs_to_keep = []
    for idx, sample in enumerate(spa1a):
        try:
            spa2a.index(sample)
        except ValueError:
            # not in list
            idxs_to_keep.append(idx)
    return a1[idxs_to_keep], idxs_to_keep


def unpacking_apply_along_axis(all_args):
    """
    Like numpy.apply_along_axis(), but with arguments in a tuple
    instead.

    This function is useful with multiprocessing.Pool().map(): (1)
    map() only handles functions that take a single argument, and (2)
    this function can generally be imported from a module, as required
    by map().
    """
    (func1d, axis, arr, args, kwargs) = all_args
    # return np.apply_along_axis(func1d, axis, arr, *args, **kwargs)


def parallel_apply_along_axis(func1d, axis, arr, *args, **kwargs):
    """
    Like numpy.apply_along_axis(), but takes advantage of multiple
    cores.
    """
    # Effective axis where apply_along_axis() will be applied by each
    # worker (any non-zero axis number would work, so as to allow the use
    # of `np.array_split()`, which is only done on axis 0):
    effective_axis = 1 if axis == 0 else axis
    if effective_axis != axis:
        arr = arr.swapaxes(axis, effective_axis)

    # Chunks for the mapping (only a few chunks):
    chunks = [(func1d, effective_axis, sub_arr, args, kwargs)
              for sub_arr in np.array_split(arr, multiprocessing.cpu_count())]

    pool = multiprocessing.Pool()
    individual_results = pool.map(unpacking_apply_along_axis, chunks)
    # Freeing the workers:
    pool.close()
    pool.join()

    return np.concatenate(individual_results)

# %%
def baseline_CNN_finalist(model_name, inshape, num_classes = 13):

    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Conv1D(128 ,10 ,padding='same' ,input_shape=inshape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(128 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(128))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(64))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax))
    model._name = model_name

    return model


def compile_and_fit_model_basic(  model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='val_accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

def compile_and_fit_model_basic_noVal(  model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

# %%
X_train_1000e, Y_train_1000e, X_test_1000e, Y_test_1000e, X_val_1000e, Y_val_1000e = getE2eData(is500=False, include_secondary=False, isColab=True)

# %%
X_train_1000e_j2nd, Y_train_1000e_j2nd, X_test_1000e_j2nd, Y_test_1000e_j2nd, X_val_1000e_j2nd, Y_val_1000e_j2nd = getE2eDataJustSecondary(isColab=True)

# %%
# merge into a new train:
X_new_train = np.concatenate( (X_train_1000e_j2nd, X_val_1000e_j2nd), axis=0 )
Y_new_train = np.concatenate( (Y_train_1000e_j2nd, Y_val_1000e_j2nd), axis=0 )
cnn_2, history_cnn_2 = compile_and_fit_model_basic_noVal(baseline_CNN_finalist,
                                              "cnn_noTest_20210516",
                                              X_new_train[0].shape,
                                              X_new_train,
                                              Y_new_train,
                                              save_max_epoch=True,
                                              save_final=True,
                                              patience_count=10,
                                              batch_size=2048,
                                              epochs=500,
                                              class_weight=None)
cnn_2.evaluate(X_test_1000e_j2nd, Y_test_1000e_j2nd)
plot_history(history_cnn_2)
# Out:
# Epoch 1/500
# 4/4 - 3s - loss: 2.8128 - accuracy: 0.1093
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_001_0.109/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/500
# 4/4 - 1s - loss: 2.4626 - accuracy: 0.1647
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_002_0.165/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/500
# 4/4 - 1s - loss: 2.3056 - accuracy: 0.1927
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_003_0.193/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/500
# 4/4 - 1s - loss: 2.2047 - accuracy: 0.2207
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_004_0.221/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/500
# 4/4 - 1s - loss: 2.1466 - accuracy: 0.2328
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_005_0.233/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/500
# 4/4 - 1s - loss: 2.0903 - accuracy: 0.2419
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_006_0.242/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/500
# 4/4 - 1s - loss: 2.0523 - accuracy: 0.2594
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_007_0.259/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/500
# 4/4 - 1s - loss: 2.0220 - accuracy: 0.2749
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_008_0.275/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/500
# 4/4 - 1s - loss: 2.0039 - accuracy: 0.2885
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_009_0.289/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/500
# 4/4 - 1s - loss: 1.9660 - accuracy: 0.3076
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_010_0.308/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 11/500
# 4/4 - 1s - loss: 1.9514 - accuracy: 0.3094
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_011_0.309/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 12/500
# 4/4 - 1s - loss: 1.9347 - accuracy: 0.3145
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_012_0.314/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 13/500
# 4/4 - 1s - loss: 1.9166 - accuracy: 0.3195
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_013_0.320/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 14/500
# 4/4 - 1s - loss: 1.8976 - accuracy: 0.3291
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_014_0.329/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 15/500
# 4/4 - 1s - loss: 1.8787 - accuracy: 0.3404
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_015_0.340/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 16/500
# 4/4 - 1s - loss: 1.8560 - accuracy: 0.3409
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_016_0.341/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 17/500
# 4/4 - 1s - loss: 1.8367 - accuracy: 0.3553
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_017_0.355/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 18/500
# 4/4 - 1s - loss: 1.8160 - accuracy: 0.3711
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_018_0.371/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 19/500
# 4/4 - 1s - loss: 1.7888 - accuracy: 0.3784
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_019_0.378/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 20/500
# 4/4 - 1s - loss: 1.7705 - accuracy: 0.3949
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_020_0.395/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 21/500
# 4/4 - 1s - loss: 1.7430 - accuracy: 0.4009
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_021_0.401/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 22/500
# 4/4 - 1s - loss: 1.7119 - accuracy: 0.4181
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_022_0.418/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 23/500
# 4/4 - 1s - loss: 1.6790 - accuracy: 0.4377
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_023_0.438/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 24/500
# 4/4 - 1s - loss: 1.6506 - accuracy: 0.4518
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_024_0.452/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 25/500
# 4/4 - 1s - loss: 1.6212 - accuracy: 0.4577
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_025_0.458/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 26/500
# 4/4 - 1s - loss: 1.5859 - accuracy: 0.4719
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_026_0.472/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 27/500
# 4/4 - 1s - loss: 1.5531 - accuracy: 0.4876
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_027_0.488/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 28/500
# 4/4 - 1s - loss: 1.5264 - accuracy: 0.4950
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_028_0.495/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 29/500
# 4/4 - 1s - loss: 1.4899 - accuracy: 0.5043
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_029_0.504/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 30/500
# 4/4 - 1s - loss: 1.4581 - accuracy: 0.5200
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_030_0.520/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 31/500
# 4/4 - 1s - loss: 1.4369 - accuracy: 0.5204
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_031_0.520/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 32/500
# 4/4 - 1s - loss: 1.4219 - accuracy: 0.5285
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_032_0.528/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 33/500
# 4/4 - 1s - loss: 1.3924 - accuracy: 0.5351
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_033_0.535/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 34/500
# 4/4 - 1s - loss: 1.3795 - accuracy: 0.5387
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_034_0.539/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 35/500
# 4/4 - 1s - loss: 1.3565 - accuracy: 0.5561
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_035_0.556/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 36/500
# 4/4 - 1s - loss: 1.3432 - accuracy: 0.5501
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 37/500
# 4/4 - 1s - loss: 1.3254 - accuracy: 0.5570
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_037_0.557/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 38/500
# 4/4 - 1s - loss: 1.3066 - accuracy: 0.5672
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_038_0.567/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 39/500
# 4/4 - 1s - loss: 1.2890 - accuracy: 0.5671
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 40/500
# 4/4 - 1s - loss: 1.2723 - accuracy: 0.5737
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_040_0.574/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 41/500
# 4/4 - 1s - loss: 1.2591 - accuracy: 0.5879
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_041_0.588/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 42/500
# 4/4 - 1s - loss: 1.2419 - accuracy: 0.5874
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 43/500
# 4/4 - 1s - loss: 1.2275 - accuracy: 0.5911
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_043_0.591/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 44/500
# 4/4 - 1s - loss: 1.2238 - accuracy: 0.5898
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 45/500
# 4/4 - 1s - loss: 1.2045 - accuracy: 0.6043
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_045_0.604/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 46/500
# 4/4 - 1s - loss: 1.1850 - accuracy: 0.6066
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_046_0.607/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 47/500
# 4/4 - 1s - loss: 1.1779 - accuracy: 0.6110
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_047_0.611/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 48/500
# 4/4 - 1s - loss: 1.1570 - accuracy: 0.6174
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_048_0.617/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 49/500
# 4/4 - 1s - loss: 1.1411 - accuracy: 0.6176
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_049_0.618/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 50/500
# 4/4 - 1s - loss: 1.1368 - accuracy: 0.6223
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_050_0.622/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 51/500
# 4/4 - 1s - loss: 1.1220 - accuracy: 0.6259
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_051_0.626/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 52/500
# 4/4 - 1s - loss: 1.1246 - accuracy: 0.6288
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_052_0.629/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 53/500
# 4/4 - 1s - loss: 1.0995 - accuracy: 0.6359
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_053_0.636/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 54/500
# 4/4 - 1s - loss: 1.0948 - accuracy: 0.6359
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 55/500
# 4/4 - 1s - loss: 1.0901 - accuracy: 0.6346
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 56/500
# 4/4 - 1s - loss: 1.0644 - accuracy: 0.6467
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_056_0.647/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 57/500
# 4/4 - 1s - loss: 1.0728 - accuracy: 0.6459
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 58/500
# 4/4 - 1s - loss: 1.0556 - accuracy: 0.6417
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 59/500
# 4/4 - 1s - loss: 1.0430 - accuracy: 0.6521
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_059_0.652/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 60/500
# 4/4 - 1s - loss: 1.0343 - accuracy: 0.6530
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_060_0.653/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 61/500
# 4/4 - 1s - loss: 1.0112 - accuracy: 0.6651
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_061_0.665/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 62/500
# 4/4 - 1s - loss: 1.0133 - accuracy: 0.6622
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 63/500
# 4/4 - 1s - loss: 1.0009 - accuracy: 0.6655
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_063_0.665/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 64/500
# 4/4 - 1s - loss: 0.9819 - accuracy: 0.6717
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_064_0.672/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 65/500
# 4/4 - 1s - loss: 0.9997 - accuracy: 0.6670
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 66/500
# 4/4 - 1s - loss: 0.9761 - accuracy: 0.6739
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_066_0.674/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 67/500
# 4/4 - 1s - loss: 0.9580 - accuracy: 0.6818
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_067_0.682/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 68/500
# 4/4 - 1s - loss: 0.9566 - accuracy: 0.6793
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 69/500
# 4/4 - 1s - loss: 0.9565 - accuracy: 0.6823
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_069_0.682/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 70/500
# 4/4 - 1s - loss: 0.9412 - accuracy: 0.6906
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_070_0.691/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 71/500
# 4/4 - 1s - loss: 0.9243 - accuracy: 0.6885
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 72/500
# 4/4 - 1s - loss: 0.9217 - accuracy: 0.6840
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 73/500
# 4/4 - 1s - loss: 0.9037 - accuracy: 0.6970
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_073_0.697/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 74/500
# 4/4 - 1s - loss: 0.9058 - accuracy: 0.6971
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_074_0.697/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 75/500
# 4/4 - 1s - loss: 0.9032 - accuracy: 0.7002
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_075_0.700/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 76/500
# 4/4 - 1s - loss: 0.8773 - accuracy: 0.7046
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_076_0.705/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 77/500
# 4/4 - 1s - loss: 0.8729 - accuracy: 0.7067
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_077_0.707/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 78/500
# 4/4 - 1s - loss: 0.8759 - accuracy: 0.7060
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 79/500
# 4/4 - 1s - loss: 0.8538 - accuracy: 0.7124
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_079_0.712/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 80/500
# 4/4 - 1s - loss: 0.8430 - accuracy: 0.7177
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_080_0.718/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 81/500
# 4/4 - 1s - loss: 0.8404 - accuracy: 0.7247
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_081_0.725/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 82/500
# 4/4 - 1s - loss: 0.8344 - accuracy: 0.7216
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 83/500
# 4/4 - 1s - loss: 0.8241 - accuracy: 0.7221
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 84/500
# 4/4 - 1s - loss: 0.8266 - accuracy: 0.7212
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 85/500
# 4/4 - 1s - loss: 0.8204 - accuracy: 0.7238
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 86/500
# 4/4 - 1s - loss: 0.7944 - accuracy: 0.7351
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_086_0.735/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 87/500
# 4/4 - 1s - loss: 0.7923 - accuracy: 0.7365
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_087_0.736/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 88/500
# 4/4 - 1s - loss: 0.7789 - accuracy: 0.7386
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_088_0.739/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 89/500
# 4/4 - 1s - loss: 0.7771 - accuracy: 0.7413
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_089_0.741/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 90/500
# 4/4 - 1s - loss: 0.7692 - accuracy: 0.7377
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 91/500
# 4/4 - 1s - loss: 0.7478 - accuracy: 0.7465
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_091_0.746/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 92/500
# 4/4 - 1s - loss: 0.7590 - accuracy: 0.7441
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 93/500
# 4/4 - 1s - loss: 0.7460 - accuracy: 0.7483
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_093_0.748/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 94/500
# 4/4 - 1s - loss: 0.7428 - accuracy: 0.7475
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 95/500
# 4/4 - 1s - loss: 0.7224 - accuracy: 0.7614
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_095_0.761/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 96/500
# 4/4 - 1s - loss: 0.7189 - accuracy: 0.7553
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 97/500
# 4/4 - 1s - loss: 0.7249 - accuracy: 0.7529
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 98/500
# 4/4 - 1s - loss: 0.7034 - accuracy: 0.7646
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_098_0.765/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 99/500
# 4/4 - 1s - loss: 0.6987 - accuracy: 0.7585
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 100/500
# 4/4 - 1s - loss: 0.6974 - accuracy: 0.7589
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 101/500
# 4/4 - 1s - loss: 0.6761 - accuracy: 0.7706
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_101_0.771/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 102/500
# 4/4 - 1s - loss: 0.6796 - accuracy: 0.7701
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 103/500
# 4/4 - 1s - loss: 0.6702 - accuracy: 0.7707
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_103_0.771/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 104/500
# 4/4 - 1s - loss: 0.6608 - accuracy: 0.7754
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_104_0.775/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 105/500
# 4/4 - 1s - loss: 0.6487 - accuracy: 0.7809
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_105_0.781/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 106/500
# 4/4 - 1s - loss: 0.6448 - accuracy: 0.7839
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_106_0.784/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 107/500
# 4/4 - 1s - loss: 0.6267 - accuracy: 0.7914
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_107_0.791/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 108/500
# 4/4 - 1s - loss: 0.6119 - accuracy: 0.7961
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_108_0.796/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 109/500
# 4/4 - 1s - loss: 0.6180 - accuracy: 0.7920
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 110/500
# 4/4 - 1s - loss: 0.6192 - accuracy: 0.7900
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 111/500
# 4/4 - 1s - loss: 0.5864 - accuracy: 0.8040
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_111_0.804/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 112/500
# 4/4 - 1s - loss: 0.6044 - accuracy: 0.7933
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 113/500
# 4/4 - 1s - loss: 0.5912 - accuracy: 0.8006
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 114/500
# 4/4 - 1s - loss: 0.5862 - accuracy: 0.7991
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 115/500
# 4/4 - 1s - loss: 0.5748 - accuracy: 0.8032
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 116/500
# 4/4 - 1s - loss: 0.5723 - accuracy: 0.8052
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_116_0.805/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 117/500
# 4/4 - 1s - loss: 0.5602 - accuracy: 0.8106
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_117_0.811/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 118/500
# 4/4 - 1s - loss: 0.5625 - accuracy: 0.8074
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 119/500
# 4/4 - 1s - loss: 0.5513 - accuracy: 0.8087
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 120/500
# 4/4 - 1s - loss: 0.5495 - accuracy: 0.8156
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_120_0.816/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 121/500
# 4/4 - 1s - loss: 0.5318 - accuracy: 0.8152
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 122/500
# 4/4 - 1s - loss: 0.5250 - accuracy: 0.8185
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_122_0.819/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 123/500
# 4/4 - 1s - loss: 0.5229 - accuracy: 0.8194
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_123_0.819/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 124/500
# 4/4 - 1s - loss: 0.5139 - accuracy: 0.8263
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_124_0.826/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 125/500
# 4/4 - 1s - loss: 0.5170 - accuracy: 0.8197
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 126/500
# 4/4 - 1s - loss: 0.4979 - accuracy: 0.8293
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_126_0.829/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 127/500
# 4/4 - 1s - loss: 0.4921 - accuracy: 0.8296
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_127_0.830/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 128/500
# 4/4 - 1s - loss: 0.4971 - accuracy: 0.8319
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_128_0.832/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 129/500
# 4/4 - 1s - loss: 0.4970 - accuracy: 0.8276
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 130/500
# 4/4 - 1s - loss: 0.4571 - accuracy: 0.8445
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_130_0.844/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 131/500
# 4/4 - 1s - loss: 0.4736 - accuracy: 0.8406
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 132/500
# 4/4 - 1s - loss: 0.4581 - accuracy: 0.8442
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 133/500
# 4/4 - 1s - loss: 0.4527 - accuracy: 0.8413
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 134/500
# 4/4 - 1s - loss: 0.4502 - accuracy: 0.8415
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 135/500
# 4/4 - 1s - loss: 0.4505 - accuracy: 0.8537
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_135_0.854/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 136/500
# 4/4 - 1s - loss: 0.4612 - accuracy: 0.8395
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 137/500
# 4/4 - 1s - loss: 0.4404 - accuracy: 0.8509
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 138/500
# 4/4 - 1s - loss: 0.4293 - accuracy: 0.8507
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 139/500
# 4/4 - 1s - loss: 0.4229 - accuracy: 0.8574
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_139_0.857/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 140/500
# 4/4 - 1s - loss: 0.4144 - accuracy: 0.8590
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_140_0.859/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 141/500
# 4/4 - 1s - loss: 0.4065 - accuracy: 0.8613
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_141_0.861/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 142/500
# 4/4 - 1s - loss: 0.4177 - accuracy: 0.8570
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 143/500
# 4/4 - 1s - loss: 0.3982 - accuracy: 0.8618
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_143_0.862/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 144/500
# 4/4 - 1s - loss: 0.3935 - accuracy: 0.8633
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_144_0.863/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 145/500
# 4/4 - 1s - loss: 0.3813 - accuracy: 0.8682
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_145_0.868/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 146/500
# 4/4 - 1s - loss: 0.3821 - accuracy: 0.8670
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 147/500
# 4/4 - 1s - loss: 0.3798 - accuracy: 0.8722
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_147_0.872/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 148/500
# 4/4 - 1s - loss: 0.3680 - accuracy: 0.8775
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_148_0.878/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 149/500
# 4/4 - 1s - loss: 0.3808 - accuracy: 0.8688
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 150/500
# 4/4 - 1s - loss: 0.3622 - accuracy: 0.8771
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 151/500
# 4/4 - 1s - loss: 0.3650 - accuracy: 0.8773
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 152/500
# 4/4 - 1s - loss: 0.3589 - accuracy: 0.8766
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 153/500
# 4/4 - 1s - loss: 0.3718 - accuracy: 0.8753
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 154/500
# 4/4 - 1s - loss: 0.3473 - accuracy: 0.8883
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_154_0.888/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 155/500
# 4/4 - 1s - loss: 0.3433 - accuracy: 0.8830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 156/500
# 4/4 - 1s - loss: 0.3247 - accuracy: 0.8914
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_156_0.891/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 157/500
# 4/4 - 1s - loss: 0.3301 - accuracy: 0.8868
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 158/500
# 4/4 - 1s - loss: 0.3309 - accuracy: 0.8868
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 159/500
# 4/4 - 1s - loss: 0.3243 - accuracy: 0.8884
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 160/500
# 4/4 - 1s - loss: 0.3199 - accuracy: 0.8903
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 161/500
# 4/4 - 1s - loss: 0.3015 - accuracy: 0.8954
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_161_0.895/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 162/500
# 4/4 - 1s - loss: 0.2999 - accuracy: 0.8957
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_162_0.896/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 163/500
# 4/4 - 1s - loss: 0.2981 - accuracy: 0.9002
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_163_0.900/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 164/500
# 4/4 - 1s - loss: 0.3096 - accuracy: 0.8949
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 165/500
# 4/4 - 1s - loss: 0.2872 - accuracy: 0.9047
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_165_0.905/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 166/500
# 4/4 - 1s - loss: 0.3001 - accuracy: 0.8979
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 167/500
# 4/4 - 1s - loss: 0.2884 - accuracy: 0.9012
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 168/500
# 4/4 - 1s - loss: 0.2867 - accuracy: 0.9025
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 169/500
# 4/4 - 1s - loss: 0.2818 - accuracy: 0.9058
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_169_0.906/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 170/500
# 4/4 - 1s - loss: 0.2759 - accuracy: 0.9073
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_170_0.907/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 171/500
# 4/4 - 1s - loss: 0.2690 - accuracy: 0.9084
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_171_0.908/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 172/500
# 4/4 - 1s - loss: 0.2640 - accuracy: 0.9137
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_172_0.914/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 173/500
# 4/4 - 1s - loss: 0.2765 - accuracy: 0.9067
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 174/500
# 4/4 - 1s - loss: 0.2553 - accuracy: 0.9130
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 175/500
# 4/4 - 1s - loss: 0.2679 - accuracy: 0.9102
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 176/500
# 4/4 - 1s - loss: 0.2550 - accuracy: 0.9122
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 177/500
# 4/4 - 1s - loss: 0.2544 - accuracy: 0.9145
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_177_0.914/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 178/500
# 4/4 - 1s - loss: 0.2549 - accuracy: 0.9135
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 179/500
# 4/4 - 1s - loss: 0.2388 - accuracy: 0.9157
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_179_0.916/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 180/500
# 4/4 - 1s - loss: 0.2392 - accuracy: 0.9161
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_180_0.916/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 181/500
# 4/4 - 1s - loss: 0.2461 - accuracy: 0.9152
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 182/500
# 4/4 - 1s - loss: 0.2366 - accuracy: 0.9196
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_182_0.920/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 183/500
# 4/4 - 1s - loss: 0.2373 - accuracy: 0.9202
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_183_0.920/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 184/500
# 4/4 - 1s - loss: 0.2304 - accuracy: 0.9203
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_184_0.920/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 185/500
# 4/4 - 1s - loss: 0.2277 - accuracy: 0.9217
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_185_0.922/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 186/500
# 4/4 - 1s - loss: 0.2297 - accuracy: 0.9227
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_186_0.923/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 187/500
# 4/4 - 1s - loss: 0.2278 - accuracy: 0.9235
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_187_0.924/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 188/500
# 4/4 - 1s - loss: 0.2212 - accuracy: 0.9278
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_188_0.928/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 189/500
# 4/4 - 1s - loss: 0.2297 - accuracy: 0.9213
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 190/500
# 4/4 - 1s - loss: 0.2182 - accuracy: 0.9264
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 191/500
# 4/4 - 1s - loss: 0.2093 - accuracy: 0.9292
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_191_0.929/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 192/500
# 4/4 - 1s - loss: 0.2167 - accuracy: 0.9252
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 193/500
# 4/4 - 1s - loss: 0.2184 - accuracy: 0.9278
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 194/500
# 4/4 - 1s - loss: 0.2122 - accuracy: 0.9261
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 195/500
# 4/4 - 1s - loss: 0.2282 - accuracy: 0.9216
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 196/500
# 4/4 - 1s - loss: 0.1998 - accuracy: 0.9325
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_196_0.932/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 197/500
# 4/4 - 1s - loss: 0.1948 - accuracy: 0.9366
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_197_0.937/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 198/500
# 4/4 - 1s - loss: 0.1962 - accuracy: 0.9327
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 199/500
# 4/4 - 1s - loss: 0.1902 - accuracy: 0.9361
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 200/500
# 4/4 - 1s - loss: 0.1920 - accuracy: 0.9343
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 201/500
# 4/4 - 1s - loss: 0.1885 - accuracy: 0.9351
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 202/500
# 4/4 - 1s - loss: 0.1937 - accuracy: 0.9304
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 203/500
# 4/4 - 1s - loss: 0.1850 - accuracy: 0.9388
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_203_0.939/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 204/500
# 4/4 - 1s - loss: 0.1806 - accuracy: 0.9388
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 205/500
# 4/4 - 1s - loss: 0.1871 - accuracy: 0.9364
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 206/500
# 4/4 - 1s - loss: 0.1875 - accuracy: 0.9339
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 207/500
# 4/4 - 1s - loss: 0.1727 - accuracy: 0.9422
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_207_0.942/assets
# ...
# Epoch 419/500
# 4/4 - 1s - loss: 0.0535 - accuracy: 0.9830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 420/500
# 4/4 - 1s - loss: 0.0492 - accuracy: 0.9833
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 421/500
# 4/4 - 1s - loss: 0.0494 - accuracy: 0.9838
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 422/500
# 4/4 - 1s - loss: 0.0506 - accuracy: 0.9826
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 423/500
# 4/4 - 1s - loss: 0.0483 - accuracy: 0.9847
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 424/500
# 4/4 - 1s - loss: 0.0474 - accuracy: 0.9834
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 425/500
# 4/4 - 1s - loss: 0.0505 - accuracy: 0.9815
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 426/500
# 4/4 - 1s - loss: 0.0479 - accuracy: 0.9839
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 427/500
# 4/4 - 1s - loss: 0.0436 - accuracy: 0.9852
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_427_0.985/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 428/500
# 4/4 - 1s - loss: 0.0485 - accuracy: 0.9857
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_428_0.986/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 429/500
# 4/4 - 1s - loss: 0.0471 - accuracy: 0.9838
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 430/500
# 4/4 - 1s - loss: 0.0525 - accuracy: 0.9843
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 431/500
# 4/4 - 1s - loss: 0.0532 - accuracy: 0.9828
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 432/500
# 4/4 - 1s - loss: 0.0500 - accuracy: 0.9847
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 433/500
# 4/4 - 1s - loss: 0.0460 - accuracy: 0.9851
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 434/500
# 4/4 - 1s - loss: 0.0477 - accuracy: 0.9846
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 435/500
# 4/4 - 1s - loss: 0.0441 - accuracy: 0.9850
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 436/500
# 4/4 - 1s - loss: 0.0513 - accuracy: 0.9831
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 437/500
# 4/4 - 1s - loss: 0.0443 - accuracy: 0.9861
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_437_0.986/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 438/500
# 4/4 - 1s - loss: 0.0511 - accuracy: 0.9822
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 439/500
# 4/4 - 1s - loss: 0.0471 - accuracy: 0.9834
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 440/500
# 4/4 - 1s - loss: 0.0442 - accuracy: 0.9861
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 441/500
# 4/4 - 1s - loss: 0.0509 - accuracy: 0.9844
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 442/500
# 4/4 - 1s - loss: 0.0463 - accuracy: 0.9850
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 443/500
# 4/4 - 1s - loss: 0.0413 - accuracy: 0.9866
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_443_0.987/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 444/500
# 4/4 - 1s - loss: 0.0458 - accuracy: 0.9831
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 445/500
# 4/4 - 1s - loss: 0.0509 - accuracy: 0.9816
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 446/500
# 4/4 - 1s - loss: 0.0439 - accuracy: 0.9854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 447/500
# 4/4 - 1s - loss: 0.0382 - accuracy: 0.9876
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_447_0.988/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 448/500
# 4/4 - 1s - loss: 0.0467 - accuracy: 0.9852
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 449/500
# 4/4 - 1s - loss: 0.0454 - accuracy: 0.9835
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 450/500
# 4/4 - 1s - loss: 0.0488 - accuracy: 0.9830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 451/500
# 4/4 - 1s - loss: 0.0483 - accuracy: 0.9826
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 452/500
# 4/4 - 1s - loss: 0.0437 - accuracy: 0.9850
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 453/500
# 4/4 - 1s - loss: 0.0432 - accuracy: 0.9861
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 454/500
# 4/4 - 1s - loss: 0.0384 - accuracy: 0.9870
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 455/500
# 4/4 - 1s - loss: 0.0462 - accuracy: 0.9847
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 456/500
# 4/4 - 1s - loss: 0.0419 - accuracy: 0.9857
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 457/500
# 4/4 - 1s - loss: 0.0455 - accuracy: 0.9866
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 458/500
# 4/4 - 1s - loss: 0.0400 - accuracy: 0.9864
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 459/500
# 4/4 - 1s - loss: 0.0421 - accuracy: 0.9861
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 460/500
# 4/4 - 1s - loss: 0.0446 - accuracy: 0.9851
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 461/500
# 4/4 - 1s - loss: 0.0432 - accuracy: 0.9855
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 462/500
# 4/4 - 1s - loss: 0.0498 - accuracy: 0.9839
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 463/500
# 4/4 - 1s - loss: 0.0458 - accuracy: 0.9852
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 464/500
# 4/4 - 1s - loss: 0.0475 - accuracy: 0.9844
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 465/500
# 4/4 - 1s - loss: 0.0450 - accuracy: 0.9855
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 466/500
# 4/4 - 1s - loss: 0.0444 - accuracy: 0.9860
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 467/500
# 4/4 - 1s - loss: 0.0428 - accuracy: 0.9873
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 468/500
# 4/4 - 1s - loss: 0.0455 - accuracy: 0.9847
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 469/500
# 4/4 - 1s - loss: 0.0412 - accuracy: 0.9866
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 470/500
# 4/4 - 1s - loss: 0.0499 - accuracy: 0.9820
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 471/500
# 4/4 - 1s - loss: 0.0408 - accuracy: 0.9864
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 472/500
# 4/4 - 1s - loss: 0.0465 - accuracy: 0.9851
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 473/500
# 4/4 - 1s - loss: 0.0454 - accuracy: 0.9839
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 474/500
# 4/4 - 1s - loss: 0.0481 - accuracy: 0.9838
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 475/500
# 4/4 - 1s - loss: 0.0478 - accuracy: 0.9854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 476/500
# 4/4 - 1s - loss: 0.0368 - accuracy: 0.9882
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_476_0.988/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 477/500
# 4/4 - 1s - loss: 0.0456 - accuracy: 0.9857
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 478/500
# 4/4 - 1s - loss: 0.0430 - accuracy: 0.9854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 479/500
# 4/4 - 1s - loss: 0.0403 - accuracy: 0.9856
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 480/500
# 4/4 - 1s - loss: 0.0508 - accuracy: 0.9847
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 481/500
# 4/4 - 1s - loss: 0.0390 - accuracy: 0.9860
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 482/500
# 4/4 - 1s - loss: 0.0435 - accuracy: 0.9874
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 483/500
# 4/4 - 1s - loss: 0.0440 - accuracy: 0.9846
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 484/500
# 4/4 - 1s - loss: 0.0386 - accuracy: 0.9859
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 485/500
# 4/4 - 1s - loss: 0.0443 - accuracy: 0.9859
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 486/500
# 4/4 - 1s - loss: 0.0384 - accuracy: 0.9869
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 487/500
# 4/4 - 1s - loss: 0.0405 - accuracy: 0.9855
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 488/500
# 4/4 - 1s - loss: 0.0329 - accuracy: 0.9895
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_488_0.990/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 489/500
# 4/4 - 1s - loss: 0.0432 - accuracy: 0.9850
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 490/500
# 4/4 - 1s - loss: 0.0386 - accuracy: 0.9873
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 491/500
# 4/4 - 1s - loss: 0.0406 - accuracy: 0.9856
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 492/500
# 4/4 - 1s - loss: 0.0368 - accuracy: 0.9885
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 493/500
# 4/4 - 1s - loss: 0.0385 - accuracy: 0.9874
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 494/500
# 4/4 - 1s - loss: 0.0375 - accuracy: 0.9872
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 495/500
# 4/4 - 1s - loss: 0.0445 - accuracy: 0.9861
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 496/500
# 4/4 - 1s - loss: 0.0464 - accuracy: 0.9834
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 497/500
# 4/4 - 1s - loss: 0.0466 - accuracy: 0.9846
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 498/500
# 4/4 - 1s - loss: 0.0431 - accuracy: 0.9857
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 499/500
# 4/4 - 1s - loss: 0.0404 - accuracy: 0.9860
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 500/500
# 4/4 - 1s - loss: 0.0390 - accuracy: 0.9870
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_saved_model_after_fit/assets
# 27/27 [==============================] - 0s 6ms/step - loss: 1.8230 - accuracy: 0.7308

# %%
# % !zip -r ./content/j2nd_cnn.zip ./content/cnn_noTest_20210516_model_488_0.990/
# zip -r j2nd_cnn.zip /content/cnn_noTest_20210516_model_488_0.990/
# Out:
# UsageError: Line magic function `%zip` not found.

# %%
from google.colab import files
files.download("/content/j2nd_cnn.zip")
