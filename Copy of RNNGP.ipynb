# %% [markdown]
# **To-do List**
#
#
# *   Current model
#   *   Issue with *class_weight* when fitting the model
#   * LSTM parameters to choose
#   * Add regularisation terms
# *   RNN-GP
#   * Obtain the dense layers from the model
#   * Use them as features into a GP
#   *  Derive metrics (Accuracy) from GPFlow output
#   *  Multi-output GP (base class and class)

# %% [markdown]
# Utilities

# %%
import tensorflow as tf
import numpy as np
from keras.layers import  Dense, Flatten, Activation, Dropout, Embedding, Conv1D, Conv2D, MaxPooling2D, MaxPooling1D, Concatenate, BatchNormalization, GaussianNoise
from keras.layers import LSTM, TimeDistributed, Permute, Reshape, Lambda, RepeatVector, merge, Input, Multiply, SimpleRNN, GRU, LeakyReLU
from keras.utils import np_utils
from keras.layers.wrappers import  Bidirectional
import h5py as h5
import matplotlib.pyplot as plt
from keras.models import Model, Sequential
from keras_self_attention import SeqSelfAttention, SeqWeightedAttention

# %%
pip install keras_self_attention
# Out:
# Collecting keras_self_attention
#   Downloading https://files.pythonhosted.org/packages/c3/34/e21dc6adcdab2be03781bde78c6c5d2b2136d35a1dd3e692d7e160ba062a/keras-self-attention-0.49.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras_self_attention) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras_self_attention) (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras_self_attention) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras_self_attention) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras_self_attention) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras_self_attention) (1.15.0)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.49.0-cp37-none-any.whl size=19468 sha256=21ecd3da96554ed24adbea575196a37ad7ee42b4a022541d0b7a6ce4e4b7ee34
#   Stored in directory: /root/.cache/pip/wheels/6f/9d/c5/26693a5092d9313daeae94db04818fc0a2b7a48ea381989f34
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.49.0

# %% [markdown]
# Train and Test Data

# %%
INPUT_DIM = 8    # 
TIME_STEPS = 500  # The step of RNN

hf_Train = h5.File('/content/sample_data/Fold_10_Train_Data_500.h5', 'r')
hf_Test = h5.File('/content/sample_data/Fold_10_Test_Data_500.h5', 'r')

X_train = hf_Train['Train_Data'] # Get train set
X_train = np.array(X_train)
Y_train = hf_Train['Label']      # Get train label
Y_train = np.array(Y_train)

X_test = hf_Test['Train_Data']     # Get test set
X_test = np.array(X_test)
Y_test = hf_Test['Label']       # Get test label
Y_test = np.array(Y_test)

Y_train = np_utils.to_categorical(Y_train, 13)  # Process the label of tain
Y_test = np_utils.to_categorical(Y_test, 13)    #  Process the label of test

# %%
X_train.shape
# Out:
# (5688, 500, 8)

# %% [markdown]
# Attention Mechanism
#
#
# *   Could be replaced with
#    * *from keras_self_attention import SeqSelfAttention, SeqWeightedAttention*
#    * *model.add(SeqWeightedAttention())*
# * What about multi-head attention?

# %%
def attention_3d_block(inputs): # Attention Mechanism
    input_dim = int(inputs.shape[2])
    a = Permute((2, 1))(inputs)
    a = Reshape((input_dim, TIME_STEPS))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(TIME_STEPS, activation='softmax', kernel_initializer='RandomNormal', bias_initializer='zeros')(a)
    a_probs = Permute((2, 1), name='attention_vec')(a)
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

# %% [markdown]
# LSTM

# %%
def model_attention_applied_after_lstm(): # Model
    inputs = Input(shape=(TIME_STEPS, INPUT_DIM,))
    lstm_units = 128
    lstm_out = Bidirectional(LSTM(lstm_units, return_sequences=True, kernel_initializer='RandomNormal', dropout= 0.3, recurrent_dropout = 0.3, recurrent_initializer='RandomNormal', bias_initializer='zero'))(inputs)
    attention_mul = attention_3d_block(lstm_out)
    attention_mul = Flatten()(attention_mul)
    dense_one = Dense(128, kernel_initializer='RandomNormal', bias_initializer='zeros', activation='relu')(attention_mul)
    dense_one = Dropout(0.4)(dense_one)
    dense_two = Dense(64, kernel_initializer='RandomNormal', bias_initializer='zeros', activation='relu')(dense_one)
    dense_two = Dropout(0.4)(dense_two)
    output = Dense(13, activation='softmax')(dense_two)
    model = Model([inputs], output)
    return model

# %% [markdown]
# CNN

# %%
def model_with_cnn(input_shape):
    model = Sequential([
        Conv1D(128, 3, padding = 'same', input_shape = input_shape),
        LeakyReLU(),
        MaxPooling1D(3),
        BatchNormalization(),
        GaussianNoise(0.05),
        #Bidirectional(GRU(128, return_sequences=True, kernel_initializer='RandomNormal', dropout= 0.3, recurrent_dropout = 0.3, recurrent_initializer='RandomNormal', bias_initializer='zero')),
        Conv1D(128, 3, padding = 'same'),
        LeakyReLU(),
        Conv1D(128, 3, padding = 'same'),
        LeakyReLU(),
        MaxPooling1D(3),
        BatchNormalization(),
        GaussianNoise(0.05),
        Conv1D(256,3, padding = 'same'),
        LeakyReLU(),
        Conv1D(256,3, padding = 'same'),
        LeakyReLU(),
        MaxPooling1D(3),
        BatchNormalization(),
        GaussianNoise(0.05),
        Flatten(),
        Dense(128, kernel_initializer='RandomNormal', bias_initializer='zeros', activation='relu'),
        Dropout(0.2),
        Dense(64, kernel_initializer='RandomNormal', bias_initializer='zeros', activation='relu'),
        Dropout(0.2),
        Dense(13, activation='softmax')
    ])
    return model

# %% [markdown]
# The improved architecture is composed of 5 CNN layers interleaved with batch normalization, Leaky ReLU activation, and max-pooling. Gaussian Noise to reduce overfitting is added every 2 CNN layers and a dropout rate at 20% is added after the last CNN layer.
#
# The network is completed with two dense layers, respectively of 128 and 64 units,to reduce input dimensions, and a final softmax layer for the output class. AMSGrad optimization with a learning rate at 0.0005 has been adopted in the learning step.

# %%
def model_with_rnn(input_shape):
    
    #RNN part
    inputs = Input(shape=(TIME_STEPS, INPUT_DIM,))
    lstm_units = 128
    lstm_one = Bidirectional(GRU(lstm_units, return_sequences=True, kernel_initializer='RandomNormal', dropout= 0.5, recurrent_dropout = 0.5, recurrent_initializer='RandomNormal', bias_initializer='zero'))(inputs)
    lstm_two = Bidirectional(GRU(lstm_units, return_sequences=True, kernel_initializer='RandomNormal', dropout= 0.5, recurrent_dropout = 0.5, recurrent_initializer='RandomNormal', bias_initializer='zero'))(lstm_one)
    lstm_two = GaussianNoise(0.05)(lstm_two)
    attention = SeqWeightedAttention()(lstm_two)
    #attention_mul = attention_3d_block(lstm_two)
    attention = Flatten()(attention)
    rnnoutput = Dense(256,kernel_initializer='RandomNormal', bias_initializer='zeros')(attention)
    rnnoutput = Dropout(0.3)(rnnoutput)

    #CNN part
    conv1 = Conv1D(64, 3, padding = 'same', input_shape = input_shape)(inputs)
    conv1 = LeakyReLU()(conv1)
    max1 = MaxPooling1D(3)(conv1)
    max1 = BatchNormalization()(max1)
    max1 = GaussianNoise(0.05)(max1)
    conv2 = Conv1D(128, 3, padding = 'same')(max1)
    conv2 = LeakyReLU()(conv2)
    conv3 = Conv1D(128, 3, padding = 'same')(conv2)
    conv3 = LeakyReLU()(conv3)
    max2 = MaxPooling1D(3)(conv3)
    max2 = BatchNormalization()(max2)
    max2 = GaussianNoise(0.05)(max2)
    conv4 = Conv1D(256,3, padding = 'same')(max2)
    conv4 = LeakyReLU()(conv4)
    conv5 = Conv1D(256,3, padding = 'same')(conv4)
    conv5 = LeakyReLU()(conv5)
    max3 = MaxPooling1D(3)(conv5)
    max3 = BatchNormalization()(max3)
    max3 = GaussianNoise(0.05)(max3)
    max3 = Flatten()(max3)
    cnnoutput = Dense(256,kernel_initializer='RandomNormal', bias_initializer='zeros')(max3)
    cnnoutput = LeakyReLU()(cnnoutput)
    cnnoutput = Dropout(0.3)(cnnoutput)

    #Concatenated output
    jointoutput = tf.keras.layers.Concatenate()([rnnoutput,cnnoutput])

    #Dense Feed-forward
    dense_one = Dense(128, kernel_initializer='RandomNormal', bias_initializer='zeros')(jointoutput)
    dense_one = LeakyReLU()(dense_one)
    dense_one = Dropout(0.3)(dense_one)
    dense_two = Dense(64, kernel_initializer='RandomNormal', bias_initializer='zeros')(dense_one)
    dense_two = LeakyReLU()(dense_two)
    dense_two = Dropout(0.3)(dense_two)
    
    #Output
    output = Dense(13, activation='softmax')(dense_two)
    model = Model([inputs], output)
    return model
    
    # model = Sequential([
    #     Bidirectional(GRU(128, return_sequences = True, dropout= 0.5, recurrent_dropout = 0.5, activation = 'relu', input_shape = input_shape)),
    #     Bidirectional(GRU(128, return_sequences = True, dropout = 0.5, recurrent_dropout = 0.5, activation = 'relu')),
    #     Bidirectional(GRU(64, dropout = 0.5, recurrent_dropout = 0.5, activation = 'relu')),
    #     SeqWeightedAttention(),
    #     Flatten(),
    #     Dense(128, kernel_initializer='RandomNormal', bias_initializer='zeros', activation='relu'),
    #     Dropout(0.5),
    #     Dense(64, kernel_initializer='RandomNormal', bias_initializer='zeros', activation='relu'),
    #     Dropout(0.5),
    #     Dense(13, activation='softmax')
    # ])
    # return model

# %% [markdown]
# Deep RNN with Attention
#
#
# *   GRU instead of LSTM

# %%
def model_with_pure_rnn(input_shape):
    
    #RNN part
    inputs = Input(shape=(TIME_STEPS, INPUT_DIM,))
    lstm_units = 128
    lstm_one = Bidirectional(GRU(lstm_units, return_sequences=True, kernel_initializer='RandomNormal', dropout= 0.5, recurrent_dropout = 0.5, recurrent_initializer='RandomNormal', bias_initializer='zero'))(inputs)
    lstm_two = Bidirectional(GRU(lstm_units, return_sequences=True, kernel_initializer='RandomNormal', dropout= 0.5, recurrent_dropout = 0.5, recurrent_initializer='RandomNormal', bias_initializer='zero'))(lstm_one)
    lstm_two = GaussianNoise(0.05)(lstm_two)
    attention = SeqWeightedAttention()(lstm_two)
    #attention_mul = attention_3d_block(lstm_two)
    attention = Flatten()(attention)
    rnnoutput = Dense(256,kernel_initializer='RandomNormal', bias_initializer='zeros')(attention)
    rnnoutput = Dropout(0.3)(rnnoutput)

    #Dense Feed-forward
    dense_one = Dense(128, kernel_initializer='RandomNormal', bias_initializer='zeros')(rnnoutput)
    dense_one = LeakyReLU()(dense_one)
    dense_one = Dropout(0.3)(dense_one)
    dense_two = Dense(64, kernel_initializer='RandomNormal', bias_initializer='zeros')(dense_one)
    dense_two = LeakyReLU()(dense_two)
    dense_two = Dropout(0.3)(dense_two)

    #Output
    output = Dense(13, activation='softmax')(dense_two)
    model = Model([inputs], output)
    return model

# %%
sum(np.mean(Y_train, axis=0))
# Out:
# array([0.07911392, 0.07911392, 0.07911392, 0.07911392, 0.07911392,
#        0.07911392, 0.07911392, 0.07911392, 0.07911392, 0.07911392,
#        0.05063291, 0.07911392, 0.07911392], dtype=float32)

# %% [markdown]
# Model Fit

# %%
m = model_attention_applied_after_lstm()
m.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
history = m.fit(X_train, Y_train, batch_size=128, epochs= 50, class_weight= None, validation_data=(X_test, Y_test)) # Train 50 epochs
m.save("Tenth_Fold_New_Model_500_8") #Save the model
# Out:
# Epoch 1/50
# 45/45 [==============================] - 114s 2s/step - loss: 2.5093 - accuracy: 0.1326 - val_loss: 2.0016 - val_accuracy: 0.3085
# Epoch 2/50
# 45/45 [==============================] - 109s 2s/step - loss: 2.0580 - accuracy: 0.2778 - val_loss: 1.8281 - val_accuracy: 0.3671
# Epoch 3/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.9218 - accuracy: 0.3309 - val_loss: 1.7875 - val_accuracy: 0.3782
# Epoch 4/50
# 45/45 [==============================] - 107s 2s/step - loss: 1.8920 - accuracy: 0.3495 - val_loss: 1.7314 - val_accuracy: 0.4241
# Epoch 5/50
# 45/45 [==============================] - 107s 2s/step - loss: 1.8343 - accuracy: 0.3827 - val_loss: 1.7368 - val_accuracy: 0.3861
# Epoch 6/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.8502 - accuracy: 0.3699 - val_loss: 1.7341 - val_accuracy: 0.3987
# Epoch 7/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.8005 - accuracy: 0.3773 - val_loss: 1.6666 - val_accuracy: 0.4241
# Epoch 8/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.7899 - accuracy: 0.3903 - val_loss: 1.6771 - val_accuracy: 0.4209
# Epoch 9/50
# 45/45 [==============================] - 111s 2s/step - loss: 1.7609 - accuracy: 0.3957 - val_loss: 1.6586 - val_accuracy: 0.4114
# Epoch 10/50
# 45/45 [==============================] - 112s 2s/step - loss: 1.7305 - accuracy: 0.4208 - val_loss: 1.6164 - val_accuracy: 0.4367
# Epoch 11/50
# 45/45 [==============================] - 113s 3s/step - loss: 1.6756 - accuracy: 0.4440 - val_loss: 1.5537 - val_accuracy: 0.4446
# Epoch 12/50
# 45/45 [==============================] - 115s 3s/step - loss: 1.6393 - accuracy: 0.4531 - val_loss: 1.4803 - val_accuracy: 0.4778
# Epoch 13/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.6007 - accuracy: 0.4496 - val_loss: 1.4609 - val_accuracy: 0.4668
# Epoch 14/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.5721 - accuracy: 0.4672 - val_loss: 1.4175 - val_accuracy: 0.4873
# Epoch 15/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.5208 - accuracy: 0.4786 - val_loss: 1.3836 - val_accuracy: 0.4889
# Epoch 16/50
# 45/45 [==============================] - 110s 2s/step - loss: 1.5156 - accuracy: 0.4937 - val_loss: 1.3695 - val_accuracy: 0.5032
# Epoch 17/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.4783 - accuracy: 0.4900 - val_loss: 1.3108 - val_accuracy: 0.5364
# Epoch 18/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.4333 - accuracy: 0.5155 - val_loss: 1.2647 - val_accuracy: 0.5443
# Epoch 19/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.3826 - accuracy: 0.5295 - val_loss: 1.2362 - val_accuracy: 0.5744
# Epoch 20/50
# 45/45 [==============================] - 110s 2s/step - loss: 1.3715 - accuracy: 0.5337 - val_loss: 1.1455 - val_accuracy: 0.5918
# Epoch 21/50
# 45/45 [==============================] - 110s 2s/step - loss: 1.2808 - accuracy: 0.5712 - val_loss: 1.0742 - val_accuracy: 0.5949
# Epoch 22/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.1905 - accuracy: 0.6003 - val_loss: 1.0114 - val_accuracy: 0.6535
# Epoch 23/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.1637 - accuracy: 0.6136 - val_loss: 0.9637 - val_accuracy: 0.6630
# Epoch 24/50
# 45/45 [==============================] - 109s 2s/step - loss: 1.1384 - accuracy: 0.6190 - val_loss: 0.9050 - val_accuracy: 0.6994
# Epoch 25/50
# 45/45 [==============================] - 108s 2s/step - loss: 1.0430 - accuracy: 0.6476 - val_loss: 0.8647 - val_accuracy: 0.6915
# Epoch 26/50
# 45/45 [==============================] - 110s 2s/step - loss: 1.0019 - accuracy: 0.6534 - val_loss: 0.8594 - val_accuracy: 0.6994
# Epoch 27/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.9766 - accuracy: 0.6764 - val_loss: 0.8021 - val_accuracy: 0.7120
# Epoch 28/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.9063 - accuracy: 0.6956 - val_loss: 0.8319 - val_accuracy: 0.6978
# Epoch 29/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.8875 - accuracy: 0.7022 - val_loss: 0.7711 - val_accuracy: 0.7389
# Epoch 30/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.8374 - accuracy: 0.7242 - val_loss: 0.7286 - val_accuracy: 0.7516
# Epoch 31/50
# 45/45 [==============================] - 112s 2s/step - loss: 0.8108 - accuracy: 0.7221 - val_loss: 0.7470 - val_accuracy: 0.7500
# Epoch 32/50
# 45/45 [==============================] - 111s 2s/step - loss: 0.8171 - accuracy: 0.7335 - val_loss: 0.7254 - val_accuracy: 0.7437
# Epoch 33/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.7954 - accuracy: 0.7403 - val_loss: 0.7175 - val_accuracy: 0.7627
# Epoch 34/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.7113 - accuracy: 0.7604 - val_loss: 0.7309 - val_accuracy: 0.7642
# Epoch 35/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.6829 - accuracy: 0.7736 - val_loss: 0.7307 - val_accuracy: 0.7532
# Epoch 36/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.6584 - accuracy: 0.7745 - val_loss: 0.7198 - val_accuracy: 0.7753
# Epoch 37/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.6084 - accuracy: 0.7915 - val_loss: 0.6937 - val_accuracy: 0.7737
# Epoch 38/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.5663 - accuracy: 0.8109 - val_loss: 0.7028 - val_accuracy: 0.7816
# Epoch 39/50
# 45/45 [==============================] - 111s 2s/step - loss: 0.5482 - accuracy: 0.8137 - val_loss: 0.6641 - val_accuracy: 0.7737
# Epoch 40/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.5253 - accuracy: 0.8222 - val_loss: 0.7305 - val_accuracy: 0.7816
# Epoch 41/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.5333 - accuracy: 0.8231 - val_loss: 0.7060 - val_accuracy: 0.7722
# Epoch 42/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.4877 - accuracy: 0.8413 - val_loss: 0.7001 - val_accuracy: 0.7959
# Epoch 43/50
# 45/45 [==============================] - 108s 2s/step - loss: 0.4476 - accuracy: 0.8562 - val_loss: 0.7056 - val_accuracy: 0.7991
# Epoch 44/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.4546 - accuracy: 0.8447 - val_loss: 0.7207 - val_accuracy: 0.7896
# Epoch 45/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.4147 - accuracy: 0.8619 - val_loss: 0.7159 - val_accuracy: 0.7864
# Epoch 46/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.4136 - accuracy: 0.8691 - val_loss: 0.7626 - val_accuracy: 0.7848
# Epoch 47/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.4135 - accuracy: 0.8650 - val_loss: 0.7537 - val_accuracy: 0.7880
# Epoch 48/50
# 45/45 [==============================] - 109s 2s/step - loss: 0.3687 - accuracy: 0.8868 - val_loss: 0.7645 - val_accuracy: 0.7690
# Epoch 49/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.3517 - accuracy: 0.8871 - val_loss: 0.7471 - val_accuracy: 0.7816
# Epoch 50/50
# 45/45 [==============================] - 110s 2s/step - loss: 0.3378 - accuracy: 0.8884 - val_loss: 0.7454 - val_accuracy: 0.7880
# INFO:tensorflow:Assets written to: Tenth_Fold_New_Model_500_8/assets

# %%
input_shape = X_train[0].shape
mCNN = model_with_cnn(input_shape)
mCNN.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
historyCNN = mCNN.fit(X_train, Y_train, batch_size=128, epochs= 50, class_weight= None, validation_data=(X_test, Y_test)) # Train 50 epochs
mCNN.save("CNN_Tenth_Fold_New_Model_500_8") #Save the model
# Out:
# Epoch 1/50
# 45/45 [==============================] - 18s 374ms/step - loss: 2.2390 - accuracy: 0.2817 - val_loss: 2.5192 - val_accuracy: 0.0854
# Epoch 2/50
# 45/45 [==============================] - 17s 368ms/step - loss: 1.3760 - accuracy: 0.5481 - val_loss: 2.9375 - val_accuracy: 0.0791
# Epoch 3/50
# 45/45 [==============================] - 16s 364ms/step - loss: 0.8869 - accuracy: 0.7098 - val_loss: 3.9537 - val_accuracy: 0.0791
# Epoch 4/50
# 45/45 [==============================] - 16s 363ms/step - loss: 0.6912 - accuracy: 0.7789 - val_loss: 3.9978 - val_accuracy: 0.1028
# Epoch 5/50
# 45/45 [==============================] - 17s 372ms/step - loss: 0.4983 - accuracy: 0.8339 - val_loss: 4.5217 - val_accuracy: 0.0807
# Epoch 6/50
# 45/45 [==============================] - 17s 375ms/step - loss: 0.3903 - accuracy: 0.8695 - val_loss: 4.2390 - val_accuracy: 0.0807
# Epoch 7/50
# 45/45 [==============================] - 16s 365ms/step - loss: 0.2636 - accuracy: 0.9176 - val_loss: 4.3966 - val_accuracy: 0.0997
# Epoch 8/50
# 45/45 [==============================] - 16s 361ms/step - loss: 0.1924 - accuracy: 0.9378 - val_loss: 2.8866 - val_accuracy: 0.2215
# Epoch 9/50
# 45/45 [==============================] - 17s 371ms/step - loss: 0.1621 - accuracy: 0.9453 - val_loss: 1.8509 - val_accuracy: 0.4699
# Epoch 10/50
# 45/45 [==============================] - 16s 361ms/step - loss: 0.1054 - accuracy: 0.9649 - val_loss: 1.3432 - val_accuracy: 0.6203
# Epoch 11/50
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0830 - accuracy: 0.9740 - val_loss: 1.1491 - val_accuracy: 0.6661
# Epoch 12/50
# 45/45 [==============================] - 16s 366ms/step - loss: 0.0654 - accuracy: 0.9817 - val_loss: 0.9958 - val_accuracy: 0.7468
# Epoch 13/50
# 45/45 [==============================] - 17s 372ms/step - loss: 0.0693 - accuracy: 0.9780 - val_loss: 0.7861 - val_accuracy: 0.7896
# Epoch 14/50
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0589 - accuracy: 0.9833 - val_loss: 0.8976 - val_accuracy: 0.7880
# Epoch 15/50
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0664 - accuracy: 0.9787 - val_loss: 0.7458 - val_accuracy: 0.8291
# Epoch 16/50
# 45/45 [==============================] - 17s 371ms/step - loss: 0.0468 - accuracy: 0.9860 - val_loss: 0.8320 - val_accuracy: 0.8228
# Epoch 17/50
# 45/45 [==============================] - 17s 369ms/step - loss: 0.0389 - accuracy: 0.9871 - val_loss: 0.7598 - val_accuracy: 0.8418
# Epoch 18/50
# 45/45 [==============================] - 17s 369ms/step - loss: 0.0357 - accuracy: 0.9886 - val_loss: 0.7069 - val_accuracy: 0.8513
# Epoch 19/50
# 45/45 [==============================] - 17s 369ms/step - loss: 0.0466 - accuracy: 0.9850 - val_loss: 0.8671 - val_accuracy: 0.8291
# Epoch 20/50
# 45/45 [==============================] - 17s 371ms/step - loss: 0.0388 - accuracy: 0.9888 - val_loss: 0.8136 - val_accuracy: 0.8275
# Epoch 21/50
# 45/45 [==============================] - 17s 372ms/step - loss: 0.0445 - accuracy: 0.9860 - val_loss: 0.8814 - val_accuracy: 0.8133
# Epoch 22/50
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0589 - accuracy: 0.9824 - val_loss: 0.9468 - val_accuracy: 0.8054
# Epoch 23/50
# 45/45 [==============================] - 17s 369ms/step - loss: 0.0374 - accuracy: 0.9888 - val_loss: 0.7892 - val_accuracy: 0.8497
# Epoch 24/50
# 45/45 [==============================] - 17s 367ms/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.8704 - val_accuracy: 0.8323
# Epoch 25/50
# 45/45 [==============================] - 16s 366ms/step - loss: 0.0310 - accuracy: 0.9912 - val_loss: 0.8844 - val_accuracy: 0.8307
# Epoch 26/50
# 45/45 [==============================] - 16s 363ms/step - loss: 0.0255 - accuracy: 0.9928 - val_loss: 0.8691 - val_accuracy: 0.8465
# Epoch 27/50
# 45/45 [==============================] - 16s 358ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 1.1185 - val_accuracy: 0.8070
# Epoch 28/50
# 45/45 [==============================] - 16s 363ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 0.7862 - val_accuracy: 0.8418
# Epoch 29/50
# 45/45 [==============================] - 16s 360ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0.8995 - val_accuracy: 0.8354
# Epoch 30/50
# 45/45 [==============================] - 16s 358ms/step - loss: 0.0207 - accuracy: 0.9929 - val_loss: 0.8543 - val_accuracy: 0.8386
# Epoch 31/50
# 45/45 [==============================] - 16s 363ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 1.1604 - val_accuracy: 0.7991
# Epoch 32/50
# 45/45 [==============================] - 16s 358ms/step - loss: 0.0427 - accuracy: 0.9854 - val_loss: 0.8753 - val_accuracy: 0.8370
# Epoch 33/50
# 45/45 [==============================] - 16s 360ms/step - loss: 0.0299 - accuracy: 0.9921 - val_loss: 0.9593 - val_accuracy: 0.8117
# Epoch 34/50
# 45/45 [==============================] - 16s 359ms/step - loss: 0.0269 - accuracy: 0.9915 - val_loss: 0.9268 - val_accuracy: 0.8307
# Epoch 35/50
# 45/45 [==============================] - 16s 358ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.9713 - val_accuracy: 0.8149
# Epoch 36/50
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0278 - accuracy: 0.9902 - val_loss: 0.9049 - val_accuracy: 0.8386
# Epoch 37/50
# 45/45 [==============================] - 16s 363ms/step - loss: 0.0194 - accuracy: 0.9928 - val_loss: 0.9251 - val_accuracy: 0.8323
# Epoch 38/50
# 45/45 [==============================] - 17s 370ms/step - loss: 0.0193 - accuracy: 0.9939 - val_loss: 0.9291 - val_accuracy: 0.8323
# Epoch 39/50
# 45/45 [==============================] - 17s 375ms/step - loss: 0.0236 - accuracy: 0.9932 - val_loss: 0.8441 - val_accuracy: 0.8354
# Epoch 40/50
# 45/45 [==============================] - 17s 370ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.8794 - val_accuracy: 0.8449
# Epoch 41/50
# 45/45 [==============================] - 16s 362ms/step - loss: 0.0209 - accuracy: 0.9943 - val_loss: 1.0686 - val_accuracy: 0.8212
# Epoch 42/50
# 45/45 [==============================] - 16s 366ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 1.1014 - val_accuracy: 0.8291
# Epoch 43/50
# 45/45 [==============================] - 16s 361ms/step - loss: 0.0288 - accuracy: 0.9880 - val_loss: 1.0648 - val_accuracy: 0.8275
# Epoch 44/50
# 45/45 [==============================] - 16s 362ms/step - loss: 0.0316 - accuracy: 0.9911 - val_loss: 1.1472 - val_accuracy: 0.8259
# Epoch 45/50
# 45/45 [==============================] - 16s 367ms/step - loss: 0.0341 - accuracy: 0.9891 - val_loss: 1.0194 - val_accuracy: 0.8165
# Epoch 46/50
# 45/45 [==============================] - 17s 368ms/step - loss: 0.0291 - accuracy: 0.9910 - val_loss: 1.1469 - val_accuracy: 0.8006
# Epoch 47/50
# 45/45 [==============================] - 17s 372ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 1.0191 - val_accuracy: 0.8259
# Epoch 48/50
# 45/45 [==============================] - 17s 377ms/step - loss: 0.0290 - accuracy: 0.9925 - val_loss: 0.9983 - val_accuracy: 0.8370
# Epoch 49/50
# 45/45 [==============================] - 17s 382ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 1.0873 - val_accuracy: 0.8259
# Epoch 50/50
# 45/45 [==============================] - 17s 373ms/step - loss: 0.0175 - accuracy: 0.9956 - val_loss: 1.1476 - val_accuracy: 0.8307
# INFO:tensorflow:Assets written to: CNN_Tenth_Fold_New_Model_500_8/assets

# %%
input_shape = X_train[0].shape
mRNN = model_with_rnn(input_shape)
mRNN.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
historyRNN = mRNN.fit(X_train, Y_train, batch_size=128, epochs= 50, class_weight= None, validation_data=(X_test, Y_test)) # Train 50 epochs
mRNN.save("RNN_Tenth_Fold_New_Model_500_8") #Save the model
# Out:
# Epoch 1/50
# 45/45 [==============================] - 246s 5s/step - loss: 2.3129 - accuracy: 0.2627 - val_loss: 2.4664 - val_accuracy: 0.0886
# Epoch 2/50
# 45/45 [==============================] - 235s 5s/step - loss: 1.3038 - accuracy: 0.5732 - val_loss: 2.9782 - val_accuracy: 0.0791
# Epoch 3/50
# 45/45 [==============================] - 234s 5s/step - loss: 0.9032 - accuracy: 0.6923 - val_loss: 3.2732 - val_accuracy: 0.1092
# Epoch 4/50
# 45/45 [==============================] - 232s 5s/step - loss: 0.6918 - accuracy: 0.7669 - val_loss: 3.5254 - val_accuracy: 0.0823
# Epoch 5/50
# 45/45 [==============================] - 232s 5s/step - loss: 0.5200 - accuracy: 0.8241 - val_loss: 2.9611 - val_accuracy: 0.1487
# Epoch 6/50
# 45/45 [==============================] - 231s 5s/step - loss: 0.3932 - accuracy: 0.8675 - val_loss: 2.5017 - val_accuracy: 0.1899
# Epoch 7/50
# 45/45 [==============================] - 231s 5s/step - loss: 0.2612 - accuracy: 0.9141 - val_loss: 2.7837 - val_accuracy: 0.3070
# Epoch 8/50
# 45/45 [==============================] - 231s 5s/step - loss: 0.1834 - accuracy: 0.9364 - val_loss: 1.7485 - val_accuracy: 0.4715
# Epoch 9/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.1436 - accuracy: 0.9551 - val_loss: 1.4839 - val_accuracy: 0.5633
# Epoch 10/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.1303 - accuracy: 0.9574 - val_loss: 1.0420 - val_accuracy: 0.6851
# Epoch 11/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0953 - accuracy: 0.9690 - val_loss: 0.8854 - val_accuracy: 0.7595
# Epoch 12/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0649 - accuracy: 0.9785 - val_loss: 0.7713 - val_accuracy: 0.8006
# Epoch 13/50
# 45/45 [==============================] - 232s 5s/step - loss: 0.0654 - accuracy: 0.9786 - val_loss: 0.7977 - val_accuracy: 0.7911
# Epoch 14/50
# 45/45 [==============================] - 238s 5s/step - loss: 0.0653 - accuracy: 0.9788 - val_loss: 0.8886 - val_accuracy: 0.8212
# Epoch 15/50
# 45/45 [==============================] - 236s 5s/step - loss: 0.0629 - accuracy: 0.9818 - val_loss: 0.9740 - val_accuracy: 0.8054
# Epoch 16/50
# 45/45 [==============================] - 236s 5s/step - loss: 0.0766 - accuracy: 0.9749 - val_loss: 0.8763 - val_accuracy: 0.8133
# Epoch 17/50
# 45/45 [==============================] - 233s 5s/step - loss: 0.1162 - accuracy: 0.9654 - val_loss: 0.9223 - val_accuracy: 0.8196
# Epoch 18/50
# 45/45 [==============================] - 232s 5s/step - loss: 0.0813 - accuracy: 0.9711 - val_loss: 1.1250 - val_accuracy: 0.8085
# Epoch 19/50
# 45/45 [==============================] - 232s 5s/step - loss: 0.0543 - accuracy: 0.9834 - val_loss: 0.9525 - val_accuracy: 0.8212
# Epoch 20/50
# 45/45 [==============================] - 232s 5s/step - loss: 0.0383 - accuracy: 0.9896 - val_loss: 1.0846 - val_accuracy: 0.8070
# Epoch 21/50
# 45/45 [==============================] - 231s 5s/step - loss: 0.0325 - accuracy: 0.9901 - val_loss: 1.1383 - val_accuracy: 0.7896
# Epoch 22/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0367 - accuracy: 0.9876 - val_loss: 1.1299 - val_accuracy: 0.8165
# Epoch 23/50
# 45/45 [==============================] - 231s 5s/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 1.0795 - val_accuracy: 0.8149
# Epoch 24/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0307 - accuracy: 0.9902 - val_loss: 1.0976 - val_accuracy: 0.8212
# Epoch 25/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0161 - accuracy: 0.9959 - val_loss: 1.5314 - val_accuracy: 0.7848
# Epoch 26/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0488 - accuracy: 0.9842 - val_loss: 1.3508 - val_accuracy: 0.7880
# Epoch 27/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0815 - accuracy: 0.9797 - val_loss: 1.0913 - val_accuracy: 0.8054
# Epoch 28/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0490 - accuracy: 0.9851 - val_loss: 0.9916 - val_accuracy: 0.8165
# Epoch 29/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0342 - accuracy: 0.9909 - val_loss: 1.2561 - val_accuracy: 0.7991
# Epoch 30/50
# 45/45 [==============================] - 228s 5s/step - loss: 0.0359 - accuracy: 0.9898 - val_loss: 1.1521 - val_accuracy: 0.7943
# Epoch 31/50
# 45/45 [==============================] - 228s 5s/step - loss: 0.0430 - accuracy: 0.9858 - val_loss: 1.2163 - val_accuracy: 0.8149
# Epoch 32/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0347 - accuracy: 0.9902 - val_loss: 1.1325 - val_accuracy: 0.8101
# Epoch 33/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0409 - accuracy: 0.9870 - val_loss: 1.0716 - val_accuracy: 0.8291
# Epoch 34/50
# 45/45 [==============================] - 230s 5s/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 1.3609 - val_accuracy: 0.8022
# Epoch 35/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0407 - accuracy: 0.9879 - val_loss: 1.1379 - val_accuracy: 0.8054
# Epoch 36/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0312 - accuracy: 0.9898 - val_loss: 1.2702 - val_accuracy: 0.8307
# Epoch 37/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0430 - accuracy: 0.9889 - val_loss: 1.2121 - val_accuracy: 0.8418
# Epoch 38/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0284 - accuracy: 0.9908 - val_loss: 1.1389 - val_accuracy: 0.8402
# Epoch 39/50
# 45/45 [==============================] - 228s 5s/step - loss: 0.0277 - accuracy: 0.9924 - val_loss: 1.3088 - val_accuracy: 0.8149
# Epoch 40/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 1.0144 - val_accuracy: 0.8291
# Epoch 41/50
# 45/45 [==============================] - 228s 5s/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 1.1479 - val_accuracy: 0.8291
# Epoch 42/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0197 - accuracy: 0.9926 - val_loss: 1.0195 - val_accuracy: 0.8418
# Epoch 43/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0181 - accuracy: 0.9951 - val_loss: 1.4673 - val_accuracy: 0.7959
# Epoch 44/50
# 45/45 [==============================] - 229s 5s/step - loss: 0.0241 - accuracy: 0.9932 - val_loss: 1.3593 - val_accuracy: 0.8038
# Epoch 45/50
# 45/45 [==============================] - 236s 5s/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 1.2935 - val_accuracy: 0.8054
# Epoch 46/50
# 45/45 [==============================] - 237s 5s/step - loss: 0.0424 - accuracy: 0.9896 - val_loss: 1.0534 - val_accuracy: 0.8117
# Epoch 47/50
# 45/45 [==============================] - 235s 5s/step - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.9295 - val_accuracy: 0.8370
# Epoch 48/50
# 25/45 [===============>..............] - ETA: 1:43 - loss: 0.0214 - accuracy: 0.9908

# %%
input_shape = X_train[0].shape
mRNNpure = model_with_pure_rnn(input_shape)
mRNNpure.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
historyRNN = mRNNpure.fit(X_train, Y_train, batch_size=128, epochs= 50, class_weight= None, validation_data=(X_test, Y_test)) # Train 50 epochs
mRNNpure.save("Pure_RNN_Tenth_Fold_New_Model_500_8") #Save the model
# Out:
# Epoch 1/50
# 45/45 [==============================] - 245s 5s/step - loss: 2.4555 - accuracy: 0.1105 - val_loss: 2.2058 - val_accuracy: 0.2057
# Epoch 2/50
# 45/45 [==============================] - 226s 5s/step - loss: 2.1885 - accuracy: 0.2130 - val_loss: 1.9499 - val_accuracy: 0.3149
# Epoch 3/50
# 45/45 [==============================] - 227s 5s/step - loss: 2.0361 - accuracy: 0.2781 - val_loss: 1.8873 - val_accuracy: 0.3244
# Epoch 4/50
# 45/45 [==============================] - 230s 5s/step - loss: 1.9796 - accuracy: 0.3026 - val_loss: 1.8303 - val_accuracy: 0.3655
# Epoch 5/50
# 45/45 [==============================] - 223s 5s/step - loss: 1.9308 - accuracy: 0.3195 - val_loss: 1.8356 - val_accuracy: 0.3259
# Epoch 6/50
# 45/45 [==============================] - 222s 5s/step - loss: 1.9205 - accuracy: 0.3175 - val_loss: 1.7636 - val_accuracy: 0.3829
# Epoch 7/50
# 45/45 [==============================] - 221s 5s/step - loss: 1.8946 - accuracy: 0.3342 - val_loss: 1.7587 - val_accuracy: 0.3766
# Epoch 8/50
# 45/45 [==============================] - 223s 5s/step - loss: 1.8659 - accuracy: 0.3355 - val_loss: 1.6920 - val_accuracy: 0.4051
# Epoch 9/50
# 45/45 [==============================] - 221s 5s/step - loss: 1.8319 - accuracy: 0.3539 - val_loss: 1.6857 - val_accuracy: 0.3924
# Epoch 10/50
# 45/45 [==============================] - 219s 5s/step - loss: 1.8223 - accuracy: 0.3647 - val_loss: 1.6375 - val_accuracy: 0.4177
# Epoch 11/50
# 45/45 [==============================] - 219s 5s/step - loss: 1.8034 - accuracy: 0.3712 - val_loss: 1.5921 - val_accuracy: 0.4383
# Epoch 12/50
# 45/45 [==============================] - 221s 5s/step - loss: 1.7717 - accuracy: 0.3769 - val_loss: 1.5745 - val_accuracy: 0.4367
# Epoch 13/50
# 45/45 [==============================] - 219s 5s/step - loss: 1.7737 - accuracy: 0.3822 - val_loss: 1.5740 - val_accuracy: 0.4636
# Epoch 14/50
# 45/45 [==============================] - 220s 5s/step - loss: 1.7114 - accuracy: 0.3951 - val_loss: 1.5631 - val_accuracy: 0.4415
# Epoch 15/50
# 45/45 [==============================] - 218s 5s/step - loss: 1.7133 - accuracy: 0.4124 - val_loss: 1.5021 - val_accuracy: 0.4905
# Epoch 16/50
# 42/45 [===========================>..] - ETA: 14s - loss: 1.6731 - accuracy: 0.4131

# %% [markdown]
# Accessing Layers

# %%
m = tf.keras.models.load_model("Tenth_Fold_New_Model_500_8")
mCNN = tf.keras.models.load_model("CNN_Tenth_Fold_New_Model_500_8")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-5628702990db> in <module>()
# ----> 1 m = tf.keras.models.load_model("Tenth_Fold_New_Model_500_8")
#       2 mCNN = tf.keras.models.load_model("CNN_Tenth_Fold_New_Model_500_8")
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: Tenth_Fold_New_Model_500_8/{saved_model.pbtxt|saved_model.pb}

# %%
m.layers[11].output.shape
# Out:
# TensorShape([None, 64])

# %%
mCNN.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_46 (Conv1D)           (None, 500, 64)           1600
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 166, 64)           0
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 166, 128)          24704
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 166, 128)          49280
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 55, 128)           0
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 55, 256)           98560
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 55, 256)           196864
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 18, 256)           0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               589952
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_40 (Dense)             (None, 13)                845
# =================================================================
# Total params: 970,061
# Trainable params: 970,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
mCNN.layers[12].output.shape
# Out:
# TensorShape([None, 64])

# %%
X_train_temp = tf.reshape(X_train,[X_train.shape[0],X_train.shape[1]*X_train.shape[2]])
X_train_temp = np.array(X_train_temp, dtype = "float64")
X_test_temp = tf.reshape(X_test,[X_test.shape[0],X_test.shape[1]*X_test.shape[2]])
X_test_temp = np.array(X_test_temp, dtype = "float64")

# %%
X_test_temp.shape
# Out:
# (632, 4000)

# %%
new_temp_model_cnn = Model(mCNN.input, mCNN.layers[12].output)
new_temp_model_attention = Model(m.input, m.layers[11].output)

# %% [markdown]
# Creating Auxiliary Dataset

# %%
# At this point, we wish to create a new dataset for the GP process
Y_train_new = np.array(hf_Train['Label'], dtype='float64')
Y_test_new = np.array(hf_Test['Label'], dtype='float64')

# %%
X_train_cnn = np.array(new_temp_model_cnn.predict(X_train), dtype='float64')
X_train_cnn = np.array(X_train_cnn, dtype='float64')
X_test_cnn = new_temp_model_cnn.predict(X_test)
X_test_cnn = np.array(X_test_cnn, dtype='float64')

# %%
X_train_cnn.shape
# Out:
# (5688, 64)

# %%
X_train_attention = np.array(new_temp_model_attention.predict(X_train), dtype='float64')
X_train_attention = np.array(X_train_attention, dtype='float64')
X_test_attention = new_temp_model_attention.predict(X_test)
X_test_attention = np.array(X_test_attention, dtype='float64')

# %%
X_train_attention.shape
# Out:
# (5688, 64)

# %%
X_train_new = np.concatenate((X_train_cnn, X_train_attention), axis = 1)
X_test_new = np.concatenate((X_test_cnn, X_test_attention), axis = 1)

# %%
X_train_new.shape
# Out:
# (5688, 128)

# %% [markdown]
# Introducing Gaussian Process

# %%
import gpflow
import numpy as np

import matplotlib.pyplot as plt
import tensorflow as tf

import gpflow
from gpflow.utilities import ops, print_summary, set_trainable
from gpflow.config import set_default_float, default_float, set_default_summary_fmt
from gpflow.ci_utils import ci_niter

import warnings
warnings.filterwarnings("ignore")  # ignore DeprecationWarnings from tensorflow

# %matplotlib inline

set_default_float('float64')

#from tensorflow2_work.multiclass_classification import plot_posterior_predictions, colors

# reproducibility:
np.random.seed(0)
tf.random.set_seed(123)

data = (X_train_new, Y_train_new)

# %% [markdown]
# Declaring the SVGP model

# %%
# sum kernel: Matern32 + White
lengthscales = tf.convert_to_tensor([1.0] * X_train_new.shape[1], dtype=default_float())
kernel = gpflow.kernels.Matern32(lengthscales=lengthscales) #+ gpflow.kernels.White(variance=0.01)

# Robustmax Multiclass Likelihood
invlink = gpflow.likelihoods.RobustMax(13)  # Robustmax inverse link function
likelihood = gpflow.likelihoods.MultiClass(13, invlink=invlink)  # Multiclass likelihood
M = 80  # Number of inducing locations
Z = X_train_new[::M].copy()  # inducing inputs CHECK DIMENSIONS

mGP = gpflow.models.SVGP(
    kernel=kernel,
    likelihood=likelihood,
    inducing_variable=Z,
    num_latent_gps=13,
    whiten=True,
    q_diag=False,
)

# Only train the variational parameters
#set_trainable(mGP.kernel.kernels[1].variance, False)
#set_trainable(mGP.inducing_variable, False)
print_summary(mGP, fmt="notebook")
# Out:
# <table>
# <thead>
# <tr><th>name                           </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape       </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>SVGP.kernel.variance           </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()          </td><td>float64</td><td>1.0                                                </td></tr>
# <tr><td>SVGP.kernel.lengthscales       </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>(128,)      </td><td>float64</td><td>[1., 1., 1....                                     </td></tr>
# <tr><td>SVGP.likelihood.invlink.epsilon</td><td>Parameter</td><td>Sigmoid       </td><td>Beta   </td><td>False      </td><td>()          </td><td>float64</td><td>0.0010000000000000005                              </td></tr>
# <tr><td>SVGP.inducing_variable.Z       </td><td>Parameter</td><td>Identity      </td><td>       </td><td>True       </td><td>(72, 128)   </td><td>float64</td><td>[[0.00000000e+00, 1.10954475e+01, 0.00000000e+00...</td></tr>
# <tr><td>SVGP.q_mu                      </td><td>Parameter</td><td>Identity      </td><td>       </td><td>True       </td><td>(72, 13)    </td><td>float64</td><td>[[0., 0., 0....                                    </td></tr>
# <tr><td>SVGP.q_sqrt                    </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(13, 72, 72)</td><td>float64</td><td>[[[1., 0., 0....                                   </td></tr>
# </tbody>
# </table>

# %% [markdown]
# Running Inference

# %%
opt = gpflow.optimizers.Scipy()

opt_logs = opt.minimize(
    mGP.training_loss_closure(data), mGP.trainable_variables, options=dict(maxiter=ci_niter(10000))
)
print_summary(mGP, fmt="notebook")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-282e8954f662> in <module>()
# ----> 1 opt = gpflow.optimizers.Scipy()
#       2
#       3 opt_logs = opt.minimize(
#       4     mGP.training_loss_closure(data), mGP.trainable_variables, options=dict(maxiter=ci_niter(10000))
#       5 )
#
# NameError: name 'gpflow' is not defined

# %%
(Y_test_GP_mean, Y_test_GP_variance) = mGP.predict_y(X_test_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-091449e2236b> in <module>()
# ----> 1 (Y_test_GP_mean, Y_test_GP_variance) = mGP.predict_y(X_test_new)
#
# NameError: name 'mGP' is not defined

# %%
Y_test_pred = []
for i in range(X_test_new.shape[0]):
  Y_test_pred.append(np.argmax(Y_test_GP_mean.numpy()[i,]))
diffs = Y_test_pred - Y_test_new
test_acc = sum(1 for x in diffs if x == 0)/X_test_new.shape[0]
print(test_acc)
# Out:
# 0.8306962025316456

# %% [markdown]
# Plot
