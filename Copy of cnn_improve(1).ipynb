# %%
import tensorflow as tf
import site
import pandas as pd
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import  Dense, Flatten, Activation, Dropout, Embedding, Conv1D, Conv2D, MaxPooling2D, MaxPooling1D, Concatenate, BatchNormalization, GaussianNoise
from tensorflow.keras.layers import LSTM, TimeDistributed, Permute, Reshape, Lambda, RepeatVector, Input, Multiply, SimpleRNN, GRU, LeakyReLU
import os
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
pd.set_option('display.width', 400)
pd.set_option('display.max_columns', 40)

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import h5py as h5
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
import errno
import os
from collections import defaultdict
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.summary import create_file_writer
from sklearn.model_selection import train_test_split
import numpy as np
import itertools
import multiprocessing

# %%
def coShuffled_vectors(X, Y):
    if tf.shape(X)[0] == tf.shape(Y)[0]:
        test_idxs = tf.range(start=0, limit=tf.shape(X)[0], dtype=tf.int32)
        shuffled_test_idxs = tf.random.shuffle(test_idxs)
        return (tf.gather(X, shuffled_test_idxs), tf.gather(Y, shuffled_test_idxs))
    else:
        raise ValueError(f"0-dimension has to be the same {tf.shape(X)[0]} != {tf.shape(Y)[0]}")


def getNpArrayFromH5(hf_Data):
    X_train = hf_Data['Train_Data']  # Get train set
    X_train = np.array(X_train)
    Y_train = hf_Data['Label']  # Get train label
    Y_train = np.array(Y_train)
    return X_train, Y_train


# data extraction
def getData(is500=True, shuffle=False, ise2e=False, include_secondary=False, validation_split=None):
    if not include_secondary:
        hf_Train = h5.File(
            f'./data/{"e2e_Train_Data" if ise2e else "Fold_10_Train_Data"}_{str(500) if is500 else str(1000)}.h5', 'r')
        hf_Test = h5.File(
            f'./data/{"e2e_Test_Data" if ise2e else "Fold_10_Test_Data"}_{str(500) if is500 else str(1000)}.h5', 'r')
    else:
        hf_Train = h5.File(f'./e2e_Train_Secondary_Data_1136.h5', 'r')
        hf_Test = h5.File(f'./e2e_Test_Secondary_Data_1136.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    X_validation = Y_validation = None
    if validation_split is not None:
        # sklearn split shuffles anyway
        X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=validation_split)

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation


def getE2eData(is500=True, shuffle=False, include_secondary=False):
    if not include_secondary:
        hf_Train = h5.File(
            f'./e2e_Train_Data_{str(500) if is500 else str(1000)}.h5', 'r')
        hf_Test = h5.File(
            f'./e2e_Test_Data_{str(500) if is500 else str(1000)}.h5', 'r')
    else:
        hf_Train = h5.File(f'./e2e_Train_Secondary_Data_1136.h5', 'r')
        hf_Test = h5.File(f'./e2e_Test_Secondary_Data_1136.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    hf_Val = h5.File(f'./e2e_Val_Secondary_Data_1136.h5', 'r') if include_secondary else h5.File(
        f'./e2e_Val_Data_{str(500) if is500 else str(1000)}.h5', 'r')
    X_validation, Y_validation = getNpArrayFromH5(hf_Val)
    Y_validation = to_categorical(Y_validation, 13)  # Process the label of tain

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation


def plot_history(history):
    acc_keys = [k for k in history.history.keys() if k in ('accuracy', 'val_accuracy')]
    loss_keys = [k for k in history.history.keys() if not k in acc_keys]
    for k, v in history.history.items():
        if k in acc_keys:
            plt.figure(1)
            plt.plot(v)
        else:
            plt.figure(2)
            plt.plot(v)
    plt.figure(1)
    plt.title('Accuracy vs. epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(acc_keys, loc='lower right')
    plt.figure(2)
    plt.title('Loss vs. epochs')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loss_keys, loc='upper right')
    plt.show()


def get_layer_by_name(layers, name, return_first=True):
    matching_named_layers = [l for l in layers if l.name == name]
    if not matching_named_layers:
        return None
    return matching_named_layers[0] if return_first else matching_named_layers


def get_combined_features_from_models(
        to_combine,
        X_train, Y_train,
        X_test, Y_test,
        reverse_one_hot=False,
        normalize_X_func=None):
    models = []
    models_dict = {}
    X_trains_out = []
    X_test_out = []
    XY_dict = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: None))))

    if reverse_one_hot:
        Y_train_new = np.apply_along_axis(np.argmax, 1, Y_train) + 1
        Y_test_new = np.apply_along_axis(np.argmax, 1, Y_test) + 1
    else:
        Y_train_new = Y_train.copy()
        Y_test_new = Y_test.copy()

    for model_file_name, layer_name, kwargs in to_combine:
        model_here = None
        if isinstance(model_file_name, tf.keras.models.Model):
            model_here = model_file_name
            model_file_name = model_here.name
        else:
            if model_file_name in models_dict.keys():
                model_here = models_dict[model_file_name]
            else:
                model_here = tf.keras.models.load_model(model_file_name,
                                                        **kwargs) if kwargs is not None else tf.keras.models.load_model \
                    (model_file_name)

        features_model = Model(model_here.input,
                               get_layer_by_name(model_here.layers, layer_name).output)
        if normalize_X_func is None:
            X_trains_out.append(np.array(features_model.predict(X_train), dtype='float64'))
            X_test_out.append(np.array(features_model.predict(X_test), dtype='float64'))
        else:
            X_trains_out.append(np.array(normalize_X_func(features_model.predict(X_train)), dtype='float64'))
            X_test_out.append(np.array(normalize_X_func(features_model.predict(X_test)), dtype='float64'))
        XY_dict[model_file_name][layer_name]['Train']['X'] = X_trains_out[-1]
        XY_dict[model_file_name][layer_name]['Test']['X'] = X_test_out[-1]
        XY_dict[model_file_name][layer_name]['Train']['Y'] = Y_train_new
        XY_dict[model_file_name][layer_name]['Test']['Y'] = Y_test_new
        models.append(((model_file_name, layer_name), (model_here, features_model)))
        models_dict[model_file_name] = model_here

    X_train_new = np.concatenate(tuple(X_trains_out), axis=1)
    X_test_new = np.concatenate(tuple(X_test_out), axis=1)

    data_train = (X_train_new, Y_train_new)
    data_test = (X_test_new, Y_test_new)

    return models, data_train, data_test, XY_dict


def make_dir_if_not_exist(used_path):
    if not os.path.isdir(used_path):
        try:
            os.mkdir(used_path)
        except OSError as exc:
            if exc.errno != errno.EEXIST:
                raise exc
            else:
                raise ValueError(f'{used_path} directoy cannot be created because its parent directory does not exist.')


def source_model(model_func, model_name, input_shape):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)
    return m


def compile_and_fit_model_with_tb(model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_every_epoch=True,
                                  save_final=False,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)
    tb_callback = TensorBoard(log_dir=f'{m.name}_logs', histogram_freq=kwargs.pop("histogram_freq", 1))
    if save_every_epoch:
        tb_callback.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.2f}'))
    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=[tb_callback], verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)
    # m.save(f"{m.name}_Tenth_Fold_New_Model_500_8") #Save the model


def compile_and_fit_model(model_func,
                          model_name,
                          input_shape,
                          X_train,
                          Y_train,
                          save_every_epoch=True,
                          save_final=False,
                          **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_every_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.2f}'))
    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)


def compile_model_and_fit_with_custom_loop(model_func,
                                           model_name,
                                           input_shape,
                                           X_train,
                                           Y_train,
                                           **kwargs):
    make_dir_if_not_exist(model_name)
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    train_writer = create_file_writer(f'{m.name}_logs/train/')
    test_writer = create_file_writer(f'{m.name}_logs/test/')
    train_step = test_step = 0

    acc_metric = tf.keras.metrics.CategoricalAccuracy()
    optimizer = tf.keras.optimizers.Adam()
    num_epochs = kwargs.get("epochs", 10)

    AUTOTUNE = tf.data.experimental.AUTOTUNE
    BATCH_SIZE = kwargs.get("batch_size", 32)
    X_test, Y_test = kwargs.get("validation_data", (None, None))
    if X_test is None:
        raise ValueError("Missing X validation data")
    if Y_test is None:
        raise ValueError("Missing Y validation data")

    train_dataset_tf = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
    train_dataset_tf = train_dataset_tf.batch(BATCH_SIZE)
    train_dataset_tf = train_dataset_tf.prefetch(AUTOTUNE)

    test_dataset_tf = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    test_dataset_tf = train_dataset_tf.batch(BATCH_SIZE)
    test_dataset_tf = train_dataset_tf.prefetch(AUTOTUNE)

    loss_fn = tf.keras.losses.CategoricalCrossentropy()

    for epoch in range(num_epochs):
        # Iterate through training set
        for batch_idx, (x, y) in enumerate(train_dataset_tf):
            with tf.GradientTape() as tape:
                y_pred = m(x, training=True)
                loss = loss_fn(y, y_pred)

            gradients = tape.gradient(loss, m.trainable_weights)
            optimizer.apply_gradients(zip(gradients, m.trainable_weights))
            acc_metric.update_state(y, y_pred)

            with train_writer.as_default():
                tf.summary.scalar("Loss", loss, step=train_step)
                tf.summary.scalar(
                    "Accuracy", acc_metric.result(), step=train_step,
                )
                train_step += 1
        # Reset accuracy in between epochs (and for testing and test)
        acc_metric.reset_states()
        # Iterate through test set
        for batch_idx, (x, y) in enumerate(test_dataset_tf):
            y_pred = m(x, training=False)
            loss = loss_fn(y, y_pred)
            acc_metric.update_state(y, y_pred)
            with test_writer.as_default():
                tf.summary.scalar("Loss", loss, step=test_step)
                tf.summary.scalar(
                    "Accuracy", acc_metric.result(), step=test_step,
                )
                test_step += 1

        acc_metric.reset_states()  # Reset accuracy in between epochs (and for testing and test)

    return m


def reinitialize_weights(model):
    for ix, layer in enumerate(model.layers):
        if hasattr(model.layers[ix], 'kernel_initializer') and hasattr(model.layers[ix], 'bias_initializer'):
            weight_initializer = model.layers[ix].kernel_initializer
            bias_initializer = model.layers[ix].bias_initializer

            old_weights, old_biases = model.layers[ix].get_weights()

            model.layers[ix].set_weights([
                weight_initializer(shape=old_weights.shape),
                bias_initializer(shape=len(old_biases))])
    return model


def reverse_tensor(X):
    return tf.gather(X, tf.reverse(tf.range(start=0, limit=tf.shape(X)[0], dtype=tf.int32), (0,)))


def run_mirrored_strategy(model_func, base_batch_size, nepochs, x_train, y_train, x_test, y_test, **kwargs):
    strategy = tf.distribute.MirroredStrategy()
    with strategy.scope():
        model = model_func()
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=tf.keras.metrics.SparseCategoricalAccuracy()
        )
    batch_size_mirr_strat = base_batch_size * strategy.num_replicas_in_sync
    history = model.fit(x_train, y_train, epochs=nepochs, batch_size=batch_size_mirr_strat,
                        validation_data=(x_test, y_test),
                        **kwargs)
    return model, history


def sparse_setdiff(a1, a2):
    a1a = a1.reshape(a1.shape[0], -1)
    a2a = a2.reshape(a2.shape[0], -1)
    spa2a = [np.where(x)[0].tolist() for x in a2a]
    spa1a = [np.where(x)[0].tolist() for x in a1a]
    idxs_to_keep = []
    for idx, sample in enumerate(spa1a):
        try:
            spa2a.index(sample)
        except ValueError:
            # not in list
            idxs_to_keep.append(idx)
    return a1[idxs_to_keep], idxs_to_keep


def unpacking_apply_along_axis(all_args):
    """
    Like numpy.apply_along_axis(), but with arguments in a tuple
    instead.

    This function is useful with multiprocessing.Pool().map(): (1)
    map() only handles functions that take a single argument, and (2)
    this function can generally be imported from a module, as required
    by map().
    """
    (func1d, axis, arr, args, kwargs) = all_args
    # return np.apply_along_axis(func1d, axis, arr, *args, **kwargs)


def parallel_apply_along_axis(func1d, axis, arr, *args, **kwargs):
    """
    Like numpy.apply_along_axis(), but takes advantage of multiple
    cores.
    """
    # Effective axis where apply_along_axis() will be applied by each
    # worker (any non-zero axis number would work, so as to allow the use
    # of `np.array_split()`, which is only done on axis 0):
    effective_axis = 1 if axis == 0 else axis
    if effective_axis != axis:
        arr = arr.swapaxes(axis, effective_axis)

    # Chunks for the mapping (only a few chunks):
    chunks = [(func1d, effective_axis, sub_arr, args, kwargs)
              for sub_arr in np.array_split(arr, multiprocessing.cpu_count())]

    pool = multiprocessing.Pool()
    individual_results = pool.map(unpacking_apply_along_axis, chunks)
    # Freeing the workers:
    pool.close()
    pool.join()

    return np.concatenate(individual_results)

# %%
def baseline_CNN_finalist(model_name, inshape, num_classes = 13):

    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Conv1D(128 ,10 ,padding='same' ,input_shape=inshape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(128 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(128))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(64))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax))
    model._name = model_name

    return model


def compile_and_fit_model_basic(  model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='val_accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

def compile_and_fit_model_basic_noVal(  model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

# %%
X_train_1000e, Y_train_1000e, X_test_1000e, Y_test_1000e, X_val_1000e, Y_val_1000e = getE2eData(is500=False, include_secondary=False)

# %%
    # merge into a new train:
    X_new_train = np.concatenate( (X_train_1000e, X_val_1000e), axis=0 )
    Y_new_train = np.concatenate( (Y_train_1000e, Y_val_1000e), axis=0 )
    cnn_2, history_cnn_2 = compile_and_fit_model_basic_noVal(baseline_CNN_finalist,
                                                  "cnn_noTest_20210516",
                                                  X_new_train[0].shape,
                                                  X_new_train,
                                                  Y_new_train,
                                                  save_max_epoch=True,
                                                  save_final=True,
                                                  patience_count=10,
                                                  batch_size=2048,
                                                  epochs=150,
                                                  class_weight=None)
    cnn_2.evaluate(X_test_1000e, Y_test_1000e)

# %%
plot_history(history_cnn_2)
cnn_2b, history_cnn_2 = compile_and_fit_model_basic_noVal(cnn_2,
                                                  cnn_2.name,
                                                  X_new_train[0].shape,
                                                  X_new_train,
                                                  Y_new_train,
                                                  save_max_epoch=True,
                                                  save_final=True,
                                                  patience_count=None,
                                                  batch_size=2048,
                                                  epochs=500,
                                                  class_weight=None)
cnn_2b.evaluate(X_test_1000e, Y_test_1000e)
# Out:
# Epoch 1/500
# 4/4 - 4s - loss: 0.1428 - accuracy: 0.9483
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_001_0.948/assets
# Epoch 2/500
# 4/4 - 2s - loss: 0.1410 - accuracy: 0.9535
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_002_0.953/assets
# Epoch 3/500
# 4/4 - 2s - loss: 0.1287 - accuracy: 0.9548
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_003_0.955/assets
# Epoch 4/500
# 4/4 - 2s - loss: 0.1266 - accuracy: 0.9601
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_004_0.960/assets
# Epoch 5/500
# 4/4 - 2s - loss: 0.1211 - accuracy: 0.9592
# Epoch 6/500
# 4/4 - 2s - loss: 0.1132 - accuracy: 0.9633
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_006_0.963/assets
# Epoch 7/500
# 4/4 - 2s - loss: 0.1184 - accuracy: 0.9606
# Epoch 8/500
# 4/4 - 2s - loss: 0.1164 - accuracy: 0.9633
# Epoch 9/500
# 4/4 - 2s - loss: 0.1076 - accuracy: 0.9657
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_009_0.966/assets
# Epoch 10/500
# 4/4 - 2s - loss: 0.1130 - accuracy: 0.9636
# Epoch 11/500
# 4/4 - 2s - loss: 0.0983 - accuracy: 0.9697
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_011_0.970/assets
# Epoch 12/500
# 4/4 - 2s - loss: 0.0972 - accuracy: 0.9682
# Epoch 13/500
# 4/4 - 2s - loss: 0.1103 - accuracy: 0.9640
# Epoch 14/500
# 4/4 - 2s - loss: 0.0968 - accuracy: 0.9698
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_014_0.970/assets
# Epoch 15/500
# 4/4 - 2s - loss: 0.0913 - accuracy: 0.9704
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_015_0.970/assets
# Epoch 16/500
# 4/4 - 2s - loss: 0.1021 - accuracy: 0.9676
# Epoch 17/500
# 4/4 - 2s - loss: 0.0950 - accuracy: 0.9672
# Epoch 18/500
# 4/4 - 2s - loss: 0.1035 - accuracy: 0.9654
# Epoch 19/500
# 4/4 - 2s - loss: 0.0932 - accuracy: 0.9699
# Epoch 20/500
# 4/4 - 2s - loss: 0.0855 - accuracy: 0.9715
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_020_0.971/assets
# Epoch 21/500
# 4/4 - 2s - loss: 0.0897 - accuracy: 0.9703
# Epoch 22/500
# 4/4 - 2s - loss: 0.0850 - accuracy: 0.9720
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_022_0.972/assets
# Epoch 23/500
# 4/4 - 2s - loss: 0.0804 - accuracy: 0.9728
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_023_0.973/assets
# Epoch 24/500
# 4/4 - 2s - loss: 0.0871 - accuracy: 0.9707
# Epoch 25/500
# 4/4 - 2s - loss: 0.0817 - accuracy: 0.9716
# Epoch 26/500
# 4/4 - 2s - loss: 0.0877 - accuracy: 0.9714
# Epoch 27/500
# 4/4 - 2s - loss: 0.0858 - accuracy: 0.9708
# Epoch 28/500
# 4/4 - 2s - loss: 0.0783 - accuracy: 0.9750
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_028_0.975/assets
# Epoch 29/500
# 4/4 - 2s - loss: 0.0814 - accuracy: 0.9727
# Epoch 30/500
# 4/4 - 2s - loss: 0.0745 - accuracy: 0.9750
# Epoch 31/500
# 4/4 - 2s - loss: 0.0796 - accuracy: 0.9734
# Epoch 32/500
# 4/4 - 2s - loss: 0.0753 - accuracy: 0.9750
# Epoch 33/500
# 4/4 - 2s - loss: 0.0793 - accuracy: 0.9741
# Epoch 34/500
# 4/4 - 2s - loss: 0.0777 - accuracy: 0.9742
# Epoch 35/500
# 4/4 - 2s - loss: 0.0828 - accuracy: 0.9711
# Epoch 36/500
# 4/4 - 2s - loss: 0.0825 - accuracy: 0.9732
# Epoch 37/500
# 4/4 - 2s - loss: 0.0742 - accuracy: 0.9739
# Epoch 38/500
# 4/4 - 2s - loss: 0.0748 - accuracy: 0.9745
# Epoch 39/500
# 4/4 - 2s - loss: 0.0773 - accuracy: 0.9719
# Epoch 40/500
# 4/4 - 2s - loss: 0.0751 - accuracy: 0.9758
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_040_0.976/assets
# Epoch 41/500
# 4/4 - 2s - loss: 0.0691 - accuracy: 0.9782
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_041_0.978/assets
# Epoch 42/500
# 4/4 - 2s - loss: 0.0793 - accuracy: 0.9727
# Epoch 43/500
# 4/4 - 2s - loss: 0.0722 - accuracy: 0.9754
# Epoch 44/500
# 4/4 - 2s - loss: 0.0650 - accuracy: 0.9774
# Epoch 45/500
# 4/4 - 2s - loss: 0.0613 - accuracy: 0.9787
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_045_0.979/assets
# Epoch 46/500
# 4/4 - 2s - loss: 0.0621 - accuracy: 0.9803
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_046_0.980/assets
# Epoch 47/500
# 4/4 - 2s - loss: 0.0633 - accuracy: 0.9800
# Epoch 48/500
# 4/4 - 2s - loss: 0.0728 - accuracy: 0.9746
# Epoch 49/500
# 4/4 - 2s - loss: 0.0644 - accuracy: 0.9780
# Epoch 50/500
# 4/4 - 2s - loss: 0.0673 - accuracy: 0.9782
# Epoch 51/500
# 4/4 - 2s - loss: 0.0615 - accuracy: 0.9798
# Epoch 52/500
# 4/4 - 2s - loss: 0.0642 - accuracy: 0.9789
# Epoch 53/500
# 4/4 - 2s - loss: 0.0629 - accuracy: 0.9782
# Epoch 54/500
# 4/4 - 2s - loss: 0.0645 - accuracy: 0.9787
# Epoch 55/500
# 4/4 - 2s - loss: 0.0646 - accuracy: 0.9798
# Epoch 56/500
# 4/4 - 2s - loss: 0.0610 - accuracy: 0.9782
# Epoch 57/500
# 4/4 - 2s - loss: 0.0569 - accuracy: 0.9813
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_057_0.981/assets
# Epoch 58/500
# 4/4 - 2s - loss: 0.0613 - accuracy: 0.9787
# Epoch 59/500
# 4/4 - 2s - loss: 0.0545 - accuracy: 0.9829
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_059_0.983/assets
# Epoch 60/500
# 4/4 - 2s - loss: 0.0649 - accuracy: 0.9765
# Epoch 61/500
# 4/4 - 2s - loss: 0.0593 - accuracy: 0.9798
# Epoch 62/500
# 4/4 - 2s - loss: 0.0585 - accuracy: 0.9798
# Epoch 63/500
# 4/4 - 2s - loss: 0.0537 - accuracy: 0.9826
# Epoch 64/500
# 4/4 - 2s - loss: 0.0656 - accuracy: 0.9767
# Epoch 65/500
# 4/4 - 2s - loss: 0.0554 - accuracy: 0.9803
# Epoch 66/500
# 4/4 - 2s - loss: 0.0583 - accuracy: 0.9804
# Epoch 67/500
# 4/4 - 2s - loss: 0.0534 - accuracy: 0.9815
# Epoch 68/500
# 4/4 - 2s - loss: 0.0553 - accuracy: 0.9819
# Epoch 69/500
# 4/4 - 2s - loss: 0.0539 - accuracy: 0.9831
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_069_0.983/assets
# Epoch 70/500
# 4/4 - 2s - loss: 0.0543 - accuracy: 0.9820
# Epoch 71/500
# 4/4 - 2s - loss: 0.0504 - accuracy: 0.9821
# Epoch 72/500
# 4/4 - 2s - loss: 0.0482 - accuracy: 0.9844
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_072_0.984/assets
# Epoch 73/500
# 4/4 - 2s - loss: 0.0539 - accuracy: 0.9826
# Epoch 74/500
# 4/4 - 2s - loss: 0.0493 - accuracy: 0.9860
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_074_0.986/assets
# Epoch 75/500
# 4/4 - 2s - loss: 0.0516 - accuracy: 0.9844
# Epoch 76/500
# 4/4 - 2s - loss: 0.0563 - accuracy: 0.9811
# Epoch 77/500
# 4/4 - 2s - loss: 0.0532 - accuracy: 0.9825
# Epoch 78/500
# 4/4 - 2s - loss: 0.0497 - accuracy: 0.9830
# Epoch 79/500
# 4/4 - 2s - loss: 0.0534 - accuracy: 0.9829
# Epoch 80/500
# 4/4 - 2s - loss: 0.0516 - accuracy: 0.9828
# Epoch 81/500
# 4/4 - 2s - loss: 0.0496 - accuracy: 0.9824
# Epoch 82/500
# 4/4 - 2s - loss: 0.0476 - accuracy: 0.9834
# Epoch 83/500
# 4/4 - 2s - loss: 0.0491 - accuracy: 0.9850
# Epoch 84/500
# 4/4 - 2s - loss: 0.0529 - accuracy: 0.9812
# Epoch 85/500
# 4/4 - 2s - loss: 0.0479 - accuracy: 0.9841
# Epoch 86/500
# 4/4 - 2s - loss: 0.0461 - accuracy: 0.9850
# Epoch 87/500
# 4/4 - 2s - loss: 0.0500 - accuracy: 0.9824
# Epoch 88/500
# 4/4 - 2s - loss: 0.0482 - accuracy: 0.9848
# Epoch 89/500
# 4/4 - 2s - loss: 0.0446 - accuracy: 0.9850
# Epoch 90/500
# 4/4 - 2s - loss: 0.0456 - accuracy: 0.9852
# Epoch 91/500
# 4/4 - 2s - loss: 0.0455 - accuracy: 0.9851
# Epoch 92/500
# 4/4 - 2s - loss: 0.0478 - accuracy: 0.9847
# Epoch 93/500
# 4/4 - 2s - loss: 0.0430 - accuracy: 0.9851
# Epoch 94/500
# 4/4 - 2s - loss: 0.0436 - accuracy: 0.9863
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_094_0.986/assets
# Epoch 95/500
# 4/4 - 2s - loss: 0.0456 - accuracy: 0.9857
# Epoch 96/500
# 4/4 - 2s - loss: 0.0494 - accuracy: 0.9844
# Epoch 97/500
# 4/4 - 2s - loss: 0.0422 - accuracy: 0.9860
# Epoch 98/500
# 4/4 - 2s - loss: 0.0471 - accuracy: 0.9848
# Epoch 99/500
# 4/4 - 2s - loss: 0.0435 - accuracy: 0.9843
# Epoch 100/500
# 4/4 - 2s - loss: 0.0402 - accuracy: 0.9878
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_100_0.988/assets
# Epoch 101/500
# 4/4 - 2s - loss: 0.0425 - accuracy: 0.9844
# Epoch 102/500
# 4/4 - 2s - loss: 0.0426 - accuracy: 0.9856
# Epoch 103/500
# 4/4 - 2s - loss: 0.0365 - accuracy: 0.9872
# Epoch 104/500
# 4/4 - 2s - loss: 0.0415 - accuracy: 0.9861
# Epoch 105/500
# 4/4 - 2s - loss: 0.0471 - accuracy: 0.9847
# Epoch 106/500
# 4/4 - 2s - loss: 0.0415 - accuracy: 0.9874
# Epoch 107/500
# 4/4 - 2s - loss: 0.0402 - accuracy: 0.9861
# Epoch 108/500
# 4/4 - 2s - loss: 0.0425 - accuracy: 0.9844
# Epoch 109/500
# 4/4 - 2s - loss: 0.0438 - accuracy: 0.9863
# Epoch 110/500
# 4/4 - 2s - loss: 0.0430 - accuracy: 0.9854
# Epoch 111/500
# 4/4 - 2s - loss: 0.0386 - accuracy: 0.9881
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_111_0.988/assets
# Epoch 112/500
# 4/4 - 2s - loss: 0.0388 - accuracy: 0.9876
# Epoch 113/500
# 4/4 - 2s - loss: 0.0387 - accuracy: 0.9864
# Epoch 114/500
# 4/4 - 2s - loss: 0.0329 - accuracy: 0.9899
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_114_0.990/assets
# Epoch 115/500
# 4/4 - 2s - loss: 0.0404 - accuracy: 0.9872
# Epoch 116/500
# 4/4 - 2s - loss: 0.0378 - accuracy: 0.9881
# Epoch 117/500
# 4/4 - 2s - loss: 0.0337 - accuracy: 0.9892
# Epoch 118/500
# 4/4 - 2s - loss: 0.0385 - accuracy: 0.9870
# Epoch 119/500
# 4/4 - 2s - loss: 0.0373 - accuracy: 0.9876
# Epoch 120/500
# 4/4 - 2s - loss: 0.0352 - accuracy: 0.9886
# Epoch 121/500
# 4/4 - 2s - loss: 0.0403 - accuracy: 0.9865
# Epoch 122/500
# 4/4 - 2s - loss: 0.0349 - accuracy: 0.9882
# Epoch 123/500
# 4/4 - 2s - loss: 0.0340 - accuracy: 0.9886
# Epoch 124/500
# 4/4 - 2s - loss: 0.0317 - accuracy: 0.9889
# Epoch 125/500
# 4/4 - 2s - loss: 0.0381 - accuracy: 0.9874
# Epoch 126/500
# 4/4 - 2s - loss: 0.0434 - accuracy: 0.9848
# Epoch 127/500
# 4/4 - 2s - loss: 0.0310 - accuracy: 0.9900
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_127_0.990/assets
# Epoch 128/500
# 4/4 - 2s - loss: 0.0385 - accuracy: 0.9877
# Epoch 129/500
# 4/4 - 2s - loss: 0.0346 - accuracy: 0.9883
# Epoch 130/500
# 4/4 - 2s - loss: 0.0366 - accuracy: 0.9881
# Epoch 131/500
# 4/4 - 2s - loss: 0.0364 - accuracy: 0.9869
# Epoch 132/500
# 4/4 - 2s - loss: 0.0317 - accuracy: 0.9889
# Epoch 133/500
# 4/4 - 2s - loss: 0.0314 - accuracy: 0.9898
# Epoch 134/500
# 4/4 - 2s - loss: 0.0362 - accuracy: 0.9879
# Epoch 135/500
# 4/4 - 2s - loss: 0.0374 - accuracy: 0.9874
# Epoch 136/500
# 4/4 - 2s - loss: 0.0345 - accuracy: 0.9891
# Epoch 137/500
# 4/4 - 2s - loss: 0.0336 - accuracy: 0.9894
# Epoch 138/500
# 4/4 - 2s - loss: 0.0344 - accuracy: 0.9883
# Epoch 139/500
# 4/4 - 2s - loss: 0.0327 - accuracy: 0.9889
# Epoch 140/500
# 4/4 - 2s - loss: 0.0315 - accuracy: 0.9896
# Epoch 141/500
# 4/4 - 2s - loss: 0.0315 - accuracy: 0.9886
# Epoch 142/500
# 4/4 - 2s - loss: 0.0356 - accuracy: 0.9883
# Epoch 143/500
# 4/4 - 2s - loss: 0.0328 - accuracy: 0.9883
# Epoch 144/500
# 4/4 - 2s - loss: 0.0337 - accuracy: 0.9873
# Epoch 145/500
# 4/4 - 2s - loss: 0.0279 - accuracy: 0.9909
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_145_0.991/assets
# Epoch 146/500
# 4/4 - 2s - loss: 0.0290 - accuracy: 0.9892
# Epoch 147/500
# 4/4 - 2s - loss: 0.0293 - accuracy: 0.9892
# Epoch 148/500
# 4/4 - 2s - loss: 0.0356 - accuracy: 0.9886
# Epoch 149/500
# 4/4 - 2s - loss: 0.0335 - accuracy: 0.9895
# Epoch 150/500
# 4/4 - 2s - loss: 0.0306 - accuracy: 0.9900
# Epoch 151/500
# 4/4 - 2s - loss: 0.0284 - accuracy: 0.9912
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_151_0.991/assets
# Epoch 152/500
# 4/4 - 2s - loss: 0.0321 - accuracy: 0.9899
# Epoch 153/500
# 4/4 - 2s - loss: 0.0414 - accuracy: 0.9850
# Epoch 154/500
# 4/4 - 2s - loss: 0.0303 - accuracy: 0.9894
# Epoch 155/500
# 4/4 - 2s - loss: 0.0299 - accuracy: 0.9896
# Epoch 156/500
# 4/4 - 2s - loss: 0.0274 - accuracy: 0.9913
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_156_0.991/assets
# Epoch 157/500
# 4/4 - 2s - loss: 0.0344 - accuracy: 0.9878
# Epoch 158/500
# 4/4 - 2s - loss: 0.0248 - accuracy: 0.9927
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_158_0.993/assets
# Epoch 159/500
# 4/4 - 2s - loss: 0.0315 - accuracy: 0.9899
# Epoch 160/500
# 4/4 - 2s - loss: 0.0270 - accuracy: 0.9922
# Epoch 161/500
# 4/4 - 2s - loss: 0.0325 - accuracy: 0.9889
# Epoch 162/500
# 4/4 - 2s - loss: 0.0308 - accuracy: 0.9904
# Epoch 163/500
# 4/4 - 2s - loss: 0.0319 - accuracy: 0.9898
# Epoch 164/500
# 4/4 - 2s - loss: 0.0270 - accuracy: 0.9909
# Epoch 165/500
# 4/4 - 2s - loss: 0.0279 - accuracy: 0.9913
# Epoch 166/500
# 4/4 - 2s - loss: 0.0283 - accuracy: 0.9913
# Epoch 167/500
# 4/4 - 2s - loss: 0.0291 - accuracy: 0.9907
# Epoch 168/500
# 4/4 - 2s - loss: 0.0271 - accuracy: 0.9908
# Epoch 169/500
# 4/4 - 2s - loss: 0.0260 - accuracy: 0.9925
# Epoch 170/500
# 4/4 - 2s - loss: 0.0254 - accuracy: 0.9914
# Epoch 171/500
# 4/4 - 2s - loss: 0.0311 - accuracy: 0.9896
# Epoch 172/500
# 4/4 - 2s - loss: 0.0243 - accuracy: 0.9922
# Epoch 173/500
# 4/4 - 2s - loss: 0.0267 - accuracy: 0.9920
# Epoch 174/500
# 4/4 - 2s - loss: 0.0235 - accuracy: 0.9920
# Epoch 175/500
# 4/4 - 2s - loss: 0.0250 - accuracy: 0.9920
# Epoch 176/500
# 4/4 - 2s - loss: 0.0273 - accuracy: 0.9903
# Epoch 177/500
# 4/4 - 2s - loss: 0.0288 - accuracy: 0.9903
# Epoch 178/500
# 4/4 - 2s - loss: 0.0234 - accuracy: 0.9920
# Epoch 179/500
# 4/4 - 2s - loss: 0.0309 - accuracy: 0.9895
# Epoch 180/500
# 4/4 - 2s - loss: 0.0242 - accuracy: 0.9916
# Epoch 181/500
# 4/4 - 2s - loss: 0.0249 - accuracy: 0.9920
# Epoch 182/500
# 4/4 - 2s - loss: 0.0264 - accuracy: 0.9905
# Epoch 183/500
# 4/4 - 2s - loss: 0.0272 - accuracy: 0.9900
# Epoch 184/500
# 4/4 - 2s - loss: 0.0289 - accuracy: 0.9920
# Epoch 185/500
# 4/4 - 2s - loss: 0.0272 - accuracy: 0.9908
# Epoch 186/500
# 4/4 - 2s - loss: 0.0297 - accuracy: 0.9900
# Epoch 187/500
# 4/4 - 2s - loss: 0.0256 - accuracy: 0.9913
# Epoch 188/500
# 4/4 - 2s - loss: 0.0215 - accuracy: 0.9927
# Epoch 189/500
# 4/4 - 2s - loss: 0.0277 - accuracy: 0.9921
# Epoch 190/500
# 4/4 - 2s - loss: 0.0286 - accuracy: 0.9905
# Epoch 191/500
# 4/4 - 2s - loss: 0.0242 - accuracy: 0.9927
# Epoch 192/500
# 4/4 - 2s - loss: 0.0232 - accuracy: 0.9921
# Epoch 193/500
# 4/4 - 2s - loss: 0.0222 - accuracy: 0.9917
# Epoch 194/500
# 4/4 - 2s - loss: 0.0262 - accuracy: 0.9907
# Epoch 195/500
# 4/4 - 2s - loss: 0.0256 - accuracy: 0.9908
# Epoch 196/500
# 4/4 - 2s - loss: 0.0219 - accuracy: 0.9933
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_196_0.993/assets
# Epoch 197/500
# 4/4 - 2s - loss: 0.0242 - accuracy: 0.9922
# Epoch 198/500
# 4/4 - 2s - loss: 0.0216 - accuracy: 0.9927
# Epoch 199/500
# 4/4 - 2s - loss: 0.0209 - accuracy: 0.9936
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_199_0.994/assets
# Epoch 200/500
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.9926
# Epoch 201/500
# 4/4 - 2s - loss: 0.0226 - accuracy: 0.9920
# Epoch 202/500
# 4/4 - 2s - loss: 0.0214 - accuracy: 0.9930
# Epoch 203/500
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.9939
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_203_0.994/assets
# Epoch 204/500
# 4/4 - 2s - loss: 0.0210 - accuracy: 0.9925
# Epoch 205/500
# 4/4 - 2s - loss: 0.0232 - accuracy: 0.9931
# Epoch 206/500
# 4/4 - 2s - loss: 0.0187 - accuracy: 0.9940
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_206_0.994/assets
# Epoch 207/500
# 4/4 - 2s - loss: 0.0224 - accuracy: 0.9922
# Epoch 208/500
# 4/4 - 2s - loss: 0.0258 - accuracy: 0.9912
# Epoch 209/500
# 4/4 - 2s - loss: 0.0213 - accuracy: 0.9933
# Epoch 210/500
# 4/4 - 2s - loss: 0.0228 - accuracy: 0.9929
# Epoch 211/500
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.9942
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_211_0.994/assets
# Epoch 212/500
# 4/4 - 2s - loss: 0.0249 - accuracy: 0.9921
# Epoch 213/500
# 4/4 - 2s - loss: 0.0218 - accuracy: 0.9929
# Epoch 214/500
# 4/4 - 2s - loss: 0.0246 - accuracy: 0.9901
# Epoch 215/500
# 4/4 - 2s - loss: 0.0208 - accuracy: 0.9931
# Epoch 216/500
# 4/4 - 2s - loss: 0.0220 - accuracy: 0.9940
# Epoch 217/500
# 4/4 - 2s - loss: 0.0230 - accuracy: 0.9914
# Epoch 218/500
# 4/4 - 2s - loss: 0.0244 - accuracy: 0.9924
# Epoch 219/500
# 4/4 - 2s - loss: 0.0235 - accuracy: 0.9918
# Epoch 220/500
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.9947
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_220_0.995/assets
# Epoch 221/500
# 4/4 - 2s - loss: 0.0190 - accuracy: 0.9936
# Epoch 222/500
# 4/4 - 2s - loss: 0.0253 - accuracy: 0.9913
# Epoch 223/500
# 4/4 - 2s - loss: 0.0195 - accuracy: 0.9933
# Epoch 224/500
# 4/4 - 2s - loss: 0.0243 - accuracy: 0.9918
# Epoch 225/500
# 4/4 - 2s - loss: 0.0225 - accuracy: 0.9921
# Epoch 226/500
# 4/4 - 2s - loss: 0.0196 - accuracy: 0.9939
# Epoch 227/500
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.9918
# Epoch 228/500
# 4/4 - 2s - loss: 0.0210 - accuracy: 0.9933
# Epoch 229/500
# 4/4 - 2s - loss: 0.0192 - accuracy: 0.9939
# Epoch 230/500
# 4/4 - 2s - loss: 0.0251 - accuracy: 0.9916
# Epoch 231/500
# 4/4 - 2s - loss: 0.0220 - accuracy: 0.9927
# Epoch 232/500
# 4/4 - 2s - loss: 0.0188 - accuracy: 0.9938
# Epoch 233/500
# 4/4 - 2s - loss: 0.0190 - accuracy: 0.9935
# Epoch 234/500
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.9943
# Epoch 235/500
# 4/4 - 2s - loss: 0.0201 - accuracy: 0.9927
# Epoch 236/500
# 4/4 - 2s - loss: 0.0225 - accuracy: 0.9925
# Epoch 237/500
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.9929
# Epoch 238/500
# 4/4 - 2s - loss: 0.0197 - accuracy: 0.9929
# Epoch 239/500
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.9935
# Epoch 240/500
# 4/4 - 2s - loss: 0.0198 - accuracy: 0.9931
# Epoch 241/500
# 4/4 - 2s - loss: 0.0215 - accuracy: 0.9929
# Epoch 242/500
# 4/4 - 2s - loss: 0.0238 - accuracy: 0.9920
# Epoch 243/500
# 4/4 - 2s - loss: 0.0227 - accuracy: 0.9927
# Epoch 244/500
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.9939
# Epoch 245/500
# 4/4 - 2s - loss: 0.0224 - accuracy: 0.9933
# Epoch 246/500
# 4/4 - 2s - loss: 0.0201 - accuracy: 0.9934
# Epoch 247/500
# 4/4 - 2s - loss: 0.0217 - accuracy: 0.9935
# Epoch 248/500
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.9931
# Epoch 249/500
# 4/4 - 2s - loss: 0.0187 - accuracy: 0.9933
# Epoch 250/500
# 4/4 - 2s - loss: 0.0224 - accuracy: 0.9925
# Epoch 251/500
# 4/4 - 2s - loss: 0.0213 - accuracy: 0.9930
# Epoch 252/500
# 4/4 - 2s - loss: 0.0213 - accuracy: 0.9924
# Epoch 253/500
# 4/4 - 2s - loss: 0.0216 - accuracy: 0.9917
# Epoch 254/500
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.9944
# Epoch 255/500
# 4/4 - 2s - loss: 0.0215 - accuracy: 0.9926
# Epoch 256/500
# 4/4 - 2s - loss: 0.0190 - accuracy: 0.9946
# Epoch 257/500
# 4/4 - 2s - loss: 0.0252 - accuracy: 0.9924
# Epoch 258/500
# 4/4 - 2s - loss: 0.0197 - accuracy: 0.9935
# Epoch 259/500
# 4/4 - 2s - loss: 0.0209 - accuracy: 0.9931
# Epoch 260/500
# 4/4 - 2s - loss: 0.0126 - accuracy: 0.9955
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_260_0.995/assets
# Epoch 261/500
# 4/4 - 2s - loss: 0.0155 - accuracy: 0.9946
# Epoch 262/500
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.9951
# Epoch 263/500
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.9940
# Epoch 264/500
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.9938
# Epoch 265/500
# 4/4 - 2s - loss: 0.0202 - accuracy: 0.9931
# Epoch 266/500
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.9940
# Epoch 267/500
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.9935
# Epoch 268/500
# 4/4 - 2s - loss: 0.0163 - accuracy: 0.9938
# Epoch 269/500
# 4/4 - 2s - loss: 0.0200 - accuracy: 0.9938
# Epoch 270/500
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.9949
# Epoch 271/500
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.9934
# Epoch 272/500
# 4/4 - 2s - loss: 0.0153 - accuracy: 0.9947
# Epoch 273/500
# 4/4 - 2s - loss: 0.0195 - accuracy: 0.9940
# Epoch 274/500
# 4/4 - 2s - loss: 0.0186 - accuracy: 0.9942
# Epoch 275/500
# 4/4 - 2s - loss: 0.0220 - accuracy: 0.9921
# Epoch 276/500
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.9944
# Epoch 277/500
# 4/4 - 2s - loss: 0.0201 - accuracy: 0.9931
# Epoch 278/500
# 4/4 - 2s - loss: 0.0193 - accuracy: 0.9935
# Epoch 279/500
# 4/4 - 2s - loss: 0.0132 - accuracy: 0.9959
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_279_0.996/assets
# Epoch 280/500
# 4/4 - 2s - loss: 0.0162 - accuracy: 0.9934
# Epoch 281/500
# 4/4 - 2s - loss: 0.0160 - accuracy: 0.9943
# Epoch 282/500
# 4/4 - 2s - loss: 0.0164 - accuracy: 0.9936
# Epoch 283/500
# 4/4 - 2s - loss: 0.0161 - accuracy: 0.9953
# Epoch 284/500
# 4/4 - 2s - loss: 0.0151 - accuracy: 0.9951
# Epoch 285/500
# 4/4 - 2s - loss: 0.0188 - accuracy: 0.9946
# Epoch 286/500
# 4/4 - 2s - loss: 0.0194 - accuracy: 0.9935
# Epoch 287/500
# 4/4 - 2s - loss: 0.0145 - accuracy: 0.9961
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_287_0.996/assets
# Epoch 288/500
# 4/4 - 2s - loss: 0.0119 - accuracy: 0.9953
# Epoch 289/500
# 4/4 - 2s - loss: 0.0194 - accuracy: 0.9926
# Epoch 290/500
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.9951
# Epoch 291/500
# 4/4 - 2s - loss: 0.0147 - accuracy: 0.9959
# Epoch 292/500
# 4/4 - 2s - loss: 0.0153 - accuracy: 0.9947
# Epoch 293/500
# 4/4 - 2s - loss: 0.0150 - accuracy: 0.9953
# Epoch 294/500
# 4/4 - 2s - loss: 0.0161 - accuracy: 0.9949
# Epoch 295/500
# 4/4 - 2s - loss: 0.0141 - accuracy: 0.9953
# Epoch 296/500
# 4/4 - 2s - loss: 0.0164 - accuracy: 0.9936
# Epoch 297/500
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.9943
# Epoch 298/500
# 4/4 - 2s - loss: 0.0146 - accuracy: 0.9956
# Epoch 299/500
# 4/4 - 2s - loss: 0.0188 - accuracy: 0.9938
# Epoch 300/500
# 4/4 - 2s - loss: 0.0189 - accuracy: 0.9929
# Epoch 301/500
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.9939
# Epoch 302/500
# 4/4 - 2s - loss: 0.0153 - accuracy: 0.9953
# Epoch 303/500
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.9939
# Epoch 304/500
# 4/4 - 2s - loss: 0.0151 - accuracy: 0.9953
# Epoch 305/500
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.9943
# Epoch 306/500
# 4/4 - 2s - loss: 0.0153 - accuracy: 0.9949
# Epoch 307/500
# 4/4 - 2s - loss: 0.0158 - accuracy: 0.9949
# Epoch 308/500
# 4/4 - 2s - loss: 0.0185 - accuracy: 0.9944
# Epoch 309/500
# 4/4 - 2s - loss: 0.0198 - accuracy: 0.9935
# Epoch 310/500
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.9948
# Epoch 311/500
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.9947
# Epoch 312/500
# 4/4 - 2s - loss: 0.0162 - accuracy: 0.9943
# Epoch 313/500
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.9948
# Epoch 314/500
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.9936
# Epoch 315/500
# 4/4 - 2s - loss: 0.0194 - accuracy: 0.9942
# Epoch 316/500
# 4/4 - 2s - loss: 0.0113 - accuracy: 0.9960
# Epoch 317/500
# 4/4 - 2s - loss: 0.0138 - accuracy: 0.9944
# Epoch 318/500
# 4/4 - 2s - loss: 0.0159 - accuracy: 0.9957
# Epoch 319/500
# 4/4 - 2s - loss: 0.0165 - accuracy: 0.9947
# Epoch 320/500
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.9947
# Epoch 321/500
# 4/4 - 2s - loss: 0.0153 - accuracy: 0.9949
# Epoch 322/500
# 4/4 - 2s - loss: 0.0190 - accuracy: 0.9929
# Epoch 323/500
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.9939
# Epoch 324/500
# 4/4 - 2s - loss: 0.0124 - accuracy: 0.9959
# Epoch 325/500
# 4/4 - 2s - loss: 0.0136 - accuracy: 0.9955
# Epoch 326/500
# 4/4 - 2s - loss: 0.0166 - accuracy: 0.9949
# Epoch 327/500
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.9953
# Epoch 328/500
# 4/4 - 2s - loss: 0.0152 - accuracy: 0.9948
# Epoch 329/500
# 4/4 - 2s - loss: 0.0148 - accuracy: 0.9953
# Epoch 330/500
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.9939
# Epoch 331/500
# 4/4 - 2s - loss: 0.0154 - accuracy: 0.9946
# Epoch 332/500
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.9936
# Epoch 333/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9953
# Epoch 334/500
# 4/4 - 2s - loss: 0.0128 - accuracy: 0.9953
# Epoch 335/500
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.9935
# Epoch 336/500
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.9946
# Epoch 337/500
# 4/4 - 2s - loss: 0.0155 - accuracy: 0.9951
# Epoch 338/500
# 4/4 - 2s - loss: 0.0151 - accuracy: 0.9949
# Epoch 339/500
# 4/4 - 2s - loss: 0.0138 - accuracy: 0.9952
# Epoch 340/500
# 4/4 - 2s - loss: 0.0117 - accuracy: 0.9965
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_340_0.997/assets
# Epoch 341/500
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.9938
# Epoch 342/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9952
# Epoch 343/500
# 4/4 - 2s - loss: 0.0158 - accuracy: 0.9940
# Epoch 344/500
# 4/4 - 2s - loss: 0.0142 - accuracy: 0.9947
# Epoch 345/500
# 4/4 - 2s - loss: 0.0146 - accuracy: 0.9946
# Epoch 346/500
# 4/4 - 2s - loss: 0.0111 - accuracy: 0.9964
# Epoch 347/500
# 4/4 - 2s - loss: 0.0129 - accuracy: 0.9949
# Epoch 348/500
# 4/4 - 2s - loss: 0.0141 - accuracy: 0.9949
# Epoch 349/500
# 4/4 - 2s - loss: 0.0148 - accuracy: 0.9946
# Epoch 350/500
# 4/4 - 2s - loss: 0.0166 - accuracy: 0.9946
# Epoch 351/500
# 4/4 - 2s - loss: 0.0132 - accuracy: 0.9953
# Epoch 352/500
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.9955
# Epoch 353/500
# 4/4 - 2s - loss: 0.0114 - accuracy: 0.9962
# Epoch 354/500
# 4/4 - 2s - loss: 0.0132 - accuracy: 0.9951
# Epoch 355/500
# 4/4 - 2s - loss: 0.0149 - accuracy: 0.9951
# Epoch 356/500
# 4/4 - 2s - loss: 0.0162 - accuracy: 0.9949
# Epoch 357/500
# 4/4 - 2s - loss: 0.0145 - accuracy: 0.9949
# Epoch 358/500
# 4/4 - 2s - loss: 0.0127 - accuracy: 0.9959
# Epoch 359/500
# 4/4 - 2s - loss: 0.0158 - accuracy: 0.9947
# Epoch 360/500
# 4/4 - 2s - loss: 0.0144 - accuracy: 0.9948
# Epoch 361/500
# 4/4 - 2s - loss: 0.0145 - accuracy: 0.9957
# Epoch 362/500
# 4/4 - 2s - loss: 0.0148 - accuracy: 0.9951
# Epoch 363/500
# 4/4 - 2s - loss: 0.0140 - accuracy: 0.9951
# Epoch 364/500
# 4/4 - 2s - loss: 0.0114 - accuracy: 0.9960
# Epoch 365/500
# 4/4 - 2s - loss: 0.0141 - accuracy: 0.9947
# Epoch 366/500
# 4/4 - 2s - loss: 0.0123 - accuracy: 0.9968
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_366_0.997/assets
# Epoch 367/500
# 4/4 - 2s - loss: 0.0123 - accuracy: 0.9959
# Epoch 368/500
# 4/4 - 2s - loss: 0.0136 - accuracy: 0.9952
# Epoch 369/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9955
# Epoch 370/500
# 4/4 - 2s - loss: 0.0127 - accuracy: 0.9959
# Epoch 371/500
# 4/4 - 2s - loss: 0.0146 - accuracy: 0.9951
# Epoch 372/500
# 4/4 - 2s - loss: 0.0091 - accuracy: 0.9973
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_372_0.997/assets
# Epoch 373/500
# 4/4 - 2s - loss: 0.0157 - accuracy: 0.9952
# Epoch 374/500
# 4/4 - 2s - loss: 0.0116 - accuracy: 0.9961
# Epoch 375/500
# 4/4 - 2s - loss: 0.0156 - accuracy: 0.9947
# Epoch 376/500
# 4/4 - 2s - loss: 0.0164 - accuracy: 0.9943
# Epoch 377/500
# 4/4 - 2s - loss: 0.0137 - accuracy: 0.9961
# Epoch 378/500
# 4/4 - 2s - loss: 0.0144 - accuracy: 0.9953
# Epoch 379/500
# 4/4 - 2s - loss: 0.0131 - accuracy: 0.9953
# Epoch 380/500
# 4/4 - 2s - loss: 0.0131 - accuracy: 0.9964
# Epoch 381/500
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.9942
# Epoch 382/500
# 4/4 - 2s - loss: 0.0131 - accuracy: 0.9957
# Epoch 383/500
# 4/4 - 2s - loss: 0.0145 - accuracy: 0.9952
# Epoch 384/500
# 4/4 - 2s - loss: 0.0142 - accuracy: 0.9952
# Epoch 385/500
# 4/4 - 2s - loss: 0.0108 - accuracy: 0.9965
# Epoch 386/500
# 4/4 - 2s - loss: 0.0130 - accuracy: 0.9952
# Epoch 387/500
# 4/4 - 2s - loss: 0.0121 - accuracy: 0.9952
# Epoch 388/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9961
# Epoch 389/500
# 4/4 - 2s - loss: 0.0108 - accuracy: 0.9964
# Epoch 390/500
# 4/4 - 2s - loss: 0.0137 - accuracy: 0.9961
# Epoch 391/500
# 4/4 - 2s - loss: 0.0110 - accuracy: 0.9961
# Epoch 392/500
# 4/4 - 2s - loss: 0.0078 - accuracy: 0.9968
# Epoch 393/500
# 4/4 - 2s - loss: 0.0120 - accuracy: 0.9966
# Epoch 394/500
# 4/4 - 2s - loss: 0.0156 - accuracy: 0.9951
# Epoch 395/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9951
# Epoch 396/500
# 4/4 - 2s - loss: 0.0121 - accuracy: 0.9955
# Epoch 397/500
# 4/4 - 2s - loss: 0.0129 - accuracy: 0.9956
# Epoch 398/500
# 4/4 - 2s - loss: 0.0151 - accuracy: 0.9949
# Epoch 399/500
# 4/4 - 2s - loss: 0.0124 - accuracy: 0.9957
# Epoch 400/500
# 4/4 - 2s - loss: 0.0111 - accuracy: 0.9971
# Epoch 401/500
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.9942
# Epoch 402/500
# 4/4 - 2s - loss: 0.0138 - accuracy: 0.9948
# Epoch 403/500
# 4/4 - 2s - loss: 0.0099 - accuracy: 0.9965
# Epoch 404/500
# 4/4 - 2s - loss: 0.0138 - accuracy: 0.9956
# Epoch 405/500
# 4/4 - 2s - loss: 0.0117 - accuracy: 0.9966
# Epoch 406/500
# 4/4 - 2s - loss: 0.0128 - accuracy: 0.9951
# Epoch 407/500
# 4/4 - 2s - loss: 0.0117 - accuracy: 0.9962
# Epoch 408/500
# 4/4 - 2s - loss: 0.0108 - accuracy: 0.9962
# Epoch 409/500
# 4/4 - 2s - loss: 0.0149 - accuracy: 0.9951
# Epoch 410/500
# 4/4 - 2s - loss: 0.0137 - accuracy: 0.9948
# Epoch 411/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9957
# Epoch 412/500
# 4/4 - 2s - loss: 0.0107 - accuracy: 0.9962
# Epoch 413/500
# 4/4 - 2s - loss: 0.0136 - accuracy: 0.9960
# Epoch 414/500
# 4/4 - 2s - loss: 0.0112 - accuracy: 0.9962
# Epoch 415/500
# 4/4 - 2s - loss: 0.0122 - accuracy: 0.9956
# Epoch 416/500
# 4/4 - 2s - loss: 0.0100 - accuracy: 0.9969
# Epoch 417/500
# 4/4 - 2s - loss: 0.0159 - accuracy: 0.9940
# Epoch 418/500
# 4/4 - 2s - loss: 0.0105 - accuracy: 0.9973
# Epoch 419/500
# 4/4 - 2s - loss: 0.0108 - accuracy: 0.9964
# Epoch 420/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9956
# Epoch 421/500
# 4/4 - 2s - loss: 0.0129 - accuracy: 0.9966
# Epoch 422/500
# 4/4 - 2s - loss: 0.0118 - accuracy: 0.9957
# Epoch 423/500
# 4/4 - 2s - loss: 0.0133 - accuracy: 0.9962
# Epoch 424/500
# 4/4 - 2s - loss: 0.0137 - accuracy: 0.9957
# Epoch 425/500
# 4/4 - 2s - loss: 0.0117 - accuracy: 0.9975
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_425_0.998/assets
# Epoch 426/500
# 4/4 - 2s - loss: 0.0115 - accuracy: 0.9956
# Epoch 427/500
# 4/4 - 2s - loss: 0.0110 - accuracy: 0.9957
# Epoch 428/500
# 4/4 - 2s - loss: 0.0129 - accuracy: 0.9955
# Epoch 429/500
# 4/4 - 2s - loss: 0.0149 - accuracy: 0.9951
# Epoch 430/500
# 4/4 - 2s - loss: 0.0106 - accuracy: 0.9962
# Epoch 431/500
# 4/4 - 2s - loss: 0.0161 - accuracy: 0.9951
# Epoch 432/500
# 4/4 - 2s - loss: 0.0120 - accuracy: 0.9962
# Epoch 433/500
# 4/4 - 2s - loss: 0.0134 - accuracy: 0.9955
# Epoch 434/500
# 4/4 - 2s - loss: 0.0136 - accuracy: 0.9960
# Epoch 435/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9957
# Epoch 436/500
# 4/4 - 2s - loss: 0.0118 - accuracy: 0.9961
# Epoch 437/500
# 4/4 - 2s - loss: 0.0088 - accuracy: 0.9970
# Epoch 438/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9955
# Epoch 439/500
# 4/4 - 2s - loss: 0.0135 - accuracy: 0.9962
# Epoch 440/500
# 4/4 - 2s - loss: 0.0112 - accuracy: 0.9960
# Epoch 441/500
# 4/4 - 2s - loss: 0.0124 - accuracy: 0.9965
# Epoch 442/500
# 4/4 - 2s - loss: 0.0127 - accuracy: 0.9955
# Epoch 443/500
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.9938
# Epoch 444/500
# 4/4 - 2s - loss: 0.0110 - accuracy: 0.9966
# Epoch 445/500
# 4/4 - 2s - loss: 0.0071 - accuracy: 0.9977
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_model_445_0.998/assets
# Epoch 446/500
# 4/4 - 2s - loss: 0.0123 - accuracy: 0.9959
# Epoch 447/500
# 4/4 - 2s - loss: 0.0091 - accuracy: 0.9971
# Epoch 448/500
# 4/4 - 2s - loss: 0.0114 - accuracy: 0.9962
# Epoch 449/500
# 4/4 - 2s - loss: 0.0105 - accuracy: 0.9960
# Epoch 450/500
# 4/4 - 2s - loss: 0.0126 - accuracy: 0.9961
# Epoch 451/500
# 4/4 - 2s - loss: 0.0079 - accuracy: 0.9973
# Epoch 452/500
# 4/4 - 2s - loss: 0.0129 - accuracy: 0.9957
# Epoch 453/500
# 4/4 - 2s - loss: 0.0125 - accuracy: 0.9957
# Epoch 454/500
# 4/4 - 2s - loss: 0.0086 - accuracy: 0.9975
# Epoch 455/500
# 4/4 - 2s - loss: 0.0110 - accuracy: 0.9965
# Epoch 456/500
# 4/4 - 2s - loss: 0.0085 - accuracy: 0.9971
# Epoch 457/500
# 4/4 - 2s - loss: 0.0134 - accuracy: 0.9956
# Epoch 458/500
# 4/4 - 2s - loss: 0.0139 - accuracy: 0.9959
# Epoch 459/500
# 4/4 - 2s - loss: 0.0113 - accuracy: 0.9960
# Epoch 460/500
# 4/4 - 2s - loss: 0.0085 - accuracy: 0.9973
# Epoch 461/500
# 4/4 - 2s - loss: 0.0121 - accuracy: 0.9962
# Epoch 462/500
# 4/4 - 2s - loss: 0.0110 - accuracy: 0.9959
# Epoch 463/500
# 4/4 - 2s - loss: 0.0091 - accuracy: 0.9966
# Epoch 464/500
# 4/4 - 2s - loss: 0.0088 - accuracy: 0.9974
# Epoch 465/500
# 4/4 - 2s - loss: 0.0120 - accuracy: 0.9961
# Epoch 466/500
# 4/4 - 2s - loss: 0.0092 - accuracy: 0.9969
# Epoch 467/500
# 4/4 - 2s - loss: 0.0103 - accuracy: 0.9968
# Epoch 468/500
# 4/4 - 2s - loss: 0.0093 - accuracy: 0.9966
# Epoch 469/500
# 4/4 - 2s - loss: 0.0105 - accuracy: 0.9961
# Epoch 470/500
# 4/4 - 2s - loss: 0.0097 - accuracy: 0.9964
# Epoch 471/500
# 4/4 - 2s - loss: 0.0117 - accuracy: 0.9965
# Epoch 472/500
# 4/4 - 2s - loss: 0.0120 - accuracy: 0.9965
# Epoch 473/500
# 4/4 - 2s - loss: 0.0141 - accuracy: 0.9956
# Epoch 474/500
# 4/4 - 2s - loss: 0.0085 - accuracy: 0.9971
# Epoch 475/500
# 4/4 - 2s - loss: 0.0112 - accuracy: 0.9959
# Epoch 476/500
# 4/4 - 2s - loss: 0.0096 - accuracy: 0.9973
# Epoch 477/500
# 4/4 - 2s - loss: 0.0099 - accuracy: 0.9960
# Epoch 478/500
# 4/4 - 2s - loss: 0.0086 - accuracy: 0.9974
# Epoch 479/500
# 4/4 - 2s - loss: 0.0144 - accuracy: 0.9960
# Epoch 480/500
# 4/4 - 2s - loss: 0.0116 - accuracy: 0.9964
# Epoch 481/500
# 4/4 - 2s - loss: 0.0136 - accuracy: 0.9953
# Epoch 482/500
# 4/4 - 2s - loss: 0.0122 - accuracy: 0.9960
# Epoch 483/500
# 4/4 - 2s - loss: 0.0132 - accuracy: 0.9955
# Epoch 484/500
# 4/4 - 2s - loss: 0.0111 - accuracy: 0.9966
# Epoch 485/500
# 4/4 - 2s - loss: 0.0123 - accuracy: 0.9964
# Epoch 486/500
# 4/4 - 2s - loss: 0.0115 - accuracy: 0.9965
# Epoch 487/500
# 4/4 - 2s - loss: 0.0128 - accuracy: 0.9946
# Epoch 488/500
# 4/4 - 2s - loss: 0.0131 - accuracy: 0.9966
# Epoch 489/500
# 4/4 - 2s - loss: 0.0099 - accuracy: 0.9959
# Epoch 490/500
# 4/4 - 2s - loss: 0.0098 - accuracy: 0.9968
# Epoch 491/500
# 4/4 - 2s - loss: 0.0087 - accuracy: 0.9969
# Epoch 492/500
# 4/4 - 2s - loss: 0.0105 - accuracy: 0.9968
# Epoch 493/500
# 4/4 - 2s - loss: 0.0082 - accuracy: 0.9969
# Epoch 494/500
# 4/4 - 2s - loss: 0.0096 - accuracy: 0.9969
# Epoch 495/500
# 4/4 - 2s - loss: 0.0107 - accuracy: 0.9956
# Epoch 496/500
# 4/4 - 2s - loss: 0.0103 - accuracy: 0.9973
# Epoch 497/500
# 4/4 - 2s - loss: 0.0104 - accuracy: 0.9964
# Epoch 498/500
# 4/4 - 2s - loss: 0.0103 - accuracy: 0.9961
# Epoch 499/500
# 4/4 - 2s - loss: 0.0151 - accuracy: 0.9948
# Epoch 500/500
# 4/4 - 2s - loss: 0.0103 - accuracy: 0.9968
# INFO:tensorflow:Assets written to: cnn_noTest_20210516_saved_model_after_fit/assets
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2018 - accuracy: 0.9592
# [0.20176781713962555, 0.9592074751853943]

# %%
from google.colab import files
files.download("/content/cnn_128.zip")
