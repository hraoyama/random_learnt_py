# %%
import tensorflow as tf
import site
import pandas as pd
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import  Dense, Flatten, Activation, Dropout, Embedding, Conv1D, Conv2D, MaxPooling2D, MaxPooling1D, Concatenate, BatchNormalization, GaussianNoise
from tensorflow.keras.layers import LSTM, TimeDistributed, Permute, Reshape, Lambda, RepeatVector, Input, Multiply, SimpleRNN, GRU, LeakyReLU
import os
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
pd.set_option('display.width', 400)
pd.set_option('display.max_columns', 40)

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import h5py as h5
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
import errno
import os
from collections import defaultdict
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.summary import create_file_writer
from sklearn.model_selection import train_test_split
import numpy as np
import itertools
import multiprocessing

# %%
def coShuffled_vectors(X, Y):
    if tf.shape(X)[0] == tf.shape(Y)[0]:
        test_idxs = tf.range(start=0, limit=tf.shape(X)[0], dtype=tf.int32)
        shuffled_test_idxs = tf.random.shuffle(test_idxs)
        return (tf.gather(X, shuffled_test_idxs), tf.gather(Y, shuffled_test_idxs))
    else:
        raise ValueError(f"0-dimension has to be the same {tf.shape(X)[0]} != {tf.shape(Y)[0]}")


def getNpArrayFromH5(hf_Data):
    X_train = hf_Data['Train_Data']  # Get train set
    X_train = np.array(X_train)
    Y_train = hf_Data['Label']  # Get train label
    Y_train = np.array(Y_train)
    return X_train, Y_train

# data extraction
def getData(is500=True, shuffle=False, ise2e=False, include_secondary=False, validation_split=None, isColab=False):
    if not include_secondary:
        hf_Train = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/{"e2e_Train_Data" if ise2e else "Fold_10_Train_Data"}_{str(500) if is500 else str(1000)}.h5', 'r')
        hf_Test = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/{"e2e_Test_Data" if ise2e else "Fold_10_Test_Data"}_{str(500) if is500 else str(1000)}.h5', 'r')
    else:
        hf_Train = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_Secondary_Data_1136.h5', 'r')
        hf_Test = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_Secondary_Data_1136.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    X_validation = Y_validation = None
    if validation_split is not None:
        # sklearn split shuffles anyway
        X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=validation_split)

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation


def getE2eData(is500=True, shuffle=False, include_secondary=False, isColab=False):
    if not include_secondary:
        hf_Train = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_Data_{str(500) if is500 else str(1000)}.h5', 'r')
        hf_Test = h5.File(
            f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_Data_{str(500) if is500 else str(1000)}.h5', 'r')
    else:
        hf_Train = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_Secondary_Data_1136.h5', 'r')
        hf_Test = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_Secondary_Data_1136.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    hf_Val = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Val_Secondary_Data_1136.h5', 'r') if include_secondary else h5.File(
        f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Val_Data_{str(500) if is500 else str(1000)}.h5', 'r')
    X_validation, Y_validation = getNpArrayFromH5(hf_Val)
    Y_validation = to_categorical(Y_validation, 13)  # Process the label of tain

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation


def getE2eDataJustSecondary(shuffle=False,isColab=False):
    hf_Train = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Train_just_Secondary_Data_1000.h5', 'r')
    hf_Test = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Test_just_Secondary_Data_1000.h5', 'r')

    X_train, Y_train = getNpArrayFromH5(hf_Train)
    X_test, Y_test = getNpArrayFromH5(hf_Test)
    Y_train = to_categorical(Y_train, 13)  # Process the label of tain
    Y_test = to_categorical(Y_test, 13)  # Process the label of te

    if shuffle:
        X_train, Y_train = coShuffled_vectors(X_train, Y_train)
        X_test, Y_test = coShuffled_vectors(X_test, Y_test)

    hf_Val = h5.File(f'./{"data" if not isColab else "drive/MyDrive/data_papers/ncRNA"}/e2e_Val_just_Secondary_Data_1000.h5', 'r')
    
    X_validation, Y_validation = getNpArrayFromH5(hf_Val)
    Y_validation = to_categorical(Y_validation, 13)  # Process the label of tain

    return X_train, Y_train, X_test, Y_test, X_validation, Y_validation

# %%
def plot_history(history):
    acc_keys = [k for k in history.history.keys() if k in ('accuracy', 'val_accuracy')]
    loss_keys = [k for k in history.history.keys() if not k in acc_keys]
    for k, v in history.history.items():
        if k in acc_keys:
            plt.figure(1)
            plt.plot(v)
        else:
            plt.figure(2)
            plt.plot(v)
    plt.figure(1)
    plt.title('Accuracy vs. epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(acc_keys, loc='lower right')
    plt.figure(2)
    plt.title('Loss vs. epochs')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loss_keys, loc='upper right')
    plt.show()


def get_layer_by_name(layers, name, return_first=True):
    matching_named_layers = [l for l in layers if l.name == name]
    if not matching_named_layers:
        return None
    return matching_named_layers[0] if return_first else matching_named_layers


def get_combined_features_from_models(
        to_combine,
        X_train, Y_train,
        X_test, Y_test,
        reverse_one_hot=False,
        normalize_X_func=None):
    models = []
    models_dict = {}
    X_trains_out = []
    X_test_out = []
    XY_dict = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: None))))

    if reverse_one_hot:
        Y_train_new = np.apply_along_axis(np.argmax, 1, Y_train) + 1
        Y_test_new = np.apply_along_axis(np.argmax, 1, Y_test) + 1
    else:
        Y_train_new = Y_train.copy()
        Y_test_new = Y_test.copy()

    for model_file_name, layer_name, kwargs in to_combine:
        model_here = None
        if isinstance(model_file_name, tf.keras.models.Model):
            model_here = model_file_name
            model_file_name = model_here.name
        else:
            if model_file_name in models_dict.keys():
                model_here = models_dict[model_file_name]
            else:
                model_here = tf.keras.models.load_model(model_file_name,
                                                        **kwargs) if kwargs is not None else tf.keras.models.load_model \
                    (model_file_name)

        features_model = Model(model_here.input,
                               get_layer_by_name(model_here.layers, layer_name).output)
        if normalize_X_func is None:
            X_trains_out.append(np.array(features_model.predict(X_train), dtype='float64'))
            X_test_out.append(np.array(features_model.predict(X_test), dtype='float64'))
        else:
            X_trains_out.append(np.array(normalize_X_func(features_model.predict(X_train)), dtype='float64'))
            X_test_out.append(np.array(normalize_X_func(features_model.predict(X_test)), dtype='float64'))
        XY_dict[model_file_name][layer_name]['Train']['X'] = X_trains_out[-1]
        XY_dict[model_file_name][layer_name]['Test']['X'] = X_test_out[-1]
        XY_dict[model_file_name][layer_name]['Train']['Y'] = Y_train_new
        XY_dict[model_file_name][layer_name]['Test']['Y'] = Y_test_new
        models.append(((model_file_name, layer_name), (model_here, features_model)))
        models_dict[model_file_name] = model_here

    X_train_new = np.concatenate(tuple(X_trains_out), axis=1)
    X_test_new = np.concatenate(tuple(X_test_out), axis=1)

    data_train = (X_train_new, Y_train_new)
    data_test = (X_test_new, Y_test_new)

    return models, data_train, data_test, XY_dict


def make_dir_if_not_exist(used_path):
    if not os.path.isdir(used_path):
        try:
            os.mkdir(used_path)
        except OSError as exc:
            if exc.errno != errno.EEXIST:
                raise exc
            else:
                raise ValueError(f'{used_path} directoy cannot be created because its parent directory does not exist.')


def source_model(model_func, model_name, input_shape):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)
    return m


def compile_and_fit_model_with_tb(model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_every_epoch=True,
                                  save_final=False,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)
    tb_callback = TensorBoard(log_dir=f'{m.name}_logs', histogram_freq=kwargs.pop("histogram_freq", 1))
    if save_every_epoch:
        tb_callback.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.2f}'))
    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=[tb_callback], verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)
    # m.save(f"{m.name}_Tenth_Fold_New_Model_500_8") #Save the model


def compile_and_fit_model(model_func,
                          model_name,
                          input_shape,
                          X_train,
                          Y_train,
                          save_every_epoch=True,
                          save_final=False,
                          **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_every_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.2f}'))
    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)


def compile_model_and_fit_with_custom_loop(model_func,
                                           model_name,
                                           input_shape,
                                           X_train,
                                           Y_train,
                                           **kwargs):
    make_dir_if_not_exist(model_name)
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    train_writer = create_file_writer(f'{m.name}_logs/train/')
    test_writer = create_file_writer(f'{m.name}_logs/test/')
    train_step = test_step = 0

    acc_metric = tf.keras.metrics.CategoricalAccuracy()
    optimizer = tf.keras.optimizers.Adam()
    num_epochs = kwargs.get("epochs", 10)

    AUTOTUNE = tf.data.experimental.AUTOTUNE
    BATCH_SIZE = kwargs.get("batch_size", 32)
    X_test, Y_test = kwargs.get("validation_data", (None, None))
    if X_test is None:
        raise ValueError("Missing X validation data")
    if Y_test is None:
        raise ValueError("Missing Y validation data")

    train_dataset_tf = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
    train_dataset_tf = train_dataset_tf.batch(BATCH_SIZE)
    train_dataset_tf = train_dataset_tf.prefetch(AUTOTUNE)

    test_dataset_tf = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    test_dataset_tf = train_dataset_tf.batch(BATCH_SIZE)
    test_dataset_tf = train_dataset_tf.prefetch(AUTOTUNE)

    loss_fn = tf.keras.losses.CategoricalCrossentropy()

    for epoch in range(num_epochs):
        # Iterate through training set
        for batch_idx, (x, y) in enumerate(train_dataset_tf):
            with tf.GradientTape() as tape:
                y_pred = m(x, training=True)
                loss = loss_fn(y, y_pred)

            gradients = tape.gradient(loss, m.trainable_weights)
            optimizer.apply_gradients(zip(gradients, m.trainable_weights))
            acc_metric.update_state(y, y_pred)

            with train_writer.as_default():
                tf.summary.scalar("Loss", loss, step=train_step)
                tf.summary.scalar(
                    "Accuracy", acc_metric.result(), step=train_step,
                )
                train_step += 1
        # Reset accuracy in between epochs (and for testing and test)
        acc_metric.reset_states()
        # Iterate through test set
        for batch_idx, (x, y) in enumerate(test_dataset_tf):
            y_pred = m(x, training=False)
            loss = loss_fn(y, y_pred)
            acc_metric.update_state(y, y_pred)
            with test_writer.as_default():
                tf.summary.scalar("Loss", loss, step=test_step)
                tf.summary.scalar(
                    "Accuracy", acc_metric.result(), step=test_step,
                )
                test_step += 1

        acc_metric.reset_states()  # Reset accuracy in between epochs (and for testing and test)

    return m


def reinitialize_weights(model):
    for ix, layer in enumerate(model.layers):
        if hasattr(model.layers[ix], 'kernel_initializer') and hasattr(model.layers[ix], 'bias_initializer'):
            weight_initializer = model.layers[ix].kernel_initializer
            bias_initializer = model.layers[ix].bias_initializer

            old_weights, old_biases = model.layers[ix].get_weights()

            model.layers[ix].set_weights([
                weight_initializer(shape=old_weights.shape),
                bias_initializer(shape=len(old_biases))])
    return model


def reverse_tensor(X):
    return tf.gather(X, tf.reverse(tf.range(start=0, limit=tf.shape(X)[0], dtype=tf.int32), (0,)))


def run_mirrored_strategy(model_func, base_batch_size, nepochs, x_train, y_train, x_test, y_test, **kwargs):
    strategy = tf.distribute.MirroredStrategy()
    with strategy.scope():
        model = model_func()
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=tf.keras.metrics.SparseCategoricalAccuracy()
        )
    batch_size_mirr_strat = base_batch_size * strategy.num_replicas_in_sync
    history = model.fit(x_train, y_train, epochs=nepochs, batch_size=batch_size_mirr_strat,
                        validation_data=(x_test, y_test),
                        **kwargs)
    return model, history


def sparse_setdiff(a1, a2):
    a1a = a1.reshape(a1.shape[0], -1)
    a2a = a2.reshape(a2.shape[0], -1)
    spa2a = [np.where(x)[0].tolist() for x in a2a]
    spa1a = [np.where(x)[0].tolist() for x in a1a]
    idxs_to_keep = []
    for idx, sample in enumerate(spa1a):
        try:
            spa2a.index(sample)
        except ValueError:
            # not in list
            idxs_to_keep.append(idx)
    return a1[idxs_to_keep], idxs_to_keep


def unpacking_apply_along_axis(all_args):
    """
    Like numpy.apply_along_axis(), but with arguments in a tuple
    instead.

    This function is useful with multiprocessing.Pool().map(): (1)
    map() only handles functions that take a single argument, and (2)
    this function can generally be imported from a module, as required
    by map().
    """
    (func1d, axis, arr, args, kwargs) = all_args
    # return np.apply_along_axis(func1d, axis, arr, *args, **kwargs)


def parallel_apply_along_axis(func1d, axis, arr, *args, **kwargs):
    """
    Like numpy.apply_along_axis(), but takes advantage of multiple
    cores.
    """
    # Effective axis where apply_along_axis() will be applied by each
    # worker (any non-zero axis number would work, so as to allow the use
    # of `np.array_split()`, which is only done on axis 0):
    effective_axis = 1 if axis == 0 else axis
    if effective_axis != axis:
        arr = arr.swapaxes(axis, effective_axis)

    # Chunks for the mapping (only a few chunks):
    chunks = [(func1d, effective_axis, sub_arr, args, kwargs)
              for sub_arr in np.array_split(arr, multiprocessing.cpu_count())]

    pool = multiprocessing.Pool()
    individual_results = pool.map(unpacking_apply_along_axis, chunks)
    # Freeing the workers:
    pool.close()
    pool.join()

    return np.concatenate(individual_results)

# %%
def baseline_CNN_finalist(model_name, inshape, num_classes = 13):

    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Conv1D(128 ,10 ,padding='same' ,input_shape=inshape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(128 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Conv1D(256 ,10 ,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))

    model.add(tf.keras.layers.GaussianNoise(1))
    model.add(tf.keras.layers.Dropout(rate=0.5))

    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(128))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(64))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax))
    model._name = model_name

    return model


def compile_and_fit_model_basic(  model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{val_accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='val_accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

def compile_and_fit_model_basic_noVal(  model_func,
                                  model_name,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
        m._name = model_name
    else:
        m = model_func(model_name, input_shape)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(model_name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

# %%
def baseline_robust_CNN(inshape,num_classes, multiplier):
    s = multiplier
    r = 0.5*multiplier
    name = f"CNN_robust_s{s:.2f}_r{r:.2f}"

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv1D(256,10,padding='same',input_shape=inshape)) 
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))
    model.add(tf.keras.layers.GaussianNoise(s))
    model.add(tf.keras.layers.Dropout(r))
    model.add(tf.keras.layers.Conv1D(256,10,padding='same')) 
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))
    model.add(tf.keras.layers.GaussianNoise(s))
    model.add(tf.keras.layers.Dropout(rate=r))
    model.add(tf.keras.layers.Conv1D(256,10,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(2))
    model.add(tf.keras.layers.Conv1D(256,10,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))
    model.add(tf.keras.layers.GaussianNoise(s))
    model.add(tf.keras.layers.Dropout(r))
    
    model.add(tf.keras.layers.Conv1D(256,10,padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    model.add(tf.keras.layers.MaxPooling1D(4))
    
    model.add(tf.keras.layers.GaussianNoise(s))
    model.add(tf.keras.layers.Dropout(r))
    
    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(128))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))
    
    model.add(tf.keras.layers.Dense(64))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU(alpha=0.5))

    model.add(tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax))
    model._name = name

    return model

def compile_and_fit_model_basic_robust(  multiplier,
                                             model_func,
                                  input_shape,
                                  X_train,
                                  Y_train,
                                  save_max_epoch=True,
                                  save_final=False,
                                  patience_count = None,
                                  **kwargs):
    m = None
    if isinstance(model_func, tf.keras.models.Model):
        m = model_func
    else:
        m = model_func(input_shape, Y_train.shape[-1], multiplier)

    callbacks_used = []
    if save_max_epoch:
        callbacks_used.append(ModelCheckpoint(f'{m.name}' + '_model_{epoch:03d}_{accuracy:0.3f}',
                                              save_weights_only=False,
                                              monitor='accuracy',
                                              mode='max',
                                              save_best_only=True))
    if patience_count is not None:
        callbacks_used.append(tf.keras.callbacks.EarlyStopping(patience=patience_count))

    m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = m.fit(X_train, Y_train, callbacks=callbacks_used, verbose=2, **kwargs)
    if save_final:
        make_dir_if_not_exist(m.name)
        m.save(f"{m.name}_saved_model_after_fit")  # Save the model
    return (m, history)

# %%
# 'new' data 
X_train_1000e, Y_train_1000e, X_test_1000e, Y_test_1000e, X_val_1000e, Y_val_1000e = getE2eData(is500=False,
                                                                                                    include_secondary=False,
                                                                                                    isColab=True)
X_train_1000e_w2nd, Y_train_1000e_w2nd, X_test_1000e_w2nd, Y_test_1000e_w2nd, X_val_1000e_w2nd, Y_val_1000e_w2nd = getE2eData(is500=False, include_secondary=True, isColab=True)
X_train_1000e_j2nd, Y_train_1000e_j2nd, X_test_1000e_j2nd, Y_test_1000e_j2nd, X_val_1000e_j2nd, Y_val_1000e_j2nd = getE2eDataJustSecondary(isColab=True)

# %%
# merge into a new train:
X_new_train = np.concatenate( (X_train_1000e, X_val_1000e), axis=0 )
Y_new_train = np.concatenate( (Y_train_1000e, Y_val_1000e), axis=0 )    

X_new_train_j2nd = np.concatenate( (X_train_1000e_j2nd, X_val_1000e_j2nd), axis=0 )
Y_new_train_j2nd = np.concatenate( (Y_train_1000e_j2nd, Y_val_1000e_j2nd), axis=0 )    

X_new_train_w2nd = np.concatenate( (X_train_1000e_w2nd, X_val_1000e_w2nd), axis=0 )
Y_new_train_w2nd = np.concatenate( (Y_train_1000e_w2nd, Y_val_1000e_w2nd), axis=0 )

# %%
make_dir_if_not_exist
# Out:
# <function __main__.make_dir_if_not_exist>

# %%
print(X_train_1000e.shape)
print(Y_train_1000e.shape)
print(X_val_1000e.shape)
print(Y_val_1000e.shape)
# Out:
# (6858, 1000, 8)
# (6858, 13)
# (857, 1000, 8)
# (857, 13)

# %%
# merge into a new train:
X_new_train = np.concatenate( (X_train_1000e, X_val_1000e), axis=0 )
Y_new_train = np.concatenate( (Y_train_1000e, Y_val_1000e), axis=0 )

# %%
results_robust
# Out:
# []

# %%
multipliers = [0.0, 0.2, 0.4, 0.6, 0.8, 1, 1.2, 1.4, 1.6, 1.8, 1.99]
results_robust = []
for m in  multipliers:
  results_robust.append(compile_and_fit_model_basic_robust(m,
                                                    baseline_robust_CNN,
                                                    X_train_1000e[0].shape,
                                                    X_train_1000e,
                                                    Y_train_1000e,
                                                    save_max_epoch=False,
                                                    save_final=True,
                                                    batch_size=128,
                                                    epochs=250,
                                                    class_weight=None,
                                                    validation_data=(X_val_1000e,Y_val_1000e))
  )
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 6/250
# 54/54 - 4s - loss: 0.0823 - accuracy: 0.9824 - val_loss: 4.0196 - val_accuracy: 0.2229
# Epoch 7/250
# 54/54 - 4s - loss: 0.0414 - accuracy: 0.9950 - val_loss: 3.4294 - val_accuracy: 0.3524
# Epoch 8/250
# 54/54 - 4s - loss: 0.0393 - accuracy: 0.9924 - val_loss: 1.9073 - val_accuracy: 0.5076
# Epoch 9/250
# 54/54 - 4s - loss: 0.0244 - accuracy: 0.9971 - val_loss: 1.0804 - val_accuracy: 0.7001
# Epoch 10/250
# 54/54 - 4s - loss: 0.0155 - accuracy: 0.9985 - val_loss: 0.3567 - val_accuracy: 0.8996
# Epoch 11/250
# 54/54 - 4s - loss: 0.0091 - accuracy: 0.9996 - val_loss: 0.3324 - val_accuracy: 0.8961
# Epoch 12/250
# 54/54 - 4s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9148
# Epoch 13/250
# 54/54 - 4s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2731 - val_accuracy: 0.9195
# Epoch 14/250
# 54/54 - 4s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9358
# Epoch 15/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9312
# Epoch 16/250
# 54/54 - 4s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9300
# Epoch 17/250
# 54/54 - 4s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2364 - val_accuracy: 0.9265
# Epoch 18/250
# 54/54 - 4s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9347
# Epoch 19/250
# 54/54 - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9347
# Epoch 20/250
# 54/54 - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9323
# Epoch 21/250
# 54/54 - 4s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9300
# Epoch 22/250
# 54/54 - 4s - loss: 8.5286e-04 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9335
# Epoch 23/250
# 54/54 - 4s - loss: 7.7909e-04 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9370
# Epoch 24/250
# 54/54 - 4s - loss: 7.8786e-04 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9393
# Epoch 25/250
# 54/54 - 4s - loss: 7.0038e-04 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9382
# Epoch 26/250
# 54/54 - 4s - loss: 6.7565e-04 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9405
# Epoch 27/250
# 54/54 - 4s - loss: 6.2599e-04 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9358
# Epoch 28/250
# 54/54 - 4s - loss: 6.4072e-04 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9253
# Epoch 29/250
# 54/54 - 4s - loss: 5.7975e-04 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9405
# Epoch 30/250
# 54/54 - 4s - loss: 5.6020e-04 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9312
# Epoch 31/250
# 54/54 - 4s - loss: 4.6159e-04 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9393
# Epoch 32/250
# 54/54 - 4s - loss: 4.6934e-04 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9347
# Epoch 33/250
# 54/54 - 4s - loss: 4.4735e-04 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9370
# Epoch 34/250
# 54/54 - 4s - loss: 4.0377e-04 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9347
# Epoch 35/250
# 54/54 - 4s - loss: 4.1178e-04 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9347
# Epoch 36/250
# 54/54 - 4s - loss: 3.6613e-04 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9347
# Epoch 37/250
# 54/54 - 4s - loss: 3.9200e-04 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9358
# Epoch 38/250
# 54/54 - 4s - loss: 4.2306e-04 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9323
# Epoch 39/250
# 54/54 - 4s - loss: 3.6787e-04 - accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.9370
# Epoch 40/250
# 54/54 - 4s - loss: 3.5919e-04 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9405
# Epoch 41/250
# 54/54 - 4s - loss: 2.9846e-04 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9382
# Epoch 42/250
# 54/54 - 4s - loss: 2.9016e-04 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9405
# Epoch 43/250
# 54/54 - 4s - loss: 2.6709e-04 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9370
# Epoch 44/250
# 54/54 - 4s - loss: 2.5693e-04 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9428
# Epoch 45/250
# 54/54 - 4s - loss: 2.6332e-04 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9370
# Epoch 46/250
# 54/54 - 4s - loss: 2.1999e-04 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9358
# Epoch 47/250
# 54/54 - 4s - loss: 2.0984e-04 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9428
# Epoch 48/250
# 54/54 - 4s - loss: 1.9441e-04 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9405
# Epoch 49/250
# 54/54 - 4s - loss: 2.0198e-04 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9405
# Epoch 50/250
# 54/54 - 4s - loss: 1.9681e-04 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9440
# Epoch 51/250
# 54/54 - 4s - loss: 1.9935e-04 - accuracy: 1.0000 - val_loss: 0.1913 - val_accuracy: 0.9417
# Epoch 52/250
# 54/54 - 4s - loss: 2.0186e-04 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9393
# Epoch 53/250
# 54/54 - 4s - loss: 1.6858e-04 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9417
# Epoch 54/250
# 54/54 - 4s - loss: 1.6281e-04 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9428
# Epoch 55/250
# 54/54 - 4s - loss: 1.5266e-04 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9382
# Epoch 56/250
# 54/54 - 4s - loss: 1.5680e-04 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9370
# Epoch 57/250
# 54/54 - 4s - loss: 1.4331e-04 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9417
# Epoch 58/250
# 54/54 - 4s - loss: 1.7375e-04 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.9277
# Epoch 59/250
# 54/54 - 4s - loss: 1.4392e-04 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9417
# Epoch 60/250
# 54/54 - 4s - loss: 1.5754e-04 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9335
# Epoch 61/250
# 54/54 - 4s - loss: 1.3257e-04 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9393
# Epoch 62/250
# 54/54 - 4s - loss: 1.1898e-04 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9393
# Epoch 63/250
# 54/54 - 4s - loss: 1.1587e-04 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9405
# Epoch 64/250
# 54/54 - 4s - loss: 1.1368e-04 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9440
# Epoch 65/250
# 54/54 - 4s - loss: 1.0456e-04 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9393
# Epoch 66/250
# 54/54 - 4s - loss: 1.0727e-04 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9405
# Epoch 67/250
# 54/54 - 4s - loss: 1.0663e-04 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9487
# Epoch 68/250
# 54/54 - 4s - loss: 9.9321e-05 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9417
# Epoch 69/250
# 54/54 - 4s - loss: 9.6213e-05 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9417
# Epoch 70/250
# 54/54 - 4s - loss: 9.3332e-05 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9417
# Epoch 71/250
# 54/54 - 4s - loss: 8.3661e-05 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9487
# Epoch 72/250
# 54/54 - 4s - loss: 1.1359e-04 - accuracy: 1.0000 - val_loss: 0.3871 - val_accuracy: 0.8973
# Epoch 73/250
# 54/54 - 4s - loss: 2.1574e-04 - accuracy: 1.0000 - val_loss: 0.2713 - val_accuracy: 0.9277
# Epoch 74/250
# 54/54 - 4s - loss: 0.2717 - accuracy: 0.9269 - val_loss: 256.0831 - val_accuracy: 0.0805
# Epoch 75/250
# 54/54 - 4s - loss: 0.4793 - accuracy: 0.8456 - val_loss: 18.4211 - val_accuracy: 0.3804
# Epoch 76/250
# 54/54 - 4s - loss: 0.1775 - accuracy: 0.9433 - val_loss: 5.6843 - val_accuracy: 0.5146
# Epoch 77/250
# 54/54 - 4s - loss: 0.0765 - accuracy: 0.9781 - val_loss: 1.1919 - val_accuracy: 0.7643
# Epoch 78/250
# 54/54 - 4s - loss: 0.0405 - accuracy: 0.9888 - val_loss: 0.5402 - val_accuracy: 0.8530
# Epoch 79/250
# 54/54 - 4s - loss: 0.0183 - accuracy: 0.9965 - val_loss: 0.7004 - val_accuracy: 0.8215
# Epoch 80/250
# 54/54 - 4s - loss: 0.0114 - accuracy: 0.9981 - val_loss: 0.3966 - val_accuracy: 0.8938
# Epoch 81/250
# 54/54 - 4s - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.3598 - val_accuracy: 0.8938
# Epoch 82/250
# 54/54 - 4s - loss: 0.0054 - accuracy: 0.9993 - val_loss: 0.5966 - val_accuracy: 0.8681
# Epoch 83/250
# 54/54 - 4s - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.3700 - val_accuracy: 0.9043
# Epoch 84/250
# 54/54 - 4s - loss: 0.0034 - accuracy: 0.9999 - val_loss: 0.4507 - val_accuracy: 0.8868
# Epoch 85/250
# 54/54 - 4s - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.3435 - val_accuracy: 0.9067
# Epoch 86/250
# 54/54 - 4s - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.3248 - val_accuracy: 0.9172
# Epoch 87/250
# 54/54 - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2978 - val_accuracy: 0.9230
# Epoch 88/250
# 54/54 - 4s - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.3453 - val_accuracy: 0.9043
# Epoch 89/250
# 54/54 - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3864 - val_accuracy: 0.9055
# Epoch 90/250
# 54/54 - 4s - loss: 9.1003e-04 - accuracy: 1.0000 - val_loss: 0.3288 - val_accuracy: 0.9113
# Epoch 91/250
# 54/54 - 4s - loss: 9.1992e-04 - accuracy: 1.0000 - val_loss: 0.3249 - val_accuracy: 0.9195
# Epoch 92/250
# 54/54 - 4s - loss: 9.2269e-04 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.8845
# Epoch 93/250
# 54/54 - 4s - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.4899 - val_accuracy: 0.8880
# Epoch 94/250
# 54/54 - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3657 - val_accuracy: 0.9067
# Epoch 95/250
# 54/54 - 4s - loss: 7.0639e-04 - accuracy: 1.0000 - val_loss: 0.3904 - val_accuracy: 0.9067
# Epoch 96/250
# 54/54 - 4s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.4250 - val_accuracy: 0.8973
# Epoch 97/250
# 54/54 - 4s - loss: 0.0165 - accuracy: 0.9961 - val_loss: 1.2348 - val_accuracy: 0.7830
# Epoch 98/250
# 54/54 - 4s - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.9902 - val_accuracy: 0.7760
# Epoch 99/250
# 54/54 - 4s - loss: 0.0089 - accuracy: 0.9968 - val_loss: 1.1767 - val_accuracy: 0.7830
# Epoch 100/250
# 54/54 - 4s - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.7466 - val_accuracy: 0.8518
# Epoch 101/250
# 54/54 - 4s - loss: 0.0103 - accuracy: 0.9978 - val_loss: 0.6930 - val_accuracy: 0.8436
# Epoch 102/250
# 54/54 - 4s - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.6265 - val_accuracy: 0.8600
# Epoch 103/250
# 54/54 - 4s - loss: 0.0218 - accuracy: 0.9934 - val_loss: 1.5569 - val_accuracy: 0.7188
# Epoch 104/250
# 54/54 - 4s - loss: 0.0197 - accuracy: 0.9943 - val_loss: 0.8205 - val_accuracy: 0.8378
# Epoch 105/250
# 54/54 - 4s - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.5908 - val_accuracy: 0.8751
# Epoch 106/250
# 54/54 - 4s - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.7073 - val_accuracy: 0.8681
# Epoch 107/250
# 54/54 - 4s - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.7984 - val_accuracy: 0.8320
# Epoch 108/250
# 54/54 - 4s - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.5870 - val_accuracy: 0.8553
# Epoch 109/250
# 54/54 - 4s - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.3890 - val_accuracy: 0.9113
# Epoch 110/250
# 54/54 - 4s - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.7159 - val_accuracy: 0.8483
# Epoch 111/250
# 54/54 - 4s - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.6047 - val_accuracy: 0.8751
# Epoch 112/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.3842 - val_accuracy: 0.9218
# Epoch 113/250
# 54/54 - 4s - loss: 9.0792e-04 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9125
# Epoch 114/250
# 54/54 - 4s - loss: 6.4826e-04 - accuracy: 1.0000 - val_loss: 0.3238 - val_accuracy: 0.9218
# Epoch 115/250
# 54/54 - 4s - loss: 4.1782e-04 - accuracy: 1.0000 - val_loss: 0.2938 - val_accuracy: 0.9242
# Epoch 116/250
# 54/54 - 4s - loss: 4.4487e-04 - accuracy: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.9218
# Epoch 117/250
# 54/54 - 4s - loss: 4.4731e-04 - accuracy: 0.9999 - val_loss: 0.3665 - val_accuracy: 0.9090
# Epoch 118/250
# 54/54 - 4s - loss: 3.1411e-04 - accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.9207
# Epoch 119/250
# 54/54 - 4s - loss: 3.5706e-04 - accuracy: 1.0000 - val_loss: 0.3075 - val_accuracy: 0.9253
# Epoch 120/250
# 54/54 - 4s - loss: 2.6106e-04 - accuracy: 1.0000 - val_loss: 0.3259 - val_accuracy: 0.9242
# Epoch 121/250
# 54/54 - 4s - loss: 3.1680e-04 - accuracy: 1.0000 - val_loss: 0.3031 - val_accuracy: 0.9300
# Epoch 122/250
# 54/54 - 4s - loss: 1.8200e-04 - accuracy: 1.0000 - val_loss: 0.2897 - val_accuracy: 0.9253
# Epoch 123/250
# 54/54 - 4s - loss: 1.3319e-04 - accuracy: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.9277
# Epoch 124/250
# 54/54 - 4s - loss: 1.6121e-04 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9253
# Epoch 125/250
# 54/54 - 4s - loss: 1.9781e-04 - accuracy: 1.0000 - val_loss: 0.2954 - val_accuracy: 0.9253
# Epoch 126/250
# 54/54 - 4s - loss: 1.5087e-04 - accuracy: 1.0000 - val_loss: 0.2887 - val_accuracy: 0.9253
# Epoch 127/250
# 54/54 - 4s - loss: 1.1325e-04 - accuracy: 1.0000 - val_loss: 0.2744 - val_accuracy: 0.9312
# Epoch 128/250
# 54/54 - 4s - loss: 1.2111e-04 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.9288
# Epoch 129/250
# 54/54 - 4s - loss: 1.1256e-04 - accuracy: 1.0000 - val_loss: 0.2836 - val_accuracy: 0.9312
# Epoch 130/250
# 54/54 - 4s - loss: 1.0070e-04 - accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 0.9288
# Epoch 131/250
# 54/54 - 4s - loss: 1.1790e-04 - accuracy: 1.0000 - val_loss: 0.2891 - val_accuracy: 0.9277
# Epoch 132/250
# 54/54 - 4s - loss: 1.0535e-04 - accuracy: 1.0000 - val_loss: 0.3107 - val_accuracy: 0.9277
# Epoch 133/250
# 54/54 - 4s - loss: 1.3036e-04 - accuracy: 1.0000 - val_loss: 0.2859 - val_accuracy: 0.9265
# Epoch 134/250
# 54/54 - 4s - loss: 7.5052e-05 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9277
# Epoch 135/250
# 54/54 - 4s - loss: 1.7861e-04 - accuracy: 1.0000 - val_loss: 0.2984 - val_accuracy: 0.9242
# Epoch 136/250
# 54/54 - 4s - loss: 9.5903e-05 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9312
# Epoch 137/250
# 54/54 - 4s - loss: 1.0901e-04 - accuracy: 1.0000 - val_loss: 0.2850 - val_accuracy: 0.9312
# Epoch 138/250
# 54/54 - 4s - loss: 8.8596e-05 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9277
# Epoch 139/250
# 54/54 - 4s - loss: 7.4716e-05 - accuracy: 1.0000 - val_loss: 0.2819 - val_accuracy: 0.9265
# Epoch 140/250
# 54/54 - 4s - loss: 1.5488e-04 - accuracy: 1.0000 - val_loss: 0.3302 - val_accuracy: 0.9230
# Epoch 141/250
# 54/54 - 4s - loss: 1.1301e-04 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9242
# Epoch 142/250
# 54/54 - 4s - loss: 8.2043e-05 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9253
# Epoch 143/250
# 54/54 - 4s - loss: 6.7673e-05 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.9300
# Epoch 144/250
# 54/54 - 4s - loss: 5.0761e-05 - accuracy: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9323
# Epoch 145/250
# 54/54 - 4s - loss: 5.6145e-05 - accuracy: 1.0000 - val_loss: 0.2766 - val_accuracy: 0.9347
# Epoch 146/250
# 54/54 - 4s - loss: 5.4162e-05 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9370
# Epoch 147/250
# 54/54 - 4s - loss: 5.0499e-05 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9358
# Epoch 148/250
# 54/54 - 4s - loss: 5.3999e-05 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9300
# Epoch 149/250
# 54/54 - 4s - loss: 1.7454e-04 - accuracy: 0.9999 - val_loss: 0.3424 - val_accuracy: 0.9172
# Epoch 150/250
# 54/54 - 4s - loss: 0.0542 - accuracy: 0.9853 - val_loss: 6.3800 - val_accuracy: 0.5333
# Epoch 151/250
# 54/54 - 4s - loss: 0.1098 - accuracy: 0.9656 - val_loss: 2.6525 - val_accuracy: 0.6709
# Epoch 152/250
# 54/54 - 4s - loss: 0.0341 - accuracy: 0.9880 - val_loss: 0.7027 - val_accuracy: 0.8728
# Epoch 153/250
# 54/54 - 4s - loss: 0.0182 - accuracy: 0.9939 - val_loss: 0.5176 - val_accuracy: 0.8880
# Epoch 154/250
# 54/54 - 4s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.6296 - val_accuracy: 0.8705
# Epoch 155/250
# 54/54 - 4s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.4231 - val_accuracy: 0.9137
# Epoch 156/250
# 54/54 - 4s - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.3214 - val_accuracy: 0.9195
# Epoch 157/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.3930 - val_accuracy: 0.9172
# Epoch 158/250
# 54/54 - 4s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.3650 - val_accuracy: 0.9148
# Epoch 159/250
# 54/54 - 4s - loss: 9.3864e-04 - accuracy: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.9347
# Epoch 160/250
# 54/54 - 4s - loss: 5.8038e-04 - accuracy: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9277
# Epoch 161/250
# 54/54 - 4s - loss: 7.5621e-04 - accuracy: 0.9999 - val_loss: 0.3645 - val_accuracy: 0.9148
# Epoch 162/250
# 54/54 - 4s - loss: 6.7908e-04 - accuracy: 0.9997 - val_loss: 0.3208 - val_accuracy: 0.9312
# Epoch 163/250
# 54/54 - 4s - loss: 5.3018e-04 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9265
# Epoch 164/250
# 54/54 - 4s - loss: 5.7200e-04 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9300
# Epoch 165/250
# 54/54 - 4s - loss: 7.1978e-04 - accuracy: 0.9999 - val_loss: 0.4467 - val_accuracy: 0.9055
# Epoch 166/250
# 54/54 - 4s - loss: 3.2229e-04 - accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.9335
# Epoch 167/250
# 54/54 - 4s - loss: 2.1348e-04 - accuracy: 1.0000 - val_loss: 0.3098 - val_accuracy: 0.9323
# Epoch 168/250
# 54/54 - 4s - loss: 3.0826e-04 - accuracy: 1.0000 - val_loss: 0.3015 - val_accuracy: 0.9335
# Epoch 169/250
# 54/54 - 4s - loss: 2.8553e-04 - accuracy: 1.0000 - val_loss: 0.2917 - val_accuracy: 0.9300
# Epoch 170/250
# 54/54 - 4s - loss: 1.5935e-04 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9323
# Epoch 171/250
# 54/54 - 4s - loss: 2.9733e-04 - accuracy: 1.0000 - val_loss: 0.2957 - val_accuracy: 0.9358
# Epoch 172/250
# 54/54 - 4s - loss: 1.8517e-04 - accuracy: 1.0000 - val_loss: 0.3046 - val_accuracy: 0.9323
# Epoch 173/250
# 54/54 - 4s - loss: 2.1185e-04 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9323
# Epoch 174/250
# 54/54 - 4s - loss: 2.1483e-04 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9347
# Epoch 175/250
# 54/54 - 4s - loss: 1.1448e-04 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9300
# Epoch 176/250
# 54/54 - 4s - loss: 1.7612e-04 - accuracy: 1.0000 - val_loss: 0.2998 - val_accuracy: 0.9300
# Epoch 177/250
# 54/54 - 4s - loss: 1.8310e-04 - accuracy: 1.0000 - val_loss: 0.3215 - val_accuracy: 0.9370
# Epoch 178/250
# 54/54 - 4s - loss: 1.5997e-04 - accuracy: 1.0000 - val_loss: 0.3216 - val_accuracy: 0.9370
# Epoch 179/250
# 54/54 - 4s - loss: 2.4327e-04 - accuracy: 1.0000 - val_loss: 0.3384 - val_accuracy: 0.9323
# Epoch 180/250
# 54/54 - 4s - loss: 1.4074e-04 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9335
# Epoch 181/250
# 54/54 - 4s - loss: 1.0747e-04 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9335
# Epoch 182/250
# 54/54 - 4s - loss: 9.6050e-05 - accuracy: 1.0000 - val_loss: 0.3272 - val_accuracy: 0.9335
# Epoch 183/250
# 54/54 - 4s - loss: 7.7983e-05 - accuracy: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.9347
# Epoch 184/250
# 54/54 - 4s - loss: 8.0468e-05 - accuracy: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.9323
# Epoch 185/250
# 54/54 - 4s - loss: 6.7246e-05 - accuracy: 1.0000 - val_loss: 0.3153 - val_accuracy: 0.9370
# Epoch 186/250
# 54/54 - 4s - loss: 1.3327e-04 - accuracy: 1.0000 - val_loss: 0.3433 - val_accuracy: 0.9288
# Epoch 187/250
# 54/54 - 4s - loss: 5.7783e-05 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9347
# Epoch 188/250
# 54/54 - 4s - loss: 6.1496e-05 - accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.9358
# Epoch 189/250
# 54/54 - 4s - loss: 6.1481e-05 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.9335
# Epoch 190/250
# 54/54 - 4s - loss: 5.2520e-05 - accuracy: 1.0000 - val_loss: 0.3072 - val_accuracy: 0.9347
# Epoch 191/250
# 54/54 - 4s - loss: 5.8675e-05 - accuracy: 1.0000 - val_loss: 0.3234 - val_accuracy: 0.9370
# Epoch 192/250
# 54/54 - 4s - loss: 4.8273e-05 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9335
# Epoch 193/250
# 54/54 - 4s - loss: 5.1202e-05 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9358
# Epoch 194/250
# 54/54 - 4s - loss: 4.5220e-05 - accuracy: 1.0000 - val_loss: 0.3171 - val_accuracy: 0.9358
# Epoch 195/250
# 54/54 - 4s - loss: 4.1815e-05 - accuracy: 1.0000 - val_loss: 0.3235 - val_accuracy: 0.9347
# Epoch 196/250
# 54/54 - 4s - loss: 4.6094e-05 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.9358
# Epoch 197/250
# 54/54 - 4s - loss: 5.4933e-05 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9370
# Epoch 198/250
# 54/54 - 4s - loss: 1.0451e-04 - accuracy: 1.0000 - val_loss: 0.3434 - val_accuracy: 0.9265
# Epoch 199/250
# 54/54 - 4s - loss: 5.6918e-05 - accuracy: 1.0000 - val_loss: 0.3019 - val_accuracy: 0.9382
# Epoch 200/250
# 54/54 - 4s - loss: 4.9022e-05 - accuracy: 1.0000 - val_loss: 0.3045 - val_accuracy: 0.9393
# Epoch 201/250
# 54/54 - 4s - loss: 4.5502e-05 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9370
# Epoch 202/250
# 54/54 - 4s - loss: 6.6669e-05 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9393
# Epoch 203/250
# 54/54 - 4s - loss: 4.1179e-05 - accuracy: 1.0000 - val_loss: 0.3106 - val_accuracy: 0.9393
# Epoch 204/250
# 54/54 - 4s - loss: 5.8694e-05 - accuracy: 1.0000 - val_loss: 0.3097 - val_accuracy: 0.9370
# Epoch 205/250
# 54/54 - 4s - loss: 1.9612e-04 - accuracy: 1.0000 - val_loss: 0.7161 - val_accuracy: 0.8763
# Epoch 206/250
# 54/54 - 4s - loss: 1.1518e-04 - accuracy: 1.0000 - val_loss: 0.4019 - val_accuracy: 0.9172
# Epoch 207/250
# 54/54 - 4s - loss: 5.6171e-05 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9312
# Epoch 208/250
# 54/54 - 4s - loss: 8.0445e-05 - accuracy: 1.0000 - val_loss: 0.3392 - val_accuracy: 0.9312
# Epoch 209/250
# 54/54 - 4s - loss: 6.6124e-05 - accuracy: 1.0000 - val_loss: 0.3236 - val_accuracy: 0.9323
# Epoch 210/250
# 54/54 - 4s - loss: 3.0666e-05 - accuracy: 1.0000 - val_loss: 0.3151 - val_accuracy: 0.9370
# Epoch 211/250
# 54/54 - 4s - loss: 3.8827e-05 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9405
# Epoch 212/250
# 54/54 - 4s - loss: 3.4542e-05 - accuracy: 1.0000 - val_loss: 0.3070 - val_accuracy: 0.9393
# Epoch 213/250
# 54/54 - 4s - loss: 2.6794e-05 - accuracy: 1.0000 - val_loss: 0.3033 - val_accuracy: 0.9405
# Epoch 214/250
# 54/54 - 4s - loss: 2.8910e-05 - accuracy: 1.0000 - val_loss: 0.3052 - val_accuracy: 0.9393
# Epoch 215/250
# 54/54 - 4s - loss: 2.5639e-05 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9405
# Epoch 216/250
# 54/54 - 4s - loss: 2.1484e-05 - accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.9393
# Epoch 217/250
# 54/54 - 4s - loss: 2.5150e-05 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.9393
# Epoch 218/250
# 54/54 - 4s - loss: 1.6642e-05 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9382
# Epoch 219/250
# 54/54 - 4s - loss: 2.6703e-05 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.9300
# Epoch 220/250
# 54/54 - 4s - loss: 2.9680e-05 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9393
# Epoch 221/250
# 54/54 - 4s - loss: 1.6514e-05 - accuracy: 1.0000 - val_loss: 0.3119 - val_accuracy: 0.9370
# Epoch 222/250
# 54/54 - 4s - loss: 2.0602e-05 - accuracy: 1.0000 - val_loss: 0.3229 - val_accuracy: 0.9370
# Epoch 223/250
# 54/54 - 4s - loss: 2.5681e-05 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9405
# Epoch 224/250
# 54/54 - 4s - loss: 3.4906e-05 - accuracy: 1.0000 - val_loss: 0.3529 - val_accuracy: 0.9300
# Epoch 225/250
# 54/54 - 4s - loss: 2.0369e-05 - accuracy: 1.0000 - val_loss: 0.3352 - val_accuracy: 0.9393
# Epoch 226/250
# 54/54 - 4s - loss: 1.7859e-05 - accuracy: 1.0000 - val_loss: 0.3232 - val_accuracy: 0.9382
# Epoch 227/250
# 54/54 - 4s - loss: 2.7761e-05 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9335
# Epoch 228/250
# 54/54 - 4s - loss: 2.3030e-05 - accuracy: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.9358
# Epoch 229/250
# 54/54 - 4s - loss: 2.1234e-05 - accuracy: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9382
# Epoch 230/250
# 54/54 - 4s - loss: 2.0877e-05 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9300
# Epoch 231/250
# 54/54 - 4s - loss: 1.9241e-05 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9358
# Epoch 232/250
# 54/54 - 4s - loss: 1.8306e-05 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9347
# Epoch 233/250
# 54/54 - 4s - loss: 1.3791e-05 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9382
# Epoch 234/250
# 54/54 - 4s - loss: 1.2284e-05 - accuracy: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.9382
# Epoch 235/250
# 54/54 - 4s - loss: 9.8821e-06 - accuracy: 1.0000 - val_loss: 0.3320 - val_accuracy: 0.9382
# Epoch 236/250
# 54/54 - 4s - loss: 1.2091e-05 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9358
# Epoch 237/250
# 54/54 - 4s - loss: 1.0065e-05 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9358
# Epoch 238/250
# 54/54 - 4s - loss: 1.0822e-05 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 0.9335
# Epoch 239/250
# 54/54 - 4s - loss: 1.1954e-05 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.9358
# Epoch 240/250
# 54/54 - 4s - loss: 9.5598e-06 - accuracy: 1.0000 - val_loss: 0.3395 - val_accuracy: 0.9370
# Epoch 241/250
# 54/54 - 4s - loss: 9.5038e-06 - accuracy: 1.0000 - val_loss: 0.3376 - val_accuracy: 0.9358
# Epoch 242/250
# 54/54 - 4s - loss: 1.4400e-05 - accuracy: 1.0000 - val_loss: 0.3433 - val_accuracy: 0.9358
# Epoch 243/250
# 54/54 - 4s - loss: 1.3006e-05 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9382
# Epoch 244/250
# 54/54 - 4s - loss: 1.2810e-05 - accuracy: 1.0000 - val_loss: 0.3425 - val_accuracy: 0.9370
# Epoch 245/250
# 54/54 - 4s - loss: 0.0444 - accuracy: 0.9886 - val_loss: 7.9413 - val_accuracy: 0.4539
# Epoch 246/250
# 54/54 - 4s - loss: 0.1522 - accuracy: 0.9532 - val_loss: 7.2892 - val_accuracy: 0.4994
# Epoch 247/250
# 54/54 - 4s - loss: 0.0350 - accuracy: 0.9880 - val_loss: 0.8026 - val_accuracy: 0.8483
# Epoch 248/250
# 54/54 - 4s - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.4256 - val_accuracy: 0.8973
# Epoch 249/250
# 54/54 - 4s - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.4470 - val_accuracy: 0.9067
# Epoch 250/250
# 54/54 - 4s - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.3903 - val_accuracy: 0.9183
# INFO:tensorflow:Assets written to: CNN_robust_s0.20_r0.10_saved_model_after_fit/assets
# Epoch 1/250
# 54/54 - 6s - loss: 1.8250 - accuracy: 0.3968 - val_loss: 3.2893 - val_accuracy: 0.0758
# Epoch 2/250
# 54/54 - 4s - loss: 1.0312 - accuracy: 0.6702 - val_loss: 5.3673 - val_accuracy: 0.0758
# Epoch 3/250
# 54/54 - 4s - loss: 0.6731 - accuracy: 0.7871 - val_loss: 7.2034 - val_accuracy: 0.0758
# Epoch 4/250
# 54/54 - 4s - loss: 0.4507 - accuracy: 0.8660 - val_loss: 7.4111 - val_accuracy: 0.0758
# Epoch 5/250
# 54/54 - 4s - loss: 0.2995 - accuracy: 0.9111 - val_loss: 6.6920 - val_accuracy: 0.0758
# Epoch 6/250
# 54/54 - 4s - loss: 0.1969 - accuracy: 0.9450 - val_loss: 4.7134 - val_accuracy: 0.2170
# Epoch 7/250
# 54/54 - 4s - loss: 0.1475 - accuracy: 0.9590 - val_loss: 3.9326 - val_accuracy: 0.2229
# Epoch 8/250
# 54/54 - 4s - loss: 0.0903 - accuracy: 0.9783 - val_loss: 1.4063 - val_accuracy: 0.5718
# Epoch 9/250
# 54/54 - 4s - loss: 0.0631 - accuracy: 0.9857 - val_loss: 1.9672 - val_accuracy: 0.5519
# Epoch 10/250
# 54/54 - 4s - loss: 0.0536 - accuracy: 0.9869 - val_loss: 0.5954 - val_accuracy: 0.8261
# Epoch 11/250
# 54/54 - 4s - loss: 0.0387 - accuracy: 0.9915 - val_loss: 0.3038 - val_accuracy: 0.9043
# Epoch 12/250
# 54/54 - 4s - loss: 0.0271 - accuracy: 0.9948 - val_loss: 0.3456 - val_accuracy: 0.8950
# Epoch 13/250
# 54/54 - 4s - loss: 0.0254 - accuracy: 0.9955 - val_loss: 0.3116 - val_accuracy: 0.9090
# Epoch 14/250
# 54/54 - 4s - loss: 0.0188 - accuracy: 0.9966 - val_loss: 0.3861 - val_accuracy: 0.8903
# Epoch 15/250
# 54/54 - 4s - loss: 0.0166 - accuracy: 0.9977 - val_loss: 0.5138 - val_accuracy: 0.8728
# Epoch 16/250
# 54/54 - 4s - loss: 0.0205 - accuracy: 0.9953 - val_loss: 0.3996 - val_accuracy: 0.9043
# Epoch 17/250
# 54/54 - 4s - loss: 0.0298 - accuracy: 0.9929 - val_loss: 0.8670 - val_accuracy: 0.7946
# Epoch 18/250
# 54/54 - 4s - loss: 0.0210 - accuracy: 0.9950 - val_loss: 0.2579 - val_accuracy: 0.9265
# Epoch 19/250
# 54/54 - 4s - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.4164 - val_accuracy: 0.8961
# Epoch 20/250
# 54/54 - 4s - loss: 0.0240 - accuracy: 0.9939 - val_loss: 0.3922 - val_accuracy: 0.9032
# Epoch 21/250
# 54/54 - 4s - loss: 0.0209 - accuracy: 0.9945 - val_loss: 0.3634 - val_accuracy: 0.9067
# Epoch 22/250
# 54/54 - 4s - loss: 0.0158 - accuracy: 0.9958 - val_loss: 0.4210 - val_accuracy: 0.8996
# Epoch 23/250
# 54/54 - 4s - loss: 0.0152 - accuracy: 0.9972 - val_loss: 0.5505 - val_accuracy: 0.8646
# Epoch 24/250
# 54/54 - 4s - loss: 0.0241 - accuracy: 0.9931 - val_loss: 0.3962 - val_accuracy: 0.8915
# Epoch 25/250
# 54/54 - 4s - loss: 0.0224 - accuracy: 0.9930 - val_loss: 0.3326 - val_accuracy: 0.9125
# Epoch 26/250
# 54/54 - 4s - loss: 0.0231 - accuracy: 0.9930 - val_loss: 0.3427 - val_accuracy: 0.9172
# Epoch 27/250
# 54/54 - 4s - loss: 0.0276 - accuracy: 0.9927 - val_loss: 0.8120 - val_accuracy: 0.8110
# Epoch 28/250
# 54/54 - 4s - loss: 0.0181 - accuracy: 0.9959 - val_loss: 0.3276 - val_accuracy: 0.9148
# Epoch 29/250
# 54/54 - 4s - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.5301 - val_accuracy: 0.8856
# Epoch 30/250
# 54/54 - 4s - loss: 0.0122 - accuracy: 0.9977 - val_loss: 0.3476 - val_accuracy: 0.9078
# Epoch 31/250
# 54/54 - 4s - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.3091 - val_accuracy: 0.9183
# Epoch 32/250
# 54/54 - 4s - loss: 0.0072 - accuracy: 0.9985 - val_loss: 0.3468 - val_accuracy: 0.9148
# Epoch 33/250
# 54/54 - 4s - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.4513 - val_accuracy: 0.8938
# Epoch 34/250
# 54/54 - 4s - loss: 0.0104 - accuracy: 0.9975 - val_loss: 0.5272 - val_accuracy: 0.8786
# Epoch 35/250
# 54/54 - 4s - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.4619 - val_accuracy: 0.8961
# Epoch 36/250
# 54/54 - 4s - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.4906 - val_accuracy: 0.8845
# Epoch 37/250
# 54/54 - 4s - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.3575 - val_accuracy: 0.9078
# Epoch 38/250
# 54/54 - 4s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.4165 - val_accuracy: 0.9008
# Epoch 39/250
# 54/54 - 4s - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.3953 - val_accuracy: 0.9067
# Epoch 40/250
# 54/54 - 4s - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.6036 - val_accuracy: 0.8705
# Epoch 41/250
# 54/54 - 4s - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.4037 - val_accuracy: 0.8985
# Epoch 42/250
# 54/54 - 4s - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.5138 - val_accuracy: 0.8961
# Epoch 43/250
# 54/54 - 4s - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.5163 - val_accuracy: 0.8833
# Epoch 44/250
# 54/54 - 4s - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.5732 - val_accuracy: 0.8751
# Epoch 45/250
# 54/54 - 4s - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.4169 - val_accuracy: 0.9113
# Epoch 46/250
# 54/54 - 4s - loss: 0.0163 - accuracy: 0.9958 - val_loss: 0.3926 - val_accuracy: 0.9078
# Epoch 47/250
# 54/54 - 4s - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.4079 - val_accuracy: 0.9113
# Epoch 48/250
# 54/54 - 4s - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.4255 - val_accuracy: 0.9043
# Epoch 49/250
# 54/54 - 4s - loss: 0.0098 - accuracy: 0.9974 - val_loss: 0.4890 - val_accuracy: 0.8926
# Epoch 50/250
# 54/54 - 4s - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.3855 - val_accuracy: 0.9090
# Epoch 51/250
# 54/54 - 4s - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.4151 - val_accuracy: 0.8950
# Epoch 52/250
# 54/54 - 4s - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.3356 - val_accuracy: 0.9207
# Epoch 53/250
# 54/54 - 4s - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.3951 - val_accuracy: 0.9078
# Epoch 54/250
# 54/54 - 4s - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3585 - val_accuracy: 0.9055
# Epoch 55/250
# 54/54 - 4s - loss: 0.0163 - accuracy: 0.9956 - val_loss: 0.6289 - val_accuracy: 0.8845
# Epoch 56/250
# 54/54 - 4s - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.4089 - val_accuracy: 0.9032
# Epoch 57/250
# 54/54 - 4s - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.5915 - val_accuracy: 0.8728
# Epoch 58/250
# 54/54 - 4s - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.3716 - val_accuracy: 0.9043
# Epoch 59/250
# 54/54 - 4s - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.6113 - val_accuracy: 0.8611
# Epoch 60/250
# 54/54 - 4s - loss: 0.0212 - accuracy: 0.9934 - val_loss: 0.7377 - val_accuracy: 0.8495
# Epoch 61/250
# 54/54 - 4s - loss: 0.0145 - accuracy: 0.9961 - val_loss: 0.5561 - val_accuracy: 0.8891
# Epoch 62/250
# 54/54 - 4s - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.4416 - val_accuracy: 0.9032
# Epoch 63/250
# 54/54 - 4s - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.4435 - val_accuracy: 0.9078
# Epoch 64/250
# 54/54 - 4s - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.3636 - val_accuracy: 0.9172
# Epoch 65/250
# 54/54 - 4s - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.3192 - val_accuracy: 0.9230
# Epoch 66/250
# 54/54 - 4s - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.8409 - val_accuracy: 0.8436
# Epoch 67/250
# 54/54 - 4s - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.4882 - val_accuracy: 0.8938
# Epoch 68/250
# 54/54 - 4s - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.3400 - val_accuracy: 0.9172
# Epoch 69/250
# 54/54 - 4s - loss: 0.0069 - accuracy: 0.9977 - val_loss: 1.0844 - val_accuracy: 0.8145
# Epoch 70/250
# 54/54 - 4s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.6921 - val_accuracy: 0.8658
# Epoch 71/250
# 54/54 - 4s - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.4372 - val_accuracy: 0.8938
# Epoch 72/250
# 54/54 - 4s - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.3260 - val_accuracy: 0.9230
# Epoch 73/250
# 54/54 - 4s - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.4519 - val_accuracy: 0.9032
# Epoch 74/250
# 54/54 - 4s - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.3472 - val_accuracy: 0.9125
# Epoch 75/250
# 54/54 - 4s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.3967 - val_accuracy: 0.9113
# Epoch 76/250
# 54/54 - 4s - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.3244 - val_accuracy: 0.9300
# Epoch 77/250
# 54/54 - 4s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.3274 - val_accuracy: 0.9183
# Epoch 78/250
# 54/54 - 4s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.3356 - val_accuracy: 0.9218
# Epoch 79/250
# 54/54 - 4s - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.4585 - val_accuracy: 0.9078
# Epoch 80/250
# 54/54 - 4s - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.4683 - val_accuracy: 0.8985
# Epoch 81/250
# 54/54 - 4s - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.3008 - val_accuracy: 0.9253
# Epoch 82/250
# 54/54 - 4s - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.3909 - val_accuracy: 0.9113
# Epoch 83/250
# 54/54 - 4s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.3171 - val_accuracy: 0.9230
# Epoch 84/250
# 54/54 - 4s - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.9489 - val_accuracy: 0.8378
# Epoch 85/250
# 54/54 - 4s - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.7342 - val_accuracy: 0.8530
# Epoch 86/250
# 54/54 - 4s - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.6453 - val_accuracy: 0.8880
# Epoch 87/250
# 54/54 - 4s - loss: 0.0085 - accuracy: 0.9981 - val_loss: 0.3098 - val_accuracy: 0.9323
# Epoch 88/250
# 54/54 - 4s - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.3188 - val_accuracy: 0.9312
# Epoch 89/250
# 54/54 - 4s - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.4403 - val_accuracy: 0.9137
# Epoch 90/250
# 54/54 - 4s - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.3618 - val_accuracy: 0.9160
# Epoch 91/250
# 54/54 - 4s - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.3084 - val_accuracy: 0.9323
# Epoch 92/250
# 54/54 - 4s - loss: 0.0120 - accuracy: 0.9956 - val_loss: 0.6562 - val_accuracy: 0.8868
# Epoch 93/250
# 54/54 - 4s - loss: 0.0233 - accuracy: 0.9927 - val_loss: 0.7607 - val_accuracy: 0.8541
# Epoch 94/250
# 54/54 - 4s - loss: 0.0196 - accuracy: 0.9931 - val_loss: 0.4322 - val_accuracy: 0.9078
# Epoch 95/250
# 54/54 - 4s - loss: 0.0175 - accuracy: 0.9949 - val_loss: 0.8039 - val_accuracy: 0.8623
# Epoch 96/250
# 54/54 - 4s - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.6417 - val_accuracy: 0.8891
# Epoch 97/250
# 54/54 - 4s - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.3473 - val_accuracy: 0.9172
# Epoch 98/250
# 54/54 - 4s - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.3334 - val_accuracy: 0.9288
# Epoch 99/250
# 54/54 - 4s - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.3584 - val_accuracy: 0.9312
# Epoch 100/250
# 54/54 - 4s - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.3824 - val_accuracy: 0.9160
# Epoch 101/250
# 54/54 - 4s - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.5383 - val_accuracy: 0.8926
# Epoch 102/250
# 54/54 - 4s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.4663 - val_accuracy: 0.9125
# Epoch 103/250
# 54/54 - 4s - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.3586 - val_accuracy: 0.9288
# Epoch 104/250
# 54/54 - 4s - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.5859 - val_accuracy: 0.8926
# Epoch 105/250
# 54/54 - 4s - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.7234 - val_accuracy: 0.8705
# Epoch 106/250
# 54/54 - 4s - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.4381 - val_accuracy: 0.9090
# Epoch 107/250
# 54/54 - 4s - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.6235 - val_accuracy: 0.8810
# Epoch 108/250
# 54/54 - 4s - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.4746 - val_accuracy: 0.9078
# Epoch 109/250
# 54/54 - 4s - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.5791 - val_accuracy: 0.8926
# Epoch 110/250
# 54/54 - 4s - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.4384 - val_accuracy: 0.9113
# Epoch 111/250
# 54/54 - 4s - loss: 0.0084 - accuracy: 0.9975 - val_loss: 1.0599 - val_accuracy: 0.8343
# Epoch 112/250
# 54/54 - 4s - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.4015 - val_accuracy: 0.9125
# Epoch 113/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.6395 - val_accuracy: 0.8950
# Epoch 114/250
# 54/54 - 4s - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.4594 - val_accuracy: 0.9148
# Epoch 115/250
# 54/54 - 4s - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.6159 - val_accuracy: 0.8926
# Epoch 116/250
# 54/54 - 4s - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.5626 - val_accuracy: 0.8891
# Epoch 117/250
# 54/54 - 4s - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.4579 - val_accuracy: 0.9032
# Epoch 118/250
# 54/54 - 4s - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.4887 - val_accuracy: 0.9032
# Epoch 119/250
# 54/54 - 4s - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.3837 - val_accuracy: 0.9172
# Epoch 120/250
# 54/54 - 4s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.4292 - val_accuracy: 0.9067
# Epoch 121/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.4060 - val_accuracy: 0.9137
# Epoch 122/250
# 54/54 - 4s - loss: 0.0154 - accuracy: 0.9958 - val_loss: 0.5051 - val_accuracy: 0.9032
# Epoch 123/250
# 54/54 - 4s - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.5940 - val_accuracy: 0.8775
# Epoch 124/250
# 54/54 - 4s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.7448 - val_accuracy: 0.8751
# Epoch 125/250
# 54/54 - 4s - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.5551 - val_accuracy: 0.8973
# Epoch 126/250
# 54/54 - 4s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.3351 - val_accuracy: 0.9195
# Epoch 127/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.3477 - val_accuracy: 0.9242
# Epoch 128/250
# 54/54 - 4s - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.4692 - val_accuracy: 0.9090
# Epoch 129/250
# 54/54 - 4s - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.3465 - val_accuracy: 0.9288
# Epoch 130/250
# 54/54 - 4s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.3353 - val_accuracy: 0.9300
# Epoch 131/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.3309 - val_accuracy: 0.9312
# Epoch 132/250
# 54/54 - 4s - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.3972 - val_accuracy: 0.9218
# Epoch 133/250
# 54/54 - 4s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.3213 - val_accuracy: 0.9358
# Epoch 134/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.4281 - val_accuracy: 0.9172
# Epoch 135/250
# 54/54 - 4s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.2996 - val_accuracy: 0.9358
# Epoch 136/250
# 54/54 - 4s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.3253 - val_accuracy: 0.9300
# Epoch 137/250
# 54/54 - 4s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.3348 - val_accuracy: 0.9230
# Epoch 138/250
# 54/54 - 4s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.3512 - val_accuracy: 0.9265
# Epoch 139/250
# 54/54 - 4s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.4340 - val_accuracy: 0.9160
# Epoch 140/250
# 54/54 - 4s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.5536 - val_accuracy: 0.8961
# Epoch 141/250
# 54/54 - 4s - loss: 0.0167 - accuracy: 0.9943 - val_loss: 1.2340 - val_accuracy: 0.8075
# Epoch 142/250
# 54/54 - 4s - loss: 0.0270 - accuracy: 0.9915 - val_loss: 0.5405 - val_accuracy: 0.9020
# Epoch 143/250
# 54/54 - 4s - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.4535 - val_accuracy: 0.9020
# Epoch 144/250
# 54/54 - 4s - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.5857 - val_accuracy: 0.8868
# Epoch 145/250
# 54/54 - 4s - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.5165 - val_accuracy: 0.8985
# Epoch 146/250
# 54/54 - 4s - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.2614 - val_accuracy: 0.9405
# Epoch 147/250
# 54/54 - 4s - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.3925 - val_accuracy: 0.9137
# Epoch 148/250
# 54/54 - 4s - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.5594 - val_accuracy: 0.8868
# Epoch 149/250
# 54/54 - 4s - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.3700 - val_accuracy: 0.9288
# Epoch 150/250
# 54/54 - 4s - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.3407 - val_accuracy: 0.9288
# Epoch 151/250
# 54/54 - 4s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.5479 - val_accuracy: 0.8903
# Epoch 152/250
# 54/54 - 4s - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.3175 - val_accuracy: 0.9148
# Epoch 153/250
# 54/54 - 4s - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.3870 - val_accuracy: 0.9218
# Epoch 154/250
# 54/54 - 4s - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.3341 - val_accuracy: 0.9300
# Epoch 155/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.4311 - val_accuracy: 0.9113
# Epoch 156/250
# 54/54 - 4s - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.3933 - val_accuracy: 0.9195
# Epoch 157/250
# 54/54 - 4s - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.3538 - val_accuracy: 0.9183
# Epoch 158/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.3605 - val_accuracy: 0.9207
# Epoch 159/250
# 54/54 - 4s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.3292 - val_accuracy: 0.9253
# Epoch 160/250
# 54/54 - 4s - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.2874 - val_accuracy: 0.9277
# Epoch 161/250
# 54/54 - 4s - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.3465 - val_accuracy: 0.9288
# Epoch 162/250
# 54/54 - 4s - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.3308 - val_accuracy: 0.9288
# Epoch 163/250
# 54/54 - 4s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.3186 - val_accuracy: 0.9312
# Epoch 164/250
# 54/54 - 4s - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.3086 - val_accuracy: 0.9300
# Epoch 165/250
# 54/54 - 4s - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.3698 - val_accuracy: 0.9288
# Epoch 166/250
# 54/54 - 4s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.3692 - val_accuracy: 0.9148
# Epoch 167/250
# 54/54 - 4s - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.2846 - val_accuracy: 0.9277
# Epoch 168/250
# 54/54 - 4s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.3593 - val_accuracy: 0.9265
# Epoch 169/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.4717 - val_accuracy: 0.9102
# Epoch 170/250
# 54/54 - 4s - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.4940 - val_accuracy: 0.9090
# Epoch 171/250
# 54/54 - 4s - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.3866 - val_accuracy: 0.9253
# Epoch 172/250
# 54/54 - 4s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.6534 - val_accuracy: 0.8926
# Epoch 173/250
# 54/54 - 4s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.3823 - val_accuracy: 0.9218
# Epoch 174/250
# 54/54 - 4s - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.4416 - val_accuracy: 0.9137
# Epoch 175/250
# 54/54 - 4s - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.6319 - val_accuracy: 0.8950
# Epoch 176/250
# 54/54 - 4s - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.4541 - val_accuracy: 0.9008
# Epoch 177/250
# 54/54 - 4s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.3520 - val_accuracy: 0.9195
# Epoch 178/250
# 54/54 - 4s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.4116 - val_accuracy: 0.9148
# Epoch 179/250
# 54/54 - 4s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.3670 - val_accuracy: 0.9125
# Epoch 180/250
# 54/54 - 4s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.3278 - val_accuracy: 0.9253
# Epoch 181/250
# 54/54 - 4s - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.4281 - val_accuracy: 0.9183
# Epoch 182/250
# 54/54 - 4s - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.5042 - val_accuracy: 0.8961
# Epoch 183/250
# 54/54 - 4s - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.6313 - val_accuracy: 0.8856
# Epoch 184/250
# 54/54 - 4s - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.3420 - val_accuracy: 0.9207
# Epoch 185/250
# 54/54 - 4s - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.5544 - val_accuracy: 0.9067
# Epoch 186/250
# 54/54 - 4s - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.8850 - val_accuracy: 0.8646
# Epoch 187/250
# 54/54 - 4s - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.4106 - val_accuracy: 0.9102
# Epoch 188/250
# 54/54 - 4s - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.5065 - val_accuracy: 0.9055
# Epoch 189/250
# 54/54 - 4s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.5878 - val_accuracy: 0.8891
# Epoch 190/250
# 54/54 - 4s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.4241 - val_accuracy: 0.9160
# Epoch 191/250
# 54/54 - 4s - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.3257 - val_accuracy: 0.9323
# Epoch 192/250
# 54/54 - 4s - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.3016 - val_accuracy: 0.9335
# Epoch 193/250
# 54/54 - 4s - loss: 0.0041 - accuracy: 0.9981 - val_loss: 0.7073 - val_accuracy: 0.8786
# Epoch 194/250
# 54/54 - 4s - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.3079 - val_accuracy: 0.9288
# Epoch 195/250
# 54/54 - 4s - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.2708 - val_accuracy: 0.9277
# Epoch 196/250
# 54/54 - 4s - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.2992 - val_accuracy: 0.9347
# Epoch 197/250
# 54/54 - 4s - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.3193 - val_accuracy: 0.9358
# Epoch 198/250
# 54/54 - 4s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.4492 - val_accuracy: 0.9125
# Epoch 199/250
# 54/54 - 4s - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.3291 - val_accuracy: 0.9230
# Epoch 200/250
# 54/54 - 4s - loss: 9.2450e-04 - accuracy: 0.9999 - val_loss: 0.2981 - val_accuracy: 0.9312
# Epoch 201/250
# 54/54 - 4s - loss: 8.7539e-04 - accuracy: 0.9997 - val_loss: 0.2983 - val_accuracy: 0.9382
# Epoch 202/250
# 54/54 - 4s - loss: 9.7742e-04 - accuracy: 0.9997 - val_loss: 0.3444 - val_accuracy: 0.9312
# Epoch 203/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.4751 - val_accuracy: 0.9137
# Epoch 204/250
# 54/54 - 4s - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.4203 - val_accuracy: 0.9230
# Epoch 205/250
# 54/54 - 4s - loss: 0.0028 - accuracy: 0.9988 - val_loss: 0.3495 - val_accuracy: 0.9277
# Epoch 206/250
# 54/54 - 4s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.3175 - val_accuracy: 0.9312
# Epoch 207/250
# 54/54 - 4s - loss: 4.1249e-04 - accuracy: 1.0000 - val_loss: 0.2869 - val_accuracy: 0.9382
# Epoch 208/250
# 54/54 - 4s - loss: 6.4435e-04 - accuracy: 0.9997 - val_loss: 0.3704 - val_accuracy: 0.9207
# Epoch 209/250
# 54/54 - 4s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2938 - val_accuracy: 0.9312
# Epoch 210/250
# 54/54 - 4s - loss: 9.4704e-04 - accuracy: 0.9997 - val_loss: 0.3908 - val_accuracy: 0.9207
# Epoch 211/250
# 54/54 - 4s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.3716 - val_accuracy: 0.9218
# Epoch 212/250
# 54/54 - 4s - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.3848 - val_accuracy: 0.9148
# Epoch 213/250
# 54/54 - 4s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.3498 - val_accuracy: 0.9265
# Epoch 214/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.4039 - val_accuracy: 0.9265
# Epoch 215/250
# 54/54 - 4s - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.4174 - val_accuracy: 0.9113
# Epoch 216/250
# 54/54 - 4s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.5086 - val_accuracy: 0.9032
# Epoch 217/250
# 54/54 - 4s - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.4600 - val_accuracy: 0.9067
# Epoch 218/250
# 54/54 - 4s - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.5794 - val_accuracy: 0.8938
# Epoch 219/250
# 54/54 - 4s - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.5536 - val_accuracy: 0.8903
# Epoch 220/250
# 54/54 - 4s - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.6917 - val_accuracy: 0.8693
# Epoch 221/250
# 54/54 - 4s - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.4668 - val_accuracy: 0.9055
# Epoch 222/250
# 54/54 - 4s - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.4288 - val_accuracy: 0.9160
# Epoch 223/250
# 54/54 - 4s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.4340 - val_accuracy: 0.9078
# Epoch 224/250
# ...
# Epoch 94/250
# 54/54 - 4s - loss: 2.5632 - accuracy: 0.0763 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 95/250
# 54/54 - 4s - loss: 2.5673 - accuracy: 0.0694 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 96/250
# 54/54 - 4s - loss: 2.5657 - accuracy: 0.0744 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 97/250
# 54/54 - 4s - loss: 2.5626 - accuracy: 0.0836 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 98/250
# 54/54 - 4s - loss: 2.5642 - accuracy: 0.0767 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 99/250
# 54/54 - 4s - loss: 2.5637 - accuracy: 0.0790 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 100/250
# 54/54 - 4s - loss: 2.5637 - accuracy: 0.0812 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 101/250
# 54/54 - 4s - loss: 2.5630 - accuracy: 0.0809 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 102/250
# 54/54 - 4s - loss: 2.5656 - accuracy: 0.0793 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 103/250
# 54/54 - 4s - loss: 2.5644 - accuracy: 0.0841 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 104/250
# 54/54 - 4s - loss: 2.5636 - accuracy: 0.0833 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 105/250
# 54/54 - 4s - loss: 2.5623 - accuracy: 0.0783 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 106/250
# 54/54 - 4s - loss: 2.5639 - accuracy: 0.0774 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 107/250
# 54/54 - 4s - loss: 2.5634 - accuracy: 0.0817 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 108/250
# 54/54 - 4s - loss: 2.5649 - accuracy: 0.0827 - val_loss: 2.5600 - val_accuracy: 0.0805
# Epoch 109/250
# 54/54 - 4s - loss: 2.5632 - accuracy: 0.0748 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 110/250
# 54/54 - 4s - loss: 2.5634 - accuracy: 0.0779 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 111/250
# 54/54 - 4s - loss: 2.5625 - accuracy: 0.0833 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 112/250
# 54/54 - 4s - loss: 2.5634 - accuracy: 0.0770 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 113/250
# 54/54 - 4s - loss: 2.5629 - accuracy: 0.0793 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 114/250
# 54/54 - 4s - loss: 2.5621 - accuracy: 0.0801 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 115/250
# 54/54 - 4s - loss: 2.5621 - accuracy: 0.0850 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 116/250
# 54/54 - 4s - loss: 2.5626 - accuracy: 0.0834 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 117/250
# 54/54 - 4s - loss: 2.5618 - accuracy: 0.0809 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 118/250
# 54/54 - 4s - loss: 2.5622 - accuracy: 0.0866 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 119/250
# 54/54 - 4s - loss: 2.5628 - accuracy: 0.0802 - val_loss: 2.5598 - val_accuracy: 0.0817
# Epoch 120/250
# 54/54 - 4s - loss: 2.5625 - accuracy: 0.0787 - val_loss: 2.5599 - val_accuracy: 0.0817
# Epoch 121/250
# 54/54 - 4s - loss: 2.5633 - accuracy: 0.0782 - val_loss: 2.5598 - val_accuracy: 0.0817
# Epoch 122/250
# 54/54 - 4s - loss: 2.5636 - accuracy: 0.0771 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 123/250
# 54/54 - 4s - loss: 2.5621 - accuracy: 0.0811 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 124/250
# 54/54 - 4s - loss: 2.5604 - accuracy: 0.0837 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 125/250
# 54/54 - 4s - loss: 2.5634 - accuracy: 0.0757 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 126/250
# 54/54 - 4s - loss: 2.5641 - accuracy: 0.0771 - val_loss: 2.5601 - val_accuracy: 0.0805
# Epoch 127/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0854 - val_loss: 2.5601 - val_accuracy: 0.0805
# Epoch 128/250
# 54/54 - 4s - loss: 2.5621 - accuracy: 0.0784 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 129/250
# 54/54 - 4s - loss: 2.5598 - accuracy: 0.0856 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 130/250
# 54/54 - 4s - loss: 2.5624 - accuracy: 0.0798 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 131/250
# 54/54 - 4s - loss: 2.5629 - accuracy: 0.0789 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 132/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0840 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 133/250
# 54/54 - 4s - loss: 2.5614 - accuracy: 0.0844 - val_loss: 2.5600 - val_accuracy: 0.0805
# Epoch 134/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0809 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 135/250
# 54/54 - 4s - loss: 2.5623 - accuracy: 0.0790 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 136/250
# 54/54 - 4s - loss: 2.5625 - accuracy: 0.0809 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 137/250
# 54/54 - 4s - loss: 2.5638 - accuracy: 0.0792 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 138/250
# 54/54 - 4s - loss: 2.5617 - accuracy: 0.0869 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 139/250
# 54/54 - 4s - loss: 2.5610 - accuracy: 0.0830 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 140/250
# 54/54 - 4s - loss: 2.5627 - accuracy: 0.0811 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 141/250
# 54/54 - 4s - loss: 2.5622 - accuracy: 0.0811 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 142/250
# 54/54 - 4s - loss: 2.5618 - accuracy: 0.0824 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 143/250
# 54/54 - 4s - loss: 2.5619 - accuracy: 0.0764 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 144/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0879 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 145/250
# 54/54 - 4s - loss: 2.5623 - accuracy: 0.0729 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 146/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0830 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 147/250
# 54/54 - 4s - loss: 2.5622 - accuracy: 0.0891 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 148/250
# 54/54 - 4s - loss: 2.5623 - accuracy: 0.0782 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 149/250
# 54/54 - 4s - loss: 2.5629 - accuracy: 0.0770 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 150/250
# 54/54 - 4s - loss: 2.5594 - accuracy: 0.0844 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 151/250
# 54/54 - 4s - loss: 2.5613 - accuracy: 0.0838 - val_loss: 2.5599 - val_accuracy: 0.0805
# Epoch 152/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0830 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 153/250
# 54/54 - 4s - loss: 2.5621 - accuracy: 0.0770 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 154/250
# 54/54 - 4s - loss: 2.5612 - accuracy: 0.0836 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 155/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0771 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 156/250
# 54/54 - 4s - loss: 2.5609 - accuracy: 0.0828 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 157/250
# 54/54 - 4s - loss: 2.5629 - accuracy: 0.0725 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 158/250
# 54/54 - 4s - loss: 2.5609 - accuracy: 0.0777 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 159/250
# 54/54 - 4s - loss: 2.5623 - accuracy: 0.0733 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 160/250
# 54/54 - 4s - loss: 2.5618 - accuracy: 0.0742 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 161/250
# 54/54 - 4s - loss: 2.5613 - accuracy: 0.0763 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 162/250
# 54/54 - 4s - loss: 2.5609 - accuracy: 0.0805 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 163/250
# 54/54 - 4s - loss: 2.5598 - accuracy: 0.0843 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 164/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0787 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 165/250
# 54/54 - 4s - loss: 2.5619 - accuracy: 0.0818 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 166/250
# 54/54 - 4s - loss: 2.5614 - accuracy: 0.0801 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 167/250
# 54/54 - 4s - loss: 2.5612 - accuracy: 0.0846 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 168/250
# 54/54 - 4s - loss: 2.5619 - accuracy: 0.0780 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 169/250
# 54/54 - 4s - loss: 2.5623 - accuracy: 0.0779 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 170/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0808 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 171/250
# 54/54 - 4s - loss: 2.5601 - accuracy: 0.0859 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 172/250
# 54/54 - 4s - loss: 2.5614 - accuracy: 0.0803 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 173/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0773 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 174/250
# 54/54 - 4s - loss: 2.5597 - accuracy: 0.0857 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 175/250
# 54/54 - 4s - loss: 2.5621 - accuracy: 0.0764 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 176/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0827 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 177/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0751 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 178/250
# 54/54 - 4s - loss: 2.5618 - accuracy: 0.0793 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 179/250
# 54/54 - 4s - loss: 2.5611 - accuracy: 0.0795 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 180/250
# 54/54 - 4s - loss: 2.5620 - accuracy: 0.0774 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 181/250
# 54/54 - 4s - loss: 2.5606 - accuracy: 0.0830 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 182/250
# 54/54 - 4s - loss: 2.5611 - accuracy: 0.0815 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 183/250
# 54/54 - 4s - loss: 2.5608 - accuracy: 0.0796 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 184/250
# 54/54 - 4s - loss: 2.5609 - accuracy: 0.0803 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 185/250
# 54/54 - 4s - loss: 2.5606 - accuracy: 0.0852 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 186/250
# 54/54 - 4s - loss: 2.5604 - accuracy: 0.0878 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 187/250
# 54/54 - 4s - loss: 2.5607 - accuracy: 0.0801 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 188/250
# 54/54 - 4s - loss: 2.5608 - accuracy: 0.0865 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 189/250
# 54/54 - 4s - loss: 2.5607 - accuracy: 0.0850 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 190/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0808 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 191/250
# 54/54 - 4s - loss: 2.5613 - accuracy: 0.0811 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 192/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0799 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 193/250
# 54/54 - 4s - loss: 2.5600 - accuracy: 0.0841 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 194/250
# 54/54 - 4s - loss: 2.5612 - accuracy: 0.0790 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 195/250
# 54/54 - 4s - loss: 2.5610 - accuracy: 0.0815 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 196/250
# 54/54 - 4s - loss: 2.5589 - accuracy: 0.0846 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 197/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0844 - val_loss: 2.5598 - val_accuracy: 0.0817
# Epoch 198/250
# 54/54 - 4s - loss: 2.5614 - accuracy: 0.0825 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 199/250
# 54/54 - 4s - loss: 2.5616 - accuracy: 0.0795 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 200/250
# 54/54 - 4s - loss: 2.5612 - accuracy: 0.0828 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 201/250
# 54/54 - 4s - loss: 2.5599 - accuracy: 0.0836 - val_loss: 2.5598 - val_accuracy: 0.0805
# Epoch 202/250
# 54/54 - 4s - loss: 2.5608 - accuracy: 0.0817 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 203/250
# 54/54 - 4s - loss: 2.5601 - accuracy: 0.0803 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 204/250
# 54/54 - 4s - loss: 2.5601 - accuracy: 0.0828 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 205/250
# 54/54 - 4s - loss: 2.5608 - accuracy: 0.0834 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 206/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0825 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 207/250
# 54/54 - 4s - loss: 2.5604 - accuracy: 0.0822 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 208/250
# 54/54 - 4s - loss: 2.5600 - accuracy: 0.0783 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 209/250
# 54/54 - 4s - loss: 2.5608 - accuracy: 0.0768 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 210/250
# 54/54 - 4s - loss: 2.5615 - accuracy: 0.0812 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 211/250
# 54/54 - 4s - loss: 2.5616 - accuracy: 0.0792 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 212/250
# 54/54 - 4s - loss: 2.5604 - accuracy: 0.0818 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 213/250
# 54/54 - 4s - loss: 2.5607 - accuracy: 0.0798 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 214/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0789 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 215/250
# 54/54 - 4s - loss: 2.5609 - accuracy: 0.0773 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 216/250
# 54/54 - 4s - loss: 2.5598 - accuracy: 0.0790 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 217/250
# 54/54 - 4s - loss: 2.5608 - accuracy: 0.0792 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 218/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0771 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 219/250
# 54/54 - 4s - loss: 2.5603 - accuracy: 0.0863 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 220/250
# 54/54 - 4s - loss: 2.5600 - accuracy: 0.0815 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 221/250
# 54/54 - 4s - loss: 2.5602 - accuracy: 0.0801 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 222/250
# 54/54 - 4s - loss: 2.5613 - accuracy: 0.0741 - val_loss: 2.5597 - val_accuracy: 0.0817
# Epoch 223/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0782 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 224/250
# 54/54 - 4s - loss: 2.5614 - accuracy: 0.0780 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 225/250
# 54/54 - 4s - loss: 2.5607 - accuracy: 0.0802 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 226/250
# 54/54 - 4s - loss: 2.5601 - accuracy: 0.0767 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 227/250
# 54/54 - 4s - loss: 2.5603 - accuracy: 0.0805 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 228/250
# 54/54 - 4s - loss: 2.5596 - accuracy: 0.0803 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 229/250
# 54/54 - 4s - loss: 2.5601 - accuracy: 0.0792 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 230/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0803 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 231/250
# 54/54 - 4s - loss: 2.5611 - accuracy: 0.0824 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 232/250
# 54/54 - 4s - loss: 2.5591 - accuracy: 0.0819 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 233/250
# 54/54 - 4s - loss: 2.5592 - accuracy: 0.0831 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 234/250
# 54/54 - 4s - loss: 2.5598 - accuracy: 0.0811 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 235/250
# 54/54 - 4s - loss: 2.5600 - accuracy: 0.0787 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 236/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0793 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 237/250
# 54/54 - 4s - loss: 2.5601 - accuracy: 0.0744 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 238/250
# 54/54 - 4s - loss: 2.5609 - accuracy: 0.0768 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 239/250
# 54/54 - 4s - loss: 2.5589 - accuracy: 0.0841 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 240/250
# 54/54 - 4s - loss: 2.5604 - accuracy: 0.0796 - val_loss: 2.5597 - val_accuracy: 0.0805
# Epoch 241/250
# 54/54 - 4s - loss: 2.5596 - accuracy: 0.0860 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 242/250
# 54/54 - 4s - loss: 2.5607 - accuracy: 0.0796 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 243/250
# 54/54 - 4s - loss: 2.5596 - accuracy: 0.0833 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 244/250
# 54/54 - 4s - loss: 2.5611 - accuracy: 0.0747 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 245/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0779 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 246/250
# 54/54 - 4s - loss: 2.5605 - accuracy: 0.0822 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 247/250
# 54/54 - 4s - loss: 2.5604 - accuracy: 0.0771 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 248/250
# 54/54 - 4s - loss: 2.5593 - accuracy: 0.0817 - val_loss: 2.5596 - val_accuracy: 0.0805
# Epoch 249/250
# 54/54 - 4s - loss: 2.5591 - accuracy: 0.0854 - val_loss: 2.5596 - val_accuracy: 0.0817
# Epoch 250/250
# 54/54 - 4s - loss: 2.5597 - accuracy: 0.0773 - val_loss: 2.5596 - val_accuracy: 0.0817
# INFO:tensorflow:Assets written to: CNN_robust_s1.99_r0.99_saved_model_after_fit/assets

# %%
dfs_to_concat = []
# pd.concat([df1, df2], axis=0)
for m, h in results_robust:
  history_df = pd.DataFrame(h.history) 
  history_df['Model'] = str(m.name)
  history_df.to_csv(f"{m.name}_history.csv",header=True, index=False)
  dfs_to_concat.append(history_df)

# %%
concatedDf = pd.concat(dfs_to_concat, axis=0, ignore_index=True)
concatedDf.to_csv("Concatenated_history.csv", header=True, index=False)

# %%
plot_history(history_cnn_2)
