# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.models import Model
from gpflow.config import set_default_float, default_float, set_default_summary_fmt
import warnings
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout, Embedding, Conv1D, Conv2D, MaxPooling2D, \
    MaxPooling1D, Concatenate, BatchNormalization, GaussianNoise
from tensorflow.keras.layers import LSTM, TimeDistributed, Permute, Reshape, Lambda, RepeatVector, Input, Multiply, \
    SimpleRNN, GRU, LeakyReLU
from keras_self_attention import SeqSelfAttention, SeqWeightedAttention
import kerastuner as kt
import site
import pandas as pd
import site
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fc56e7956e1b> in <module>()
#       3 from tensorflow.keras.layers import Bidirectional
#       4 from tensorflow.keras.models import Model
# ----> 5 from gpflow.config import set_default_float, default_float, set_default_summary_fmt
#       6 import warnings
#       7 from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout, Embedding, Conv1D, Conv2D, MaxPooling2D,     MaxPooling1D, Concatenate, BatchNormalization, GaussianNoise
#
# ModuleNotFoundError: No module named 'gpflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
